# %% [markdown]
# ### **필요 라이브러리 및 API 키 설정**

# %%
from typing import List
from polygon import RESTClient
import os
import requests
from langchain_community.document_loaders import WebBaseLoader
from langchain_core.tools import tool
from tavily import TavilyClient
import pandas as pd
from bs4 import BeautifulSoup
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# False

# %%
tavily_client = TavilyClient(api_key=os.environ['TAVILY_API_KEY'])
polygon_client = RESTClient(api_key=os.environ["POLYGON_API_KEY"])
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %% [markdown]
# ### **SEC 파일링을 통해 비재무 지표 요약하기**

# %% [markdown]
# SEC 홈페이지

# %% [markdown]
# !https://www.sec.gov/search-filings/edgar-application-programming-interfaces

# %%
headers = {'User-Agent': "your.email@example.com"}
company_tickers_url = "https://www.sec.gov/files/company_tickers.json"
response = requests.get(company_tickers_url, headers=headers)
company_tickers = response.json()
company_data = pd.DataFrame.from_dict(company_tickers, orient='index')
company_data['cik_str'] = company_data['cik_str'].astype(str).str.zfill(10)
ticker = "NVDA".upper()
company_data.set_index('ticker', inplace=True)


cik = company_data.loc['NVDA', 'cik_str']

base_url = f"https://data.sec.gov/submissions/CIK{cik}.json"
response = requests.get(base_url, headers=headers)

data = response.json()
filings = data.get('filings', {}).get('recent', {})
forms = filings.get('form', [])
dates = filings.get('filingDate', [])
accession_numbers = filings.get('accessionNumber', [])
document_urls = filings.get('primaryDocument', [])
df = pd.DataFrame({
    'form': forms,
    'date': dates,
    'accession_number': accession_numbers,
    'document_url': document_urls
})
df_filtered = df[df['form'].isin(['10-K', '10-Q', '8-K'])]
latest_filings = df_filtered.sort_values('date', ascending=False).drop_duplicates('form')

# %%
results = {}
for _, row in latest_filings.iterrows():
    form_type = row['form']
    date = row['date']
    accession_number = row['accession_number']
    document_url = row['document_url']
    filing_url = f"https://www.sec.gov/Archives/edgar/data/{int(cik)}/{accession_number.replace('-', '')}/{document_url}"
    response = requests.get(filing_url, headers=headers)
    if response.status_code != 200:
        results[form_type] = f"Failed to retrieve the filing from {filing_url}"
    else:
        soup = BeautifulSoup(response.content, 'html.parser')
        text_content = soup.get_text(separator='\n')
        results[form_type] = {
            'date': date,
            'url': filing_url,
            'content': text_content
        }

# %%
results
# Out:
# {'8-K': {'date': '2025-03-07',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581025000039/nvda-20250303.htm',
#   'content': '\n\n\n\n\n\n\n\n\n\nnvda-20250303\n0001045810\nfalse\n0001045810\n2025-03-03\n2025-03-03\nUNITED STATES\nSECURITIES AND EXCHANGE COMMISSION\nWASHINGTON, DC 20549\n______________\nFORM \n8-K\n \nCURRENT REPORT\nPURSUANT TO SECTION 13 OR 15(d) OF\nTHE SECURITIES EXCHANGE ACT OF 1934\nDate of Report (Date of earliest event reported): \nMarch 3, 2025\nNVIDIA CORP\nORATION\n(Exact name of registrant as specified in its charter)\nDelaware\n0-23985\n94-3177549\n(State or other jurisdiction\n(Commission\n(IRS Employer\nof incorporation)\nFile Number)\nIdentification No.)\n2788 San Tomas Expressway\n, \nSanta Clara\n, \nCA\n \n95051\n \n(Address of principal executive offices)   (Zip Code)\nRegistrant’s telephone number, including area code: \n(\n408\n) \n486-2000\n \nNot Applicable\n(Former name or former address, if changed since last report)\nCheck the appropriate box below if the Form 8-K filing is intended to simultaneously satisfy the filing obligation of the registrant under any of the following provisions:\n☐\n  Written communications pursuant to Rule 425 under the Securities Act (17 CFR 230.425)\n☐\n Soliciting material pursuant to Rule 14a-12 under the Exchange Act (17 CFR 240.14a-12)\n☐\n Pre-commencement communications pursuant to Rule 14d-2(b) under the Exchange Act (17 CFR 240.14d-2(b))\n☐\n Pre-commencement communications pursuant to Rule 13e-4(c) under the Exchange Act (17 CFR 240.13e-4(c))\nSecurities registered pursuant to Section 12(b) of the Act:\nTitle of each class\nTrading Symbol(s)\nName of each exchange on which registered\nCommon Stock, $0.001 par value per share\nNVDA\nThe Nasdaq Global Select Market\nIndicate by check mark whether the registrant is an emerging growth company as defined in Rule 405 of the Securities Act of 1933 (§230.405 of this chapter) or Rule 12b-2 of the Securities Exchange Act of 1934 (§240.12b-2 of this chapter). \n\xa0\xa0\xa0\xa0 Emerging Growth Company \n☐\n \nIf an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised financial accounting standards provided pursuant to Section 13(a) of the Exchange Act. ☐\nItem 5.02. Departure of Directors or Certain Officers; Election of Directors; Appointment of Certain Officers; Compensatory Arrangements of Certain Officers.\nAdoption of Fiscal Year 2026 Variable Compensation Plan\nOn March 3, 2025, the Compensation Committee of the Board of Directors, or the Board, of NVIDIA Corporation, or the Company, adopted the Variable Compensation Plan for Fiscal Year 2026, or the 2026 Plan, which provides eligible executive officers the opportunity to earn a variable cash payment based on the level of achievement by the Company of certain corporate performance goals, or the Performance Goals, during fiscal year 2026. The Company operates on a fiscal year ending on the last Sunday in January and designates its fiscal year by the year in which that fiscal year ends. Fiscal year 2026 refers to the Company’s fiscal year ending January 25, 2026.\nThe Compensation Committee has set the Performance Goals for fiscal year 2026 based upon the achievement of specified fiscal year 2026 revenue and has established threshold compensation plan, base compensation plan, and stretch compensation plan levels.\nUnless otherwise determined by the Compensation Committee, a participant must remain an employee through the payment date under the 2026 Plan to be eligible to earn an award.\nThe following table sets forth the respective target award opportunities for base compensation plan achievement for the Company’s named executive officers under the 2026 Plan:\nNamed Executive Officer\nTarget Award Opportunity for Base Compensation Plan\nAchievement\nTarget Award Opportunity for\nBase Compensation Plan\nAchievement as a % of\nFiscal Year 2026 Base Salary\nJen-Hsun Huang\nPresident and Chief Executive Officer\n$3,000,000\n200%\nColette M. Kress\nExecutive Vice Pre ...
#  '10-K': {'date': '2025-02-26',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581025000023/nvda-20250126.htm',
#   'content': '\n\n\n\n\n\n\n\n\n\nnvda-20250126\n0001045810\n2025\nFY\nfalse\n491\n358\nP1Y\nP2Y\nP2Y\nP1Y\nP3Y\nhttp://fasb.org/us-gaap/2024#AccruedLiabilitiesCurrent\nhttp://fasb.org/us-gaap/2024#AccruedLiabilitiesCurrent\nhttp://fasb.org/us-gaap/2024#AccruedLiabilitiesCurrent\niso4217:USD\nxbrli:shares\niso4217:USD\nxbrli:shares\nxbrli:pure\nnvda:period\nnvda:segment\n0001045810\n2024-01-29\n2025-01-26\n0001045810\n2024-07-26\n0001045810\n2025-02-21\n0001045810\nnvda:JohnO.DabiriMember\n2024-10-28\n2025-01-26\n0001045810\nnvda:AartiShahNovember25202410b51TradingArrangementMember\nnvda:MsAartiShahMember\n2024-10-28\n2025-01-26\n0001045810\nnvda:AartiShahSeptember27202410b51TradingArrangementMember\nnvda:MsAartiShahMember\n2024-10-28\n2025-01-26\n0001045810\n2024-10-28\n2025-01-26\n0001045810\nnvda:AartiShahSeptember27202410b51TradingArrangementMember\nnvda:MsAartiShahMember\n2025-01-26\n0001045810\nnvda:AartiShahNovember25202410b51TradingArrangementMember\nnvda:MsAartiShahMember\n2025-01-26\n0001045810\nnvda:JohnO.DabiriMember\n2025-01-26\n0001045810\n2023-01-30\n2024-01-28\n0001045810\n2022-01-31\n2023-01-29\n0001045810\n2025-01-26\n0001045810\n2024-01-28\n0001045810\nus-gaap:CommonStockMember\n2022-01-30\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2022-01-30\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2022-01-30\n0001045810\nus-gaap:RetainedEarningsMember\n2022-01-30\n0001045810\n2022-01-30\n0001045810\nus-gaap:RetainedEarningsMember\n2022-01-31\n2023-01-29\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2022-01-31\n2023-01-29\n0001045810\nus-gaap:CommonStockMember\n2022-01-31\n2023-01-29\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2022-01-31\n2023-01-29\n0001045810\nus-gaap:CommonStockMember\n2023-01-29\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2023-01-29\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2023-01-29\n0001045810\nus-gaap:RetainedEarningsMember\n2023-01-29\n0001045810\n2023-01-29\n0001045810\nus-gaap:RetainedEarningsMember\n2023-01-30\n2024-01-28\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2023-01-30\n2024-01-28\n0001045810\nus-gaap:CommonStockMember\n2023-01-30\n2024-01-28\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2023-01-30\n2024-01-28\n0001045810\nus-gaap:CommonStockMember\n2024-01-28\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2024-01-28\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2024-01-28\n0001045810\nus-gaap:RetainedEarningsMember\n2024-01-28\n0001045810\nus-gaap:RetainedEarningsMember\n2024-01-29\n2025-01-26\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2024-01-29\n2025-01-26\n0001045810\nus-gaap:CommonStockMember\n2024-01-29\n2025-01-26\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2024-01-29\n2025-01-26\n0001045810\nus-gaap:CommonStockMember\n2025-01-26\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2025-01-26\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2025-01-26\n0001045810\nus-gaap:RetainedEarningsMember\n2025-01-26\n0001045810\nsrt:MinimumMember\n2024-01-29\n2025-01-26\n0001045810\nsrt:MaximumMember\n2024-01-29\n2025-01-26\n0001045810\nus-gaap:CapitalLossCarryforwardMember\n2025-01-26\n0001045810\nsrt:MinimumMember\nnvda:EquipmentComputeHardwareAndSoftwareMember\n2025-01-26\n0001045810\nsrt:MinimumMember\n2025-01-26\n0001045810\nsrt:MaximumMember\nnvda:EquipmentComputeHardwareAndSoftwareMember\n2025-01-26\n0001045810\nsrt:MaximumMember\n2025-01-26\n0001045810\nus-gaap:BuildingMember\n2025-01-26\n0001045810\nnvda:ArmLimitedMember\n2022-01-31\n2023-01-29\n0001045810\nus-gaap:CostOfSalesMember\n2024-01-29\n2025-01-26\n0001045810\nus-gaap:CostOfSalesMember\n2023-01-30\n2024-01-28\n0001045810\nus-gaap:CostOfSalesMember\n2022-01-31\n2023-01-29\n0001045810\nus-gaap:ResearchAndDevelopmentExpenseMember\n2024-01-29\n2025-01-26\n0001045810\nus-gaap:ResearchAndDevelopmentExpenseMember\n2023-01-30\n2024-01-28\n0001045810\nus-g ...
#  '10-Q': {'date': '2024-11-20',
#   'url': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581024000316/nvda-20241027.htm',
#   'content': '\n\n\n\n\n\n\n\n\n\nnvda-20241027\n0001045810\n1/26\n2025\nQ3\nFALSE\nhttp://fasb.org/us-gaap/2024#AccruedLiabilitiesCurrent\nhttp://fasb.org/us-gaap/2024#AccruedLiabilitiesCurrent\n0\n550\n456\nxbrli:shares\niso4217:USD\niso4217:USD\nxbrli:shares\nxbrli:pure\nnvda:segment\n0001045810\n2024-01-29\n2024-10-27\n0001045810\n2024-11-15\n0001045810\n2024-07-29\n2024-10-27\n0001045810\n2023-07-31\n2023-10-29\n0001045810\n2023-01-30\n2023-10-29\n0001045810\n2024-10-27\n0001045810\n2024-01-28\n0001045810\nus-gaap:CommonStockMember\n2024-07-28\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2024-07-28\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2024-07-28\n0001045810\nus-gaap:RetainedEarningsMember\n2024-07-28\n0001045810\n2024-07-28\n0001045810\nus-gaap:RetainedEarningsMember\n2024-07-29\n2024-10-27\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2024-07-29\n2024-10-27\n0001045810\nus-gaap:CommonStockMember\n2024-07-29\n2024-10-27\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2024-07-29\n2024-10-27\n0001045810\nus-gaap:CommonStockMember\n2024-10-27\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2024-10-27\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2024-10-27\n0001045810\nus-gaap:RetainedEarningsMember\n2024-10-27\n0001045810\nus-gaap:CommonStockMember\n2023-07-30\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2023-07-30\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2023-07-30\n0001045810\nus-gaap:RetainedEarningsMember\n2023-07-30\n0001045810\n2023-07-30\n0001045810\nus-gaap:RetainedEarningsMember\n2023-07-31\n2023-10-29\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2023-07-31\n2023-10-29\n0001045810\nus-gaap:CommonStockMember\n2023-07-31\n2023-10-29\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2023-07-31\n2023-10-29\n0001045810\nus-gaap:CommonStockMember\n2023-10-29\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2023-10-29\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2023-10-29\n0001045810\nus-gaap:RetainedEarningsMember\n2023-10-29\n0001045810\n2023-10-29\n0001045810\nus-gaap:CommonStockMember\n2024-01-28\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2024-01-28\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2024-01-28\n0001045810\nus-gaap:RetainedEarningsMember\n2024-01-28\n0001045810\nus-gaap:RetainedEarningsMember\n2024-01-29\n2024-10-27\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2024-01-29\n2024-10-27\n0001045810\nus-gaap:CommonStockMember\n2024-01-29\n2024-10-27\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2024-01-29\n2024-10-27\n0001045810\nus-gaap:CommonStockMember\n2023-01-29\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2023-01-29\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2023-01-29\n0001045810\nus-gaap:RetainedEarningsMember\n2023-01-29\n0001045810\n2023-01-29\n0001045810\nus-gaap:RetainedEarningsMember\n2023-01-30\n2023-10-29\n0001045810\nus-gaap:AccumulatedOtherComprehensiveIncomeMember\n2023-01-30\n2023-10-29\n0001045810\nus-gaap:CommonStockMember\n2023-01-30\n2023-10-29\n0001045810\nus-gaap:AdditionalPaidInCapitalMember\n2023-01-30\n2023-10-29\n0001045810\n2024-05-01\n2024-05-31\n0001045810\n2024-06-06\n0001045810\n2024-06-07\n0001045810\nus-gaap:OperatingLeaseLeaseNotYetCommencedMember\n2024-10-27\n0001045810\nsrt:MinimumMember\n2024-10-27\n0001045810\nsrt:MaximumMember\n2024-10-27\n0001045810\nus-gaap:CostOfSalesMember\n2024-07-29\n2024-10-27\n0001045810\nus-gaap:CostOfSalesMember\n2023-07-31\n2023-10-29\n0001045810\nus-gaap:CostOfSalesMember\n2024-01-29\n2024-10-27\n0001045810\nus-gaap:CostOfSalesMember\n2023-01-30\n2023-10-29\n0001045810\nus-gaap:ResearchAndDevelopmentExpenseMember\n2024-07-29\n2024-10-27\n0001045810\nus-gaap:ResearchAndDevelopmentExpenseMember\n2023-07-31\n2023-10-29\n0001045810\nus-gaap:ResearchAndDevelopmentExpenseMember\n2024-01-29\n2024-10-27\n0001045810\nus-gaa ...

# %%
@tool
def get_latest_filing_content(ticker: str) -> dict:
    """주어진 티커에 대한 최신 10-K, 10-Q, 8-K 파일링을 수집하고 해당 파일링의 내용을 추출합니다."""
    headers = {'User-Agent': "your.email@example.com"}
    company_tickers_url = "https://www.sec.gov/files/company_tickers.json"
    response = requests.get(company_tickers_url, headers=headers)
    if response.status_code != 200:
        return f"Failed to retrieve company tickers."
    company_tickers = response.json()
    company_data = pd.DataFrame.from_dict(company_tickers, orient='index')
    company_data['cik_str'] = company_data['cik_str'].astype(str).str.zfill(10)
    ticker = ticker.upper()
    company_data.set_index('ticker', inplace=True)
    if ticker not in company_data.index:
        return f"Ticker {ticker} not found."
    
    cik = company_data.loc[ticker, 'cik_str']
    base_url = f"https://data.sec.gov/submissions/CIK{cik}.json"
    response = requests.get(base_url, headers=headers)
    if response.status_code != 200:
        return f"Failed to retrieve filings for CIK {cik}"
    data = response.json()
    filings = data.get('filings', {}).get('recent', {})
    forms = filings.get('form', [])
    dates = filings.get('filingDate', [])
    accession_numbers = filings.get('accessionNumber', [])
    document_urls = filings.get('primaryDocument', [])
    df = pd.DataFrame({
        'form': forms,
        'date': dates,
        'accession_number': accession_numbers,
        'document_url': document_urls
    })
    df_filtered = df[df['form'].isin(['10-K', '10-Q', '8-K'])]
    latest_filings = df_filtered.sort_values('date', ascending=False).drop_duplicates('form')
    results = {}
    for _, row in latest_filings.iterrows():
        form_type = row['form']
        date = row['date']
        accession_number = row['accession_number']
        document_url = row['document_url']
        filing_url = f"https://www.sec.gov/Archives/edgar/data/{int(cik)}/{accession_number.replace('-', '')}/{document_url}"
        response = requests.get(filing_url, headers=headers)
        if response.status_code != 200:
            results[form_type] = f"Failed to retrieve the filing from {filing_url}"
        else:
            soup = BeautifulSoup(response.content, 'html.parser')
            text_content = soup.get_text(separator='\n')
            results[form_type] = {
                'date': date,
                'url': filing_url,
                'content': text_content
            }
        # LCEL 체인 구성
    def summarize_filings(filings: dict) -> dict:
        prompt = ChatPromptTemplate.from_template(
            """다음은 {form_type} 파일링의 내용입니다. 주요 재무 지표, 중요한 사실들, 
            그리고 구체적인 세부 사항을 포함하여 요약해주세요. 
            최대한 풍부한 요약이 되게끔 해주세요.
            
            각 보고서 유형에 따라 다음과 같은 중요 정보들을 포함해야 합니다:
        
            10-K (연간 보고서):
            - 주요 재무 지표 (정확한 수치와 함께 매출, 순이익, EPS 등)
            - 사업 개요 및 주요 제품/서비스 (구체적인 제품명이나 서비스명 포함)
            - 주요 시장 및 고객 (가능한 경우 주요 고객사 이름 포함)
            - 경영진의 주요 변동 사항 (해당되는 경우 구체적인 이름과 직책 포함)
            - 중요한 위험 요인 (구체적인 예시와 함께)
            - 향후 전략 및 전망
            - 주요 소송 또는 규제 이슈 (구체적인 사건명이나 관련 기관명 포함)
        
            10-Q (분기 보고서):
            - 분기별 주요 재무 지표 (정확한 수치와 전년 동기 대비 변동률)
            - 주요 제품/서비스의 실적 (구체적인 제품명이나 서비스명과 함께)
            - 시장 동향 및 경쟁 상황 (가능한 경우 경쟁사 이름 포함)
            - 단기적인 위험 요소나 기회 (구체적인 예시와 함께)
            - 주요 운영 변경 사항 (해당되는 경우 구체적인 내용 포함)
        
            8-K (수시 보고서):
            - 보고 이벤트의 성격 (예: 경영진 변경, 인수합병, 중요 계약 체결 등)
            - 해당 이벤트의 주요 내용 (관련된 모든 당사자의 이름, 금액, 날짜 등 포함)
            - 회사에 미치는 잠재적 영향 (가능한 경우 구체적인 수치 예측 포함)
            - 관련된 중요 인물의 배경 (해당되는 경우)
        
            각 항목에 대해 가능한 한 구체적인 세부 사항 (이름, 숫자, 날짜 등)을 포함해주세요. 
            그러나 전체 요약은 간결해야 하며, 각 항목은 1-3문장으로 제한해주세요.
        
            파일링 내용:
            {text}
        
            요약:"""
        )
        chain = prompt | llm | StrOutputParser()

        # 배치 처리를 위한 입력 준비
        inputs = [
            {"text": filing_data['content'], "form_type": form_type}
            for form_type, filing_data in filings.items()
            if isinstance(filing_data, dict) and 'content' in filing_data
        ]

        summaries = chain.batch(inputs)

        return {
            form_type: summary
            for (form_type, filing_data), summary in zip(filings.items(), summaries)
            if isinstance(filing_data, dict) and 'content' in filing_data
        }

    # 파일링 수집 및 요약
    summaries = summarize_filings(results)

    return summaries

# %%
get_latest_filing_content({"ticker":'NVDA'})
# Out:
# /var/folders/1x/st3vh8xs6715dcgqc1gk2hhh0000gn/T/ipykernel_67813/3169507120.py:1: LangChainDeprecationWarning: The method `BaseTool.__call__` was deprecated in langchain-core 0.1.47 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   get_latest_filing_content({"ticker":'NVDA'})
# {'8-K': '**NVIDIA Corporation 8-K Filing Summary (March 3, 2025)**\n\n1. **보고 이벤트의 성격**: NVIDIA는 2026 회계연도 변동 보상 계획(Variable Compensation Plan)을 채택하였으며, 이는 특정 기업 성과 목표 달성에 따라 임원들이 현금 보상을 받을 수 있는 기회를 제공합니다.\n\n2. **해당 이벤트의 주요 내용**: 2026 계획은 2026 회계연도 매출 달성을 기준으로 성과 목표를 설정하였으며, 임원들은 보상 지급일에 직원으로 남아 있어야 보상을 받을 수 있습니다. 주요 임원들의 목표 보상 기회는 다음과 같습니다:\n   - **Jen-Hsun Huang** (CEO): $3,000,000 (200%의 기본 급여)\n   - **Colette M. Kress** (CFO): $300,000 (33%)\n   - **Ajay K. Puri** (EVP, Worldwide Field Operations): $650,000 (68%)\n   - **Debora Shoquist** (EVP, Operations): $250,000 (29%)\n   - **Timothy S. Teter** (EVP, General Counsel): $250,000 (29%)\n\n3. **회사에 미치는 잠재적 영향**: 이 변동 보상 계획은 임원들의 성과를 유도하여 회사의 매출 증가에 기여할 것으로 예상되며, 이는 주주 가치를 높이는 데 긍정적인 영향을 미칠 수 있습니다.\n\n4. **관련된 중요 인물의 배경**: Jen-Hsun Huang은 NVIDIA의 창립자이자 CEO로, 회사의 전략적 방향을 이끌고 있으며, Colette M. Kress는 CFO로서 재무 전략을 담당하고 있습니다. Ajay K. Puri, Debora Shoquist, Timothy S. Teter는 각각의 분야에서 중요한 역할을 수행하고 있습니다. \n\n이 보고서는 NVIDIA의 2026 회계연도 변동 보상 계획에 대한 중요한 세부 사항을 제공하며, 회사의 경영진 보상 구조와 성과 기반 보상 시스템을 강조합니다.',
#  '10-K': '### NVIDIA Corporation 10-K 요약 (2025년 1월 26일 종료)\n\n#### 주요 재무 지표\n- **매출**: $130.5 billion (전년 대비 114% 증가)\n- **순이익**: $72.9 billion (전년 대비 145% 증가)\n- **주당순이익 (EPS)**: $2.94 (전년 대비 147% 증가)\n- **총 자산**: $111.6 billion\n- **총 부채**: $32.3 billion\n\n#### 사업 개요 및 주요 제품/서비스\nNVIDIA는 가속 컴퓨팅을 선도하며, 데이터 센터, 게임, 전문 시각화 및 자동차 시장을 포함한 다양한 분야에서 GPU 및 AI 솔루션을 제공합니다. 주요 제품으로는 **Hopper 아키텍처**와 **GeForce RTX 40 시리즈**가 있습니다.\n\n#### 주요 시장 및 고객\nNVIDIA의 고객은 데이터 센터, 게임, 전문 시각화 및 자동차 산업의 기업들로, 주요 고객사로는 **Direct Customer A, B, C**가 있으며, 이들은 각각 12%, 11%, 11%의 매출을 차지합니다. 전체 매출의 53%는 미국 외 지역에서 발생했습니다.\n\n#### 경영진의 주요 변동 사항\n- **Jen-Hsun Huang**: CEO\n- **Colette M. Kress**: CFO\n- **Ajay K. Puri**: EVP, Worldwide Field Operations\n- **Debora Shoquist**: EVP, Operations\n- **Timothy S. Teter**: EVP, General Counsel\n\n#### 중요한 위험 요인\n- **경쟁 심화**: AMD, Intel 등과의 치열한 경쟁.\n- **공급망 리스크**: 반도체 공급 부족 및 제조 리드 타임 증가.\n- **규제 리스크**: 미국의 수출 통제 및 국제 무역 규제 변화.\n- **사이버 보안**: 데이터 유출 및 사이버 공격의 위험.\n\n#### 향후 전략 및 전망\nNVIDIA는 AI 및 가속 컴퓨팅 플랫폼의 리더십을 강화하고, 데이터 센터 및 클라우드 서비스의 성장을 지속할 계획입니다. 또한, 새로운 제품 아키텍처인 **Blackwell**을 통해 시장 점유율을 확대할 예정입니다.\n\n#### 주요 소송 또는 규제 이슈\n- **증권 관련 소송**: NVIDIA는 과거의 채널 재고 및 암호화폐 채굴에 대한 잘못된 진술로 인해 소송을 받고 있으며, 이 사건은 현재 진행 중입니다.\n- **수출 통제**: 미국 정부의 수출 통제로 인해 중국 및 기타 국가에 대한 제품 판매에 제한이 있을 수 있습니다.\n\n이 보고서는 NVIDIA의 재무 상태와 운영 성과를 종합적으로 보여주며, 향후 전략과 위험 요소를 명확히 하고 있습니다.',
#  '10-Q': '### NVIDIA Corporation 10-Q Summary for the Quarter Ended October 27, 2024\n\n#### 주요 재무 지표\n- **매출**: $35,082 million (전년 동기 대비 94% 증가, 전 분기 대비 17% 증가)\n- **순이익**: $19,309 million (전년 동기 대비 109% 증가)\n- **주당순이익 (EPS)**: $0.78 (전년 동기 대비 111% 증가)\n- **총 자산**: $96,013 million (2024년 1월 28일 대비 증가)\n- **현금 및 현금성 자산**: $9,107 million\n\n#### 사업 개요 및 주요 제품/서비스\nNVIDIA는 데이터 센터, 게임, 전문 시각화 및 자동차 분야에서 GPU 및 AI 솔루션을 제공하는 선도적인 기업입니다. 주요 제품으로는 Hopper 아키텍처 기반의 데이터 센터 시스템과 GeForce RTX 40 시리즈 GPU가 있습니다.\n\n#### 주요 시장 및 고객\n- **데이터 센터**: 매출의 약 50%가 클라우드 서비스 제공업체에서 발생.\n- **게임**: GeForce GPU 판매 증가.\n- **자동차**: 자율주행 플랫폼의 수요 증가.\n\n#### 경영진의 주요 변동 사항\n특별한 경영진 변동 사항은 보고되지 않았습니다.\n\n#### 중요한 위험 요인\n- **수요 예측의 불확실성**: 고객 수요 예측의 부정확성으로 인한 재고 과잉 또는 부족.\n- **수출 통제**: 미국 정부의 수출 통제가 NVIDIA의 제품 판매에 미치는 영향.\n- **글로벌 공급망 문제**: 공급망의 복잡성과 공급 제약으로 인한 생산 차질 가능성.\n\n#### 향후 전략 및 전망\nNVIDIA는 데이터 센터 및 AI 솔루션에 대한 수요 증가에 대응하기 위해 공급망을 확장하고 있으며, Blackwell 아키텍처의 생산을 시작할 예정입니다. 또한, 새로운 제품 출시 주기를 연간으로 설정하여 시장의 변화에 신속하게 대응할 계획입니다.\n\n#### 주요 소송 또는 규제 이슈\nNVIDIA는 여러 소송에 연루되어 있으며, 특히 증권 관련 소송이 진행 중입니다. 이 소송은 NVIDIA의 경영진이 잘못된 정보를 제공했다는 주장과 관련이 있습니다.\n\n### 결론\nNVIDIA는 강력한 매출 성장과 순이익 증가를 기록하며, 데이터 센터 및 AI 솔루션 시장에서의 입지를 강화하고 있습니다. 그러나 수요 예측의 불확실성과 수출 통제 등의 위험 요소가 존재하며, 향후 전략적으로 이러한 문제를 해결해 나갈 필요가 있습니다.'}

# %% [markdown]
# ### **경쟁사 관련 증권 뉴스 가져오기**

# %%
import time

@tool
def collect_competitor_news(ticker, news_count):
    """주어진 티커 관련 회사들의 최신 증권 뉴스를 수집합니다.
    Args:
        ticker (str): The company ticker.
        news_count (int): number how many news will we collect. Basic Number is 10.
    Returns:
        Dict(List): 
        A Dict of Competitors' news, each containing recent news articles' description.

    Example:
        response = competitor_news("ticker":"AAPL", "news_count":10)
        response = {"MSFT": ["US stock....", "MS invests on...", ...]}
    """
    related_companies = polygon_client.get_related_companies(ticker)
    competitors = [i.ticker for i in related_companies]
    
    competitors_news = {}
    for c in competitors:
        time.sleep(30)
        api_key = os.environ["POLYGON_API_KEY"]
        api_url = f"https://api.polygon.io/v2/reference/news?ticker={c}&order=desc&limit={news_count}&sort=published_utc&apiKey={api_key}&published_utc=2023-01-01"
        result = requests.get(api_url).json()
        print(result)
        competitors_news[c] = [i['description'] for i in result['results']]
    return competitors_news

# %%
collect_competitor_news.run({"ticker":"NVDA", "news_count":3})
# Out:
# {'results': [], 'status': 'OK', 'request_id': '8818d65ce7972b070107db547ee97b7f'}
# {'results': [{'id': 'TOq9N9-WDAVjb2yiTm4YLYXx61jo4LuRJOeUiBDOZEk', 'publisher': {'name': 'MarketWatch', 'homepage_url': 'https://www.marketwatch.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/marketwatch.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/marketwatch.ico'}, 'title': 'Is this a good — or bad — time for me to ask for a raise? The job market is strong, but layoffs are on the rise', 'author': 'MarketWatch', 'published_utc': '2023-01-01T21:05:00Z', 'article_url': 'https://www.marketwatch.com/story/the-u-s-job-market-is-strong-but-layoffs-are-on-the-rise-is-this-a-good-or-bad-time-to-ask-for-a-raise-11670007812', 'tickers': ['WBD', 'TSLA', 'META'], 'amp_url': 'https://www.marketwatch.com/amp/story/the-u-s-job-market-is-strong-but-layoffs-are-on-the-rise-is-this-a-good-or-bad-time-to-ask-for-a-raise-11670007812', 'image_url': 'https://images.mktw.net/im-677478/social', 'description': 'The Labor Department reported 263,000 new jobs in November, while the  U.S. unemployment rate held steady at 3.7%.'}, {'id': 'uTFAkKCw0lpErKTRNiuHNxZxx2w_cFtQEmKYBSUcZJ4', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': 'Can Nvidia Help Walmart and Target Solve Their Theft Problem?', 'author': 'newsfeedback@fool.com (Nicholas Rossolillo)', 'published_utc': '2023-01-01T18:11:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/can-nvidia-help-walmart-and-target-solve-theft/', 'tickers': ['NVDA', 'WMT', 'TGT', 'META', 'AMZN', 'SHOP'], 'image_url': 'https://g.foolcdn.com/editorial/images/714808/store-pickup-curbside-pickup-e-commerce.jpg', 'description': '"Shrinkage" refers to organized theft at a retail store, but it shrinks more than just a retailer\'s inventory.', 'keywords': ['investing']}, {'id': '_LTIM5xuD2Jk0YzGYKyL24Gx1h0ijp6PnFxgjHl8-bI', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': "Nasdaq Bear Market: 1 Supercharged Growth Stock to Buy Like There's No Tomorrow", 'author': 'newsfeedback@fool.com (Danny Vena)', 'published_utc': '2023-01-01T13:52:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/nasdaq-bear-market-1-supercharged-growth-stock-to/', 'tickers': ['TTD', 'META', 'GOOGL', 'IT', 'FORR', 'GOOG'], 'image_url': 'https://g.foolcdn.com/editorial/images/714569/couple-wearing-wool-socks-watching-television-in-the-winter.jpg', 'description': "This disruptive company has been mauled by 2022's bear market, but it's setting the stage for a massive rebound.", 'keywords': ['investing']}], 'status': 'OK', 'request_id': 'be22f85efa1dc62602cad361f8d93000', 'count': 3, 'next_url': 'https://api.polygon.io/v2/reference/news?cursor=YXA9MjAyMy0wMS0wMVQxMyUzQTUyJTNBMDBaJmFzPV9MVElNNXh1RDJKazBZekdZS3lMMjRHeDFoMGlqcDZQbkZ4Z2pIbDgtYkkmbGltaXQ9MyZvcmRlcj1kZXNjZW5kaW5nJnB1Ymxpc2hlZF91dGM9MjAyMy0wMS0wMSZ0aWNrZXI9TUVUQQ'}
# {'results': [{'id': 'OG6EFT2zQGmJ2hetinN6wh3dgvEsq5ftWmOTv072CzA', 'publisher': {'name': 'Seeking Alpha', 'homepage_url': 'https://seekingalpha.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/seekingalpha.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/seekingalpha.ico'}, 'title': 'Amazon: 100 Top Growth Stocks, Ranked', 'author': 'Blue Harbinger', 'published_utc': '2023-01-01T16:00:00Z', 'article_url': 'https://seekingalpha.com/article/4567216-amazon-100-top-growth-stocks-ranked', 'tickers': ['ASML', 'BABA', 'COUP', 'CRM', 'CRWD', 'DDOG', 'ENPH', 'EPAM', 'FTNT', 'GOOG', 'GOOGL', 'MELI', 'MSFT', 'NET', 'NOW', 'PAYC', 'PLTR', 'SE', 'SHOP', 'SNOW', 'SPLK', 'SQ', 'TTD', 'AMZN'], 'image_url': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1355263724/image_1355263724.jpg?io=getty-c-w750', 'description': 'Amazon shares were down nearly 50% in 2022, despite the fact that revenues kept growing rapidly. Learn more about AMZN stock and growth stocks in general.'}, {'id': '_LTIM5xuD2Jk0YzGYKyL24Gx1h0ijp6PnFxgjHl8-bI', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': "Nasdaq Bear Market: 1 Supercharged Growth Stock to Buy Like There's No Tomorrow", 'author': 'newsfeedback@fool.com (Danny Vena)', 'published_utc': '2023-01-01T13:52:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/nasdaq-bear-market-1-supercharged-growth-stock-to/', 'tickers': ['TTD', 'META', 'GOOGL', 'IT', 'FORR', 'GOOG'], 'image_url': 'https://g.foolcdn.com/editorial/images/714569/couple-wearing-wool-socks-watching-television-in-the-winter.jpg', 'description': "This disruptive company has been mauled by 2022's bear market, but it's setting the stage for a massive rebound.", 'keywords': ['investing']}, {'id': 'VfN5xNUzocpVp1chf9uICMOkPMtSajr6dJov3z6EZzM', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': '3 Software Stocks That Could Bring a Brighter New Year', 'author': 'newsfeedback@fool.com (Will Healy, Justin Pope, and Jake Lerch)', 'published_utc': '2023-01-01T13:00:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/3-software-stocks-bring-brighter-new-year/', 'tickers': ['GOOG', 'GOOGL', 'MSFT', 'AMZN', 'FVRR', 'TOST'], 'image_url': 'https://g.foolcdn.com/editorial/images/714553/excited-looking-at-phone-outside.jpg', 'description': 'After a difficult 2022, these stocks could experience a turnaround in 2023.', 'keywords': ['investing']}], 'status': 'OK', 'request_id': '52355123f28a38536dbfd3f3ec3c3d33', 'count': 3, 'next_url': 'https://api.polygon.io/v2/reference/news?cursor=YXA9MjAyMy0wMS0wMVQxMyUzQTAwJTNBMDBaJmFzPVZmTjV4TlV6b2NwVnAxY2hmOXVJQ01Pa1BNdFNhanI2ZEpvdjN6NkVaek0mbGltaXQ9MyZvcmRlcj1kZXNjZW5kaW5nJnB1Ymxpc2hlZF91dGM9MjAyMy0wMS0wMSZ0aWNrZXI9R09PR0w'}
# {'results': [{'id': 'TOq9N9-WDAVjb2yiTm4YLYXx61jo4LuRJOeUiBDOZEk', 'publisher': {'name': 'MarketWatch', 'homepage_url': 'https://www.marketwatch.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/marketwatch.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/marketwatch.ico'}, 'title': 'Is this a good — or bad — time for me to ask for a raise? The job market is strong, but layoffs are on the rise', 'author': 'MarketWatch', 'published_utc': '2023-01-01T21:05:00Z', 'article_url': 'https://www.marketwatch.com/story/the-u-s-job-market-is-strong-but-layoffs-are-on-the-rise-is-this-a-good-or-bad-time-to-ask-for-a-raise-11670007812', 'tickers': ['WBD', 'TSLA', 'META'], 'amp_url': 'https://www.marketwatch.com/amp/story/the-u-s-job-market-is-strong-but-layoffs-are-on-the-rise-is-this-a-good-or-bad-time-to-ask-for-a-raise-11670007812', 'image_url': 'https://images.mktw.net/im-677478/social', 'description': 'The Labor Department reported 263,000 new jobs in November, while the  U.S. unemployment rate held steady at 3.7%.'}, {'id': 'K2lpF9Thgjn0gj_v1IPCmaUxE4tJAdrLjoIgC4IEvRA', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': 'Where Does Tesla Stock Go in 2023?', 'author': 'newsfeedback@fool.com (Travis Hoium and Jon Quast)', 'published_utc': '2023-01-01T13:15:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/where-do-tesla-and-rivian-go-in-2023/', 'tickers': ['TSLA', 'F', 'TM', 'GM', 'RIVN'], 'image_url': 'https://g.foolcdn.com/editorial/images/713816/youtube-thumbnails-91.png', 'description': 'Tesla had a terrible 2022 and 2023 might not be any better.', 'keywords': ['investing']}], 'status': 'OK', 'request_id': 'e45ed3568fe7dfa78fb8b37459d919f1', 'count': 2}
# {'results': [{'id': '4SGiy0vLDAZUig0Pgp9gzzkDhmTQSlwo_aOjrPBZvTo', 'publisher': {'name': 'MarketWatch', 'homepage_url': 'https://www.marketwatch.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/marketwatch.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/marketwatch.ico'}, 'title': "‘Our social skills are like any other muscle’: Are you socializing with coworkers for the first time since the pandemic? It's time to strategize.", 'author': 'MarketWatch', 'published_utc': '2023-01-01T20:53:00Z', 'article_url': 'https://www.marketwatch.com/story/our-social-skills-are-like-any-other-muscle-are-you-attending-your-first-office-party-of-the-pandemic-its-time-to-strategize-11672240712', 'tickers': ['ZM', 'GOOG'], 'amp_url': 'https://www.marketwatch.com/amp/story/our-social-skills-are-like-any-other-muscle-are-you-attending-your-first-office-party-of-the-pandemic-its-time-to-strategize-11672240712', 'image_url': 'https://images.mktw.net/im-686543/social', 'description': 'Whether you’re new to the workplace or rusty after two years of remote work, this ultimate guide to office parties should help you.'}, {'id': 'OG6EFT2zQGmJ2hetinN6wh3dgvEsq5ftWmOTv072CzA', 'publisher': {'name': 'Seeking Alpha', 'homepage_url': 'https://seekingalpha.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/seekingalpha.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/seekingalpha.ico'}, 'title': 'Amazon: 100 Top Growth Stocks, Ranked', 'author': 'Blue Harbinger', 'published_utc': '2023-01-01T16:00:00Z', 'article_url': 'https://seekingalpha.com/article/4567216-amazon-100-top-growth-stocks-ranked', 'tickers': ['ASML', 'BABA', 'COUP', 'CRM', 'CRWD', 'DDOG', 'ENPH', 'EPAM', 'FTNT', 'GOOG', 'GOOGL', 'MELI', 'MSFT', 'NET', 'NOW', 'PAYC', 'PLTR', 'SE', 'SHOP', 'SNOW', 'SPLK', 'SQ', 'TTD', 'AMZN'], 'image_url': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1355263724/image_1355263724.jpg?io=getty-c-w750', 'description': 'Amazon shares were down nearly 50% in 2022, despite the fact that revenues kept growing rapidly. Learn more about AMZN stock and growth stocks in general.'}, {'id': '_LTIM5xuD2Jk0YzGYKyL24Gx1h0ijp6PnFxgjHl8-bI', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': "Nasdaq Bear Market: 1 Supercharged Growth Stock to Buy Like There's No Tomorrow", 'author': 'newsfeedback@fool.com (Danny Vena)', 'published_utc': '2023-01-01T13:52:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/nasdaq-bear-market-1-supercharged-growth-stock-to/', 'tickers': ['TTD', 'META', 'GOOGL', 'IT', 'FORR', 'GOOG'], 'image_url': 'https://g.foolcdn.com/editorial/images/714569/couple-wearing-wool-socks-watching-television-in-the-winter.jpg', 'description': "This disruptive company has been mauled by 2022's bear market, but it's setting the stage for a massive rebound.", 'keywords': ['investing']}], 'status': 'OK', 'request_id': '04ec3abeb16474567daca2714a534542', 'count': 3, 'next_url': 'https://api.polygon.io/v2/reference/news?cursor=YXA9MjAyMy0wMS0wMVQxMyUzQTUyJTNBMDBaJmFzPV9MVElNNXh1RDJKazBZekdZS3lMMjRHeDFoMGlqcDZQbkZ4Z2pIbDgtYkkmbGltaXQ9MyZvcmRlcj1kZXNjZW5kaW5nJnB1Ymxpc2hlZF91dGM9MjAyMy0wMS0wMSZ0aWNrZXI9R09PRw'}
# {'results': [{'id': 'OG6EFT2zQGmJ2hetinN6wh3dgvEsq5ftWmOTv072CzA', 'publisher': {'name': 'Seeking Alpha', 'homepage_url': 'https://seekingalpha.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/seekingalpha.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/seekingalpha.ico'}, 'title': 'Amazon: 100 Top Growth Stocks, Ranked', 'author': 'Blue Harbinger', 'published_utc': '2023-01-01T16:00:00Z', 'article_url': 'https://seekingalpha.com/article/4567216-amazon-100-top-growth-stocks-ranked', 'tickers': ['ASML', 'BABA', 'COUP', 'CRM', 'CRWD', 'DDOG', 'ENPH', 'EPAM', 'FTNT', 'GOOG', 'GOOGL', 'MELI', 'MSFT', 'NET', 'NOW', 'PAYC', 'PLTR', 'SE', 'SHOP', 'SNOW', 'SPLK', 'SQ', 'TTD', 'AMZN'], 'image_url': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1355263724/image_1355263724.jpg?io=getty-c-w750', 'description': 'Amazon shares were down nearly 50% in 2022, despite the fact that revenues kept growing rapidly. Learn more about AMZN stock and growth stocks in general.'}, {'id': 'VfN5xNUzocpVp1chf9uICMOkPMtSajr6dJov3z6EZzM', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': '3 Software Stocks That Could Bring a Brighter New Year', 'author': 'newsfeedback@fool.com (Will Healy, Justin Pope, and Jake Lerch)', 'published_utc': '2023-01-01T13:00:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/3-software-stocks-bring-brighter-new-year/', 'tickers': ['GOOG', 'GOOGL', 'MSFT', 'AMZN', 'FVRR', 'TOST'], 'image_url': 'https://g.foolcdn.com/editorial/images/714553/excited-looking-at-phone-outside.jpg', 'description': 'After a difficult 2022, these stocks could experience a turnaround in 2023.', 'keywords': ['investing']}, {'id': 'HvrZmYcW9m94mi2OSwsn16rPYkf7HW7a6S65oVl5mrQ', 'publisher': {'name': 'Seeking Alpha', 'homepage_url': 'https://seekingalpha.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/seekingalpha.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/seekingalpha.ico'}, 'title': 'Microsoft 2023: History Suggests A Rebound', 'author': 'Tradevestor', 'published_utc': '2023-01-01T12:32:13Z', 'article_url': 'https://seekingalpha.com/article/4567248-microsoft-2023-history-suggests-rebound', 'tickers': ['MSFT'], 'image_url': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1402827477/image_1402827477.jpg?io=getty-c-w750', 'description': 'History suggests Microsoft stock is likely to rebound in 2023. Click here to read the details from the past and why MSFT could outperform in 2023.'}], 'status': 'OK', 'request_id': '5564028699a68596b78fe44ad1e9a0b1', 'count': 3, 'next_url': 'https://api.polygon.io/v2/reference/news?cursor=YXA9MjAyMy0wMS0wMVQxMiUzQTMyJTNBMTNaJmFzPUh2clptWWNXOW05NG1pMk9Td3NuMTZyUFlrZjdIVzdhNlM2NW9WbDVtclEmbGltaXQ9MyZvcmRlcj1kZXNjZW5kaW5nJnB1Ymxpc2hlZF91dGM9MjAyMy0wMS0wMSZ0aWNrZXI9TVNGVA'}
# {'results': [{'id': 'uTFAkKCw0lpErKTRNiuHNxZxx2w_cFtQEmKYBSUcZJ4', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': 'Can Nvidia Help Walmart and Target Solve Their Theft Problem?', 'author': 'newsfeedback@fool.com (Nicholas Rossolillo)', 'published_utc': '2023-01-01T18:11:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/can-nvidia-help-walmart-and-target-solve-theft/', 'tickers': ['NVDA', 'WMT', 'TGT', 'META', 'AMZN', 'SHOP'], 'image_url': 'https://g.foolcdn.com/editorial/images/714808/store-pickup-curbside-pickup-e-commerce.jpg', 'description': '"Shrinkage" refers to organized theft at a retail store, but it shrinks more than just a retailer\'s inventory.', 'keywords': ['investing']}, {'id': 'nF34o3imAHY-k9fW2znWhyjSJ8ZDUXL0rwc-skl-KFc', 'publisher': {'name': 'MarketWatch', 'homepage_url': 'https://www.marketwatch.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/marketwatch.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/marketwatch.ico'}, 'title': "Here's everything coming to Amazon's Prime Video in January 2023", 'author': 'MarketWatch', 'published_utc': '2023-01-01T18:08:00Z', 'article_url': 'https://www.marketwatch.com/story/heres-everything-coming-to-amazons-prime-video-in-january-2023-11671404938', 'tickers': ['AMZN'], 'amp_url': 'https://www.marketwatch.com/amp/story/heres-everything-coming-to-amazons-prime-video-in-january-2023-11671404938', 'image_url': 'https://images.mktw.net/im-688072/social', 'description': "Get ready for the final season of 'Hunters,' a Jennifer Lopez-Josh Duhamel rom-com and much more"}, {'id': 'OG6EFT2zQGmJ2hetinN6wh3dgvEsq5ftWmOTv072CzA', 'publisher': {'name': 'Seeking Alpha', 'homepage_url': 'https://seekingalpha.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/seekingalpha.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/seekingalpha.ico'}, 'title': 'Amazon: 100 Top Growth Stocks, Ranked', 'author': 'Blue Harbinger', 'published_utc': '2023-01-01T16:00:00Z', 'article_url': 'https://seekingalpha.com/article/4567216-amazon-100-top-growth-stocks-ranked', 'tickers': ['ASML', 'BABA', 'COUP', 'CRM', 'CRWD', 'DDOG', 'ENPH', 'EPAM', 'FTNT', 'GOOG', 'GOOGL', 'MELI', 'MSFT', 'NET', 'NOW', 'PAYC', 'PLTR', 'SE', 'SHOP', 'SNOW', 'SPLK', 'SQ', 'TTD', 'AMZN'], 'image_url': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1355263724/image_1355263724.jpg?io=getty-c-w750', 'description': 'Amazon shares were down nearly 50% in 2022, despite the fact that revenues kept growing rapidly. Learn more about AMZN stock and growth stocks in general.'}], 'status': 'OK', 'request_id': '61408b6ecfd6c096a4e0b6d6a736084f', 'count': 3, 'next_url': 'https://api.polygon.io/v2/reference/news?cursor=YXA9MjAyMy0wMS0wMVQxNiUzQTAwJTNBMDBaJmFzPU9HNkVGVDJ6UUdtSjJoZXRpbk42d2gzZGd2RXNxNWZ0V21PVHYwNzJDekEmbGltaXQ9MyZvcmRlcj1kZXNjZW5kaW5nJnB1Ymxpc2hlZF91dGM9MjAyMy0wMS0wMSZ0aWNrZXI9QU1aTg'}
# {'results': [{'id': 'XpBo0RCkBUSo-p6HZjngXH-lyj3_b_WwTEDC0q1x8QU', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': 'Down 28% in 2022, Is Apple Stock a Buy for 2023?', 'author': 'newsfeedback@fool.com (Parkev Tatevosian, CFA)', 'published_utc': '2023-01-01T11:00:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/down-28-in-2022-is-apple-stock-a-buy-for-2023/', 'tickers': ['AAPL'], 'image_url': 'https://g.foolcdn.com/editorial/images/714930/talk-to-us-79.jpg', 'description': "Apple's sales were slowed by supply chain constraints in 2022.", 'keywords': ['investing']}, {'id': 'E775YlJ7TBZfE59GEFM2DpXR42UYeeC0Ti_tsouVBv4', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': "80% of Warren Buffett's Portfolio Is Invested in These 7 Stocks as 2023 Begins", 'author': 'newsfeedback@fool.com (Keith Speights)', 'published_utc': '2023-01-01T10:50:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/80-of-warren-buffetts-portfolio-is-invested-in-the/', 'tickers': ['AAPL', 'BRK.A', 'BRK.B', 'BAC', 'KO', 'CVX', 'AXP', 'OXY', 'KHC'], 'image_url': 'https://g.foolcdn.com/editorial/images/714220/warren-buffett-tmf-photo.jpg', 'description': 'Two of these stocks were especially big winners for Buffett in 2022.', 'keywords': ['investing']}, {'id': 'pKGX2UQdI-sOlv9k4IRmZJDr3dr_OLD_BLpAgbyBJTU', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': '2 Beaten-Down Warren Buffett Stocks to Buy in 2023', 'author': 'newsfeedback@fool.com (Cory Renauer)', 'published_utc': '2023-01-01T10:13:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/beaten-down-warren-buffett-stocks-to-buy-in-2023/', 'tickers': ['PARA', 'BRK.A', 'BRK.B', 'AAPL'], 'image_url': 'https://g.foolcdn.com/editorial/images/714821/warren-buffett-fool-may-2015.jpg', 'description': "These are high-conviction stocks for the Oracle of Omaha but they're trading at knocked-down prices.", 'keywords': ['investing']}], 'status': 'OK', 'request_id': 'c5413eb8ff16a9a8e2d78740cdcc7bbf', 'count': 3, 'next_url': 'https://api.polygon.io/v2/reference/news?cursor=YXA9MjAyMy0wMS0wMVQxMCUzQTEzJTNBMDBaJmFzPXBLR1gyVVFkSS1zT2x2OWs0SVJtWkpEcjNkcl9PTERfQkxwQWdieUJKVFUmbGltaXQ9MyZvcmRlcj1kZXNjZW5kaW5nJnB1Ymxpc2hlZF91dGM9MjAyMy0wMS0wMSZ0aWNrZXI9QUFQTA'}
# {'results': [{'id': 'CQ78KM5Ub4hBkC5_U7iYlx_1FnYJUdWElxT7GWgwJlI', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': '2 High-Yield Dividend Tech Stocks to Buy for 2023', 'author': 'newsfeedback@fool.com (Timothy Green)', 'published_utc': '2023-01-01T14:10:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/2-high-yield-dividend-tech-stocks-to-buy-for-2023/', 'tickers': ['INTC', 'T'], 'image_url': 'https://g.foolcdn.com/editorial/images/714867/happy-businessman-and-flying-dollar-banknotes-dividend-returns.jpg', 'description': 'These battered tech stocks offer dividend yields more than triple that of the S&P 500.', 'keywords': ['investing']}, {'id': '1GPuJIrlVBZ4T-CX24VI9zAPKFvUmS7SRMzo5VT64cA', 'publisher': {'name': 'The Motley Fool', 'homepage_url': 'https://www.fool.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/themotleyfool.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/themotleyfool.ico'}, 'title': 'Taiwan Semi vs. Intel Stock: Which Is the Better Buy Now?', 'author': 'newsfeedback@fool.com (Jose Najarro and Nicholas Rossolillo)', 'published_utc': '2023-01-01T14:00:00Z', 'article_url': 'https://www.fool.com/investing/2023/01/01/taiwan-semi-vs-intel-stock-which-is-the-better-buy/', 'tickers': ['INTC', 'TSM'], 'image_url': 'https://g.foolcdn.com/editorial/images/714851/copy-of-jose-najarro-30.png', 'description': 'These two semiconductor investors are back to discuss which chip giant they would choose.', 'keywords': ['investing']}, {'id': 'QYxaWHZrmZ4m4KgU-iyck6mQrzz026M2Lj_KEyCx_vg', 'publisher': {'name': 'Seeking Alpha', 'homepage_url': 'https://seekingalpha.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/seekingalpha.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/seekingalpha.ico'}, 'title': '2023 Dividend Growth Portfolio Review And Look Ahead', 'author': 'Wyo Investments', 'published_utc': '2023-01-01T06:30:54Z', 'article_url': 'https://seekingalpha.com/article/4567219-2023-dividend-growth-portfolio-review-and-look-ahead', 'tickers': ['ABBV', 'ABT', 'ADP', 'AFL', 'AMGN', 'AMP', 'AOS', 'APD', 'AVGO', 'BBY', 'BLK', 'BMY', 'BX', 'CAH', 'CINF', 'CME', 'COP', 'CVS', 'DHIL', 'DUK', 'EPD', 'FBIN', 'HD', 'HON', 'ICE', 'INTC', 'JNJ', 'LADR', 'LMT', 'LOW', 'MBC', 'MDT', 'MO', 'MSA', 'MSFT', 'NNN', 'O', 'OHI', 'PEP', 'PM', 'PRU', 'PSX', 'SBUX', 'SJM', 'SNA', 'SPG', 'TXN', 'UL', 'V', 'WBA', 'AAPL'], 'image_url': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1397555970/image_1397555970.jpg?io=getty-c-w750', 'description': 'I review my current holdings and sectors in the portfolio and how it has changed over the years. See my income projections for 2023 and potential pitfalls.'}], 'status': 'OK', 'request_id': '3e9e8322b8236c0d860c1e26fafd8c1f', 'count': 3}
# {'results': [{'id': 'QYxaWHZrmZ4m4KgU-iyck6mQrzz026M2Lj_KEyCx_vg', 'publisher': {'name': 'Seeking Alpha', 'homepage_url': 'https://seekingalpha.com/', 'logo_url': 'https://s3.polygon.io/public/assets/news/logos/seekingalpha.svg', 'favicon_url': 'https://s3.polygon.io/public/assets/news/favicons/seekingalpha.ico'}, 'title': '2023 Dividend Growth Portfolio Review And Look Ahead', 'author': 'Wyo Investments', 'published_utc': '2023-01-01T06:30:54Z', 'article_url': 'https://seekingalpha.com/article/4567219-2023-dividend-growth-portfolio-review-and-look-ahead', 'tickers': ['ABBV', 'ABT', 'ADP', 'AFL', 'AMGN', 'AMP', 'AOS', 'APD', 'AVGO', 'BBY', 'BLK', 'BMY', 'BX', 'CAH', 'CINF', 'CME', 'COP', 'CVS', 'DHIL', 'DUK', 'EPD', 'FBIN', 'HD', 'HON', 'ICE', 'INTC', 'JNJ', 'LADR', 'LMT', 'LOW', 'MBC', 'MDT', 'MO', 'MSA', 'MSFT', 'NNN', 'O', 'OHI', 'PEP', 'PM', 'PRU', 'PSX', 'SBUX', 'SJM', 'SNA', 'SPG', 'TXN', 'UL', 'V', 'WBA', 'AAPL'], 'image_url': 'https://static.seekingalpha.com/cdn/s3/uploads/getty_images/1397555970/image_1397555970.jpg?io=getty-c-w750', 'description': 'I review my current holdings and sectors in the portfolio and how it has changed over the years. See my income projections for 2023 and potential pitfalls.'}], 'status': 'OK', 'request_id': '18ae26dfb4b2163808642133031dc635', 'count': 1}
# {'AMD': [],
#  'META': ['The Labor Department reported 263,000 new jobs in November, while the  U.S. unemployment rate held steady at 3.7%.',
#   '"Shrinkage" refers to organized theft at a retail store, but it shrinks more than just a retailer\'s inventory.',
#   "This disruptive company has been mauled by 2022's bear market, but it's setting the stage for a massive rebound."],
#  'GOOGL': ['Amazon shares were down nearly 50% in 2022, despite the fact that revenues kept growing rapidly. Learn more about AMZN stock and growth stocks in general.',
#   "This disruptive company has been mauled by 2022's bear market, but it's setting the stage for a massive rebound.",
#   'After a difficult 2022, these stocks could experience a turnaround in 2023.'],
#  'TSLA': ['The Labor Department reported 263,000 new jobs in November, while the  U.S. unemployment rate held steady at 3.7%.',
#   'Tesla had a terrible 2022 and 2023 might not be any better.'],
#  'GOOG': ['Whether you’re new to the workplace or rusty after two years of remote work, this ultimate guide to office parties should help you.',
#   'Amazon shares were down nearly 50% in 2022, despite the fact that revenues kept growing rapidly. Learn more about AMZN stock and growth stocks in general.',
#   "This disruptive company has been mauled by 2022's bear market, but it's setting the stage for a massive rebound."],
#  'MSFT': ['Amazon shares were down nearly 50% in 2022, despite the fact that revenues kept growing rapidly. Learn more about AMZN stock and growth stocks in general.',
#   'After a difficult 2022, these stocks could experience a turnaround in 2023.',
#   'History suggests Microsoft stock is likely to rebound in 2023. Click here to read the details from the past and why MSFT could outperform in 2023.'],
#  'AMZN': ['"Shrinkage" refers to organized theft at a retail store, but it shrinks more than just a retailer\'s inventory.',
#   "Get ready for the final season of 'Hunters,' a Jennifer Lopez-Josh Duhamel rom-com and much more",
#   'Amazon shares were down nearly 50% in 2022, despite the fact that revenues kept growing rapidly. Learn more about AMZN stock and growth stocks in general.'],
#  'AAPL': ["Apple's sales were slowed by supply chain constraints in 2022.",
#   'Two of these stocks were especially big winners for Buffett in 2022.',
#   "These are high-conviction stocks for the Oracle of Omaha but they're trading at knocked-down prices."],
#  'INTC': ['These battered tech stocks offer dividend yields more than triple that of the S&P 500.',
#   'These two semiconductor investors are back to discuss which chip giant they would choose.',
#   'I review my current holdings and sectors in the portfolio and how it has changed over the years. See my income projections for 2023 and potential pitfalls.'],
#  'AVGO': ['I review my current holdings and sectors in the portfolio and how it has changed over the years. See my income projections for 2023 and potential pitfalls.']}

# %%
@tool
def collect_company_news(company_name: str) -> str:
    """Collect recent news for the given company."""
    search_results = tavily_client.search(query=f"recent news about {company_name}", days=7)
    return f"Collected news and market data for {company_name}: \n{search_results}"

@tool
def collect_market_news(sector: str) -> str:
    """Collect recent market data for the given company's sector."""
    search_results = tavily_client.search(query=f"{sector} industry news", days=7)
    return f"Collected news and market data for {sector}: {search_results}"

@tool
def scrape_webpages(urls: List[str]) -> str:
    """Scrape the provided web pages for detailed information."""
    loader = WebBaseLoader(urls)
    docs = loader.load()
    return "\n\n".join(
        [f'<Document name="{doc.metadata.get("title", "")}">\n{doc.page_content}\n</Document>'
         for doc in docs]
    )
