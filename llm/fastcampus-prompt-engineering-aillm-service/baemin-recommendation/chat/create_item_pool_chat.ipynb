# %% [markdown]
# # 기존 서비스 --> 대화형 추천으로 변경
# 1. 추천풀 및 메뉴 벡터 DB 생성 <-- 해당 노트북
# 2. 사용자 발화 기반 개인화 추천 API 개발
# 3. 데모 수정: 대화형 UI 및 Function Calling, 멀티턴 대화 기능 추가
# - OpenAI Function Calling 복습
#
# ## 추천풀 및 메뉴 벡터 DB 생성
# ### Restaurant Info 정보 가져오기
#
# - 현재 포맷

# %%
'''
"1367138" : {
    "restaurant": "88곱창-분당점",
    "url": "https://www.yogiyo.co.kr/mobile/#/1367138/",
    "reviews": [
        {"menus": "menu1,menu2,menu3", "review_text": "맛있음"},
        {"menus": "menu1,menu3,menu5", "review_text": "굿"}
    ]
}
'''

# %%
import os
import urllib

import certifi
from pymongo.server_api import ServerApi
from pymongo import MongoClient

from dotenv import load_dotenv

load_dotenv("../res/.env")

uri = os.environ['MONGODB_URI']
client = MongoClient(uri, server_api=ServerApi('1'), tlsCAFile=certifi.where())
db = client.restaurant_db
collection = db.restaurant_info

# restaurants_info = list(collection.find({}, {'_id': False}))
restaurants_info = list(collection.find({}))
restaurants_info
# Out:
# [{'_id': '1031899',
#   'restaurant': '버거킹-판교유스페이스점',
#   'reviews': [{'menus': '통새우와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),와퍼/1',
#     'review_text': '든든하게 먹었습니다아'},
#    {'menus': '통새우와퍼세트/1(사이드변경(프렌치프라이L),음료변경(스프라이트L)),롱치킨버거/1',
#     'review_text': '매번 자주 시켜먹는 곳인데 말이 필요 없습니다..너무 맛있습니다.'},
#    {'menus': '몬스터와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(스프라이트R)),몬스터와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),통새우와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '회사에서 사진촬영이 금지여서 대충 찍었지만 맛있게 잘 먹었습니다'},
#    {'menus': '치킨킹 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(스프라이트 제로R)),와퍼/1',
#     'review_text': '사진엔 없지만 기본와퍼도 맛있네요'},
#    {'menus': '콰트로치즈와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),통새우와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),통새우와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(아이스아메리카노))',
#     'review_text': '주문한 버거 3개 중 2개만 와서 누락분 다시 보내달라고 연락한 지 30분이 넘었는데, 최대한 빨리 보내준다더니 아직도 안 오고 있는 상황 허허허...와이프와 아이는 이미 다 먹었고, 저는 감튀만 먹고 있습니다. 이제 벨이 울리네요..'},
#    {'menus': '불끈버거 맥시멈 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(아이스아메리카노)),콘샐러드/1',
#     'review_text': '잘 먹었습니다.'},
#    {'menus': '통새우와퍼세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라R（변경 없음 ）)),치즈와퍼/1',
#     'review_text': '맛있게먹었습니다~~'},
#    {'menus': '콰트로치즈와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(스프라이트 제로R)),롱치킨버거/1',
#     'review_text': '롱치킨버거는 너겟같은 패티네용'},
#    {'menus': '베이컨치즈와퍼 세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라 제로L)),와퍼/1',
#     'review_text': '가끔 먹는데 트러플 없어진거같네요\n아쉬움'},
#    {'menus': '몬스터와퍼/1,롱치킨버거/1,몬스터 주니어/1', 'review_text': '믿고먹는 버거킹 잘 먹었습니다'},
#    {'menus': '콰트로치즈 풀드비프 와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R)),블랙바비큐콰트로치즈와퍼 세트/2(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R))',
#     'review_text': '벌거킹 꽈뚜로찌주깨맜있써여'},
#    {'menus': '콰트로치즈 풀드비프 와퍼/2', 'review_text': '맛있네요 생각보다 더 맛있어서 좋았습니다'},
#    {'menus': '베이컨치즈와퍼 세트/1(사이드변경(너겟킹 4조각),음료변경(코카-콜라L)),콰트로치즈와퍼 세트/1(사이드변경(너겟킹 4조각),음료변경(코카-콜라R（변경 없음 ）)),몬스터와퍼세트/1(사이드변경(너겟킹 4조각),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '버거킹 못버려.마시슴'},
#    {'menus': '불맛 더블치즈앤베이컨버거 세트/3(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '치킨킹BLT 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),치즈버거/1',
#     'review_text': '치즈버거작지만맛있네요~~'},
#    {'menus': '블랙바비큐와퍼 세트/1(사이드변경(프렌치프라이L),음료변경(스프라이트 제로R)),비프불고기버거/1',
#     'review_text': '맛있는 버거 빠른 배송 감사합니다'},
#    {'menus': '스파이시 풀드비프 와퍼 세트/1(버거(스파이시 풀드비프 와퍼),사이드변경(쉐이킹프라이 매콤치즈),음료변경(코카-콜라 제로R)),너겟킹4조각/1,매콤치즈 시즈닝/5',
#     'review_text': '회사원이시라면 저녁에 시키지 마세요 햄버거 기다리다 야근하셔야됩니다. 늦는다고 연락한통 안주시는게 더 열받네요. 목욜에 햄버거땜에 야근해야되는게 쌍욕나옵니다 진심.'},
#    {'menus': '몬스터 주니어 세트/1(버거(몬스터 주니어),사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),몬스터와퍼세트/1(버거(몬스터와퍼),사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라L))',
#     'review_text': '배송이 뭔 두시간이 걸립니까..원래 안그랬는데\n오늘은 좀 심했습니다..'},
#    {'menus': '리얼 어니언링R/1,오리지널스 화이트 페타 싱글 세트/1(버거(오리지널스 화이트 페타 싱글),사이드변경(프렌치프라이L),음료변경(아이스아메리카노))',
#     'review_text': '잘 먹었습니다.'},
#    {'menus': '트러플머쉬룸와퍼 세트/1(버거(트러플머쉬룸와퍼),사이드변경(리얼 어니언링 교환),음료변경(기라델리 딥초코 핫 교환)),비프불고기버거/1,너겟킹4조각/1',
#     'review_text': '와퍼는 트러플향이 1도 안나고 핫초코는 맹탕임 비추'},
#    {'menus': '베이컨치즈와퍼 세트/1(버거(베이컨치즈와퍼),사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R))',
#     'review_text': '버거킹이 감튀가 맛잇네요ㅎㅎ햄버거도 요청사항도 잘 들어주시고 맛있었어요~'},
#    {'menus': '몬스터와퍼세트/1(버거(몬스터와퍼),사이드변경(코울슬로),음료변경(코카-콜라 제로L))',
#     'review_text': '코카콜라 제로를 주문했는데 그냥 콜라가 왔어요'},
#    {'menus': '통새우와퍼세트/1(버거(통새우와퍼),사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라L)),21치즈스틱/1,리얼 어니언링R/1',
#     'review_text': '버거킹 감튀좋아해서 자주시켜먹는데 양이 많아서 항상 다 못먹네요 요번에 어니언링과함께 시켰는데 진짜 영파만 튀긴듯'},
#    {'menus': '비프라구 팩/1(버거선택1(클래식 비프라구 와퍼),버거선택2(베이컨치즈 비프라구 와퍼),사이드1(프렌치프라이R),사이드2(리얼어니언링),음료변경(코카-콜라 제로R),음료변경2(코카-콜라 제로R)),콰트로치즈 비프라구 팩/1(버거선택1(콰트로치즈 비프라구 와퍼),버거선택2(클래식 비프라구 와퍼),사이드1(프렌치프라이R),사이드2(리얼어니언링),음료변경(코카-콜라 제로R),음료변경2(코카-콜라 제로R)),콰트로치즈와퍼/1',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '베이컨치즈와퍼 세트/2(버거(베이컨치즈와퍼),사이드변경(프렌치프라이R - 기본),음료변경(아이스아메리카노)),바삭킹2조각/1,코코넛슈림프3조각＋스위트칠리소스/1',
#     'review_text': '와퍼 세트의 품목 두 개가 배송 누락되었는데 고객센터와 통화 후 빠른 재배송 되었어요.'},
#    {'menus': '롱치킨버거/1,코코넛슈림프6조각＋스위트칠리소스/1,코울슬로/1,콘샐러드/1,불고기와퍼주니어/1,몬스터와퍼세트/1(버거(몬스터와퍼),사이드변경(프렌치프라이L),음료변경(코카-콜라 제로L))',
#     'review_text': '맛있게 먹었습니다!'},
#    {'menus': '와퍼주니어세트/1(버거(와퍼주니어),사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),디아블로소스/1,바삭킹4조각/1',
#     'review_text': '배달 예정 시간보다 20분쯤 늦게 받았네요.\n콜라 얼음 다 녹았고, 햄버거나 바삭킹은 다 식음.'},
#    {'menus': '통새우와퍼세트/1(버거(통새우와퍼),사이드변경(리얼 어니언링 교환),음료변경(코카-콜라 제로L))',
#     'review_text': '맛있게 잘 먹었습니당~'},
#    {'menus': '콰트로치즈 비프라구 와퍼 세트/1(버거(콰트로치즈 비프라구 와퍼),사이드변경(프렌치프라이L),음료변경(스프라이트 제로R)),바삭킹2조각/1',
#     'review_text': '케찹이 아까운 신지 어제는 3개 달라고 말씀드려도 1개 주시더니 오늘은 아예 없네요ㅎㅎ 이제 알겠으니 안시키겠습니다.'},
#    {'menus': '콰트로치즈 비프라구 와퍼 세트/1(버거(콰트로치즈 비프라구 와퍼),사이드변경(프렌치프라이L),음료변경(스프라이트 제로R)),바삭킹2조각/1',
#     'review_text': '케찹 3개 요청했는데 안왔어요ㅠ 그래도 신제품 맛있네요.'},
#    {'menus': '몬스터와퍼세트/1(버거(몬스터와퍼),사이드변경(프렌치프라이L),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '맛이랑 양 모두 좋았어요\n근데 배달이 1시간 걸린건 아쉬웠어요'},
#    {'menus': '불맛 더블치즈앤베이컨버거 세트/1(버거(불맛 더블치즈앤베이컨버거),사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),불맛 더블치즈앤베이컨버거 세트/2(버거(불맛 더블치즈앤베이컨버거),사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R)),콰트로치즈와퍼 세트/1(버거(콰트로치즈와퍼),사이드변경(너겟킹 4조각),음료변경(코카-콜라 제로L)),너겟킹4조각/1,스윗어니언 시즈닝/1',
#     'review_text': '맛있어요 그런데 배달 에정 시간이랑 실제 도착 시간이랑 너무 다릅니다\n예상 시간보다 한시간 일찍 오심'},
#    {'menus': '클래식 비프라구 와퍼 세트/1(버거(클래식 비프라구 와퍼),사이드변경(리얼 어니언링 교환),음료변경(코카-콜라 제로L))',
#     'review_text': '맛있게 잘먹었습니다 ㅎㅎ 다음에 또 시킬게요'},
#    {'menus': '베이컨치즈 비프라구 와퍼 세트/1(버거(베이컨치즈 비프라구 와퍼),사이드변경(너겟킹 4조각),음료변경(코카-콜라 제로R))',
#     'review_text': '아주 맛이가 있고 !'},
#    {'menus': '통새우와퍼세트/1(버거(통새우와퍼),사이드변경(리얼 어니언링 교환),음료변경(코카-콜라 제로L))',
#     'review_text': '맛있게 잘 먹었습니당'},
#    {'menus': '베이컨치즈 비프라구 와퍼 세트/1(버거(베이컨치즈 비프라구 와퍼),사이드변경(프렌치프라이R - 기본),음료변경(아이스아메리카노)),와퍼/1',
#     'review_text': '잘 먹었습니다.'},
#    {'menus': '클래식 비프라구 와퍼 세트/1(버거(클래식 비프라구 와퍼),사이드변경(프렌치프라이R - 기본),음료변경(스프라이트 제로L)),더블비프불고기버거 세트/1(버거(더블비프불고기버거),사이드변경(프렌치프라이L),음료변경(코카-콜라L)),통새우 슈림프버거 세트/1(버거(통새우 슈림프버거),사이드변경(치즈스틱),음료변경(아메리카노 교환)),베이컨치즈 비프라구 와퍼 세트/1(버거(베이컨치즈 비프라구 와퍼),사이드변경(치즈스틱),음료변경(코카-콜라 제로R))',
#     'review_text': '맛있었습니다. 잘먹었습니다.'},
#    {'menus': '베이컨치즈 비프라구 와퍼/2,베이컨치즈 비프라구 와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(스프라이트 제로L)),베이컨치즈 비프라구 와퍼 세트/1(사이드변경(코울슬로),음료변경(코카-콜라 제로L)),베이컨치즈 비프라구 와퍼 세트/1(사이드변경(너겟킹 4조각),음료변경(코카-콜라 제로R)),베이컨치즈 비프라구 와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로L)),통새우 슈림프버거/1,롱치킨버거/1,너겟킹10조각/1',
#     'review_text': '버거버거킹이다 버거어 킹!!'},
#    {'menus': '오리지널스 아보카도 잭 싱글 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R)),블랙바비큐콰트로치즈와퍼 단품/1,롱치킨버거/1,통새우 슈림프버거/1,와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R)),콰트로치즈와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(스프라이트 제로L)),콰트로치즈와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로L))',
#     'review_text': '버거버거버거킹!!!! 버거킹은 킹'},
#    {'menus': '블랙바비큐콰트로치즈와퍼 세트/2(사이드변경(코울슬로),음료변경(코카-콜라 제로L))',
#     'review_text': '맛있게 잘 먹었습니다 !'},
#    {'menus': '치즈와퍼주니어세트/1(사이드변경(너겟킹 4조각),음료변경(미닛메이드 오렌지)),오리지널스 아보카도 잭 싱글 세트/1(사이드변경(쉐이킹프라이 구운갈릭),음료변경(코카-콜라 제로L))',
#     'review_text': '맛있게 잘먹었어요~'},
#    {'menus': '와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),롱치킨버거/1,불고기와퍼주니어세트/1(사이드변경(프렌치프라이R - 기본),음료변경(스프라이트R))',
#     'review_text': '잘먹었습니다 ~~~'},
#    {'menus': '블랙바비큐콰트로치즈와퍼 세트/1(사이드변경(코울슬로),음료변경(코카-콜라 제로L)),블랙바비큐콰트로치즈와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R)),불맛 더블치즈버거 세트/1(사이드변경(치즈스틱),음료변경(코카-콜라 제로L)),크리미모짜볼5조각/1',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '블랙바비큐콰트로치즈와퍼 세트/1(사이드변경(치즈스틱),음료변경(코카-콜라 제로R)),블랙바비큐콰트로치즈와퍼 세트/1(사이드변경(코울슬로),음료변경(코카-콜라 제로R))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '와퍼주니어세트/2(사이드변경(프렌치프라이L),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '와퍼주니어 맛있게 잘 먹었습니다.'},
#    {'menus': '통모짜와퍼 세트\t/1(사이드변경(프렌치프라이R - 기본),음료변경(스프라이트 제로L)),치즈버거/1',
#     'review_text': '\u200d'},
#    {'menus': '몬스터와퍼/1,코코넛슈림프6조각＋스위트칠리소스/1', 'review_text': '잘 먹었어요 감사합니다'},
#    {'menus': '블랙바비큐와퍼 세트/1(사이드변경(너겟킹 4조각),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '맛있게 먹었습니다.'},
#    {'menus': '불고기와퍼주니어세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),와퍼/1',
#     'review_text': '배송빠르게 와서 좋았어요!!'},
#    {'menus': '큐브 스테이크 와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '콰트로치즈와퍼주니어세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),갈릭불고기와퍼/1,너겟킹10조각/1',
#     'review_text': '맛있습니딘 정말. 굿굿굿'},
#    {'menus': '콰트로치즈와퍼 세트/3(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로L)),콰트로치즈와퍼/1',
#     'review_text': '항상 시켜먹는 버거 새트인데 맛있어요'},
#    {'menus': '큐브 스테이크 올인팩（2인）/1(음료변경(스프라이트R),음료변경2(스프라이트R))',
#     'review_text': '맛있어요! 배달도 오래 걸린다고 써있었지만 총알 배송이었어요'},
#    {'menus': '치즈와퍼세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라L)),바삭킹2조각/1,아메리카노/1',
#     'review_text': '배달빠르고 따뜻하게 잘먹었어요'},
#    {'menus': '불고기와퍼세트/2(사이드변경(콘샐러드),음료변경(코카-콜라 제로R)),불고기와퍼세트/2(사이드변경(프렌치프라이R - 기본),음료변경(아이스아메리카노)),와퍼주니어/1',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '블랙바비큐콰트로치즈와퍼 세트/1(사이드변경(코울슬로),음료변경(코카-콜라 제로R)),블랙바비큐콰트로치즈와퍼 세트/1(사이드변경(쉐이킹프라이 스윗어니언),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '맛있게 잘 먹었습니다.\n빨대는 따로 안 챙겨주나보네요..'},
#    {'menus': '불고기와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R)),불고기와퍼세트/1(사이드변경(코울슬로),음료변경(아이스아메리카노)),불고기와퍼세트/2(사이드변경(콘샐러드),음료변경(아이스아메리카노))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '몬스터와퍼세트/1(사이드변경(코울슬로),음료변경(코카-콜라 제로L)),스파이시 큐브 스테이크 와퍼/1',
#     'review_text': '몬스터와퍼셋트 주문했는데, 코울슬로는 없네요. 매장 전화도 안받고‥ 어쩔 수 없이 글 올리느라 버거는 다 식고‥ 기분이 좀 안좋네요'},
#    {'menus': '불고기와퍼세트/2(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R)),불고기와퍼세트/1(사이드변경(코울슬로),음료변경(아이스아메리카노)),불고기와퍼세트/1(사이드변경(콘샐러드),음료변경(아이스아메리카노))',
#     'review_text': '맛있어요\n또 주문할게요'},
#    {'menus': '통새우와퍼/1,치즈와퍼주니어/1,프렌치프라이 （R）/1',
#     'review_text': '맛있어요 감자튀김도 넘나 똥똥하고 좋은것'},
#    {'menus': '큐브 스테이크 와퍼 세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라R（변경 없음 ）)),바삭킹2조각/1,콰트로치즈와퍼주니어세트/1(사이드변경(콘샐러드),음료변경(코카-콜라 제로R)),콰트로치즈와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R))',
#     'review_text': '점심시간에 배달 빨리 와서 좋습니다\n맛은 버거킹맛'},
#    {'menus': '통새우 슈림프버거 세트/1(사이드변경(치즈스틱),음료변경(코카-콜라 제로R)),트러플치즈프라이/1',
#     'review_text': '사이드 변경 치즈스틱이 안왔네여.'},
#    {'menus': '블양양 맥시멈3 세트/1(사이드변경(너겟킹 4조각),음료변경(기라델리 딥초코 핫 교환))',
#     'review_text': '만족합니다 ^^ 잘먹엇어요'},
#    {'menus': '몬스터와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),롱치킨버거세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),더블비프불고기버거/1,슈림프버거/1',
#     'review_text': '배달도 빠르고 맜있게 잘먹었습니다'},
#    {'menus': '더블비프불고기버거/1,콰트로치즈와퍼 세트/1(사이드변경(치즈프라이 교환),음료변경(코카-콜라L))',
#     'review_text': '양파 빼달랬는데 안빼줘서 먹지도못했네요'},
#    {'menus': '와퍼/1,와퍼주니어/1,코코넛슈림프3조각＋스위트칠리소스/1,콘샐러드/1',
#     'review_text': '먹느라 사진을 못찍었네요^^ 채소도 신선하고 맛있었어요!'},
#    {'menus': '프렌치프라이 （L）/1,갈릭불고기와퍼/1,와퍼/1', 'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '불고기와퍼세트/1(사이드변경(코울슬로),음료변경(코카-콜라 제로R)),불고기와퍼세트/2(사이드변경(콘샐러드),음료변경(아이스아메리카노)),트러플머쉬룸와퍼주니어 세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라 제로R))',
#     'review_text': '미리 못찍고 다 먹어버렸네요\n마침 콜라 안마시고 냉장고에 넣어뒀던거 찍었어요\n버거킹 너무 맛나요'},
#    {'menus': '불고기와퍼세트/1(사이드변경(너겟킹 4조각),음료변경(코카-콜라R（변경 없음 ）)),몬스터와퍼/1,불고기와퍼/1,너겟킹 8조각/1',
#     'review_text': '배달시간이.앱으로 체크할때마다 늘어나는.괴이한 현상을 목격했네요.45분정도가 60분이 넘어 70분대 와서 못먹고 나갈뻔했어요.(처음 예상시간안에 왔으면 여유로운 저녁이었겠죠)\n몬스터버거의 매운쏘스가 한곳에 몰려서.\n밍밍하게 먹다가 아린맛 몰려먹으니 자극적이고 맛이. 왜. 이런생각 들더라고요.\n이런 맛없는 버거는 처음이었어요.\n나머지 불고기와퍼는 괜찮았고요.'},
#    {'menus': '블랙바비큐콰트로치즈와퍼 세트/1(사이드변경(너겟킹 4조각),음료변경(아이스초코 교환)),바삭킹2조각/1,디아블로소스/1',
#     'review_text': '맛있게 잘먹었어요ㅎㅎ'},
#    {'menus': '불고기와퍼세트/2(사이드변경(코울슬로),음료변경(아이스아메리카노)),불고기와퍼세트/2(사이드변경(프렌치프라이R - 기본),음료변경(스프라이트R))',
#     'review_text': '맛나게 잘먹었습니다'},
#    {'menus': '블랙바비큐와퍼 세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라L)),더블비프불고기버거/1',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '몬스터X 세트/1(사이드변경(쉐이킹프라이 구운갈릭),음료변경(코카-콜라 제로L)),롱치킨버거/1',
#     'review_text': '양념감자 300원 더주고 주문했는데 소스안줌 ㅅㄱ'},
#    {'menus': '블랙바비큐와퍼 세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라R（변경 없음 ）)),콰트로치즈와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로R)),트러플머쉬룸와퍼주니어 세트/1(사이드변경(콘샐러드),음료변경(코카-콜라 제로R))',
#     'review_text': '배달이 예상시간보다 조금 늦었어요\n맛은 잇엇어요'},
#    {'menus': '몬스터와퍼세트/1(사이드변경(프렌치프라이L),음료변경(레몬라임맛 제로 교환)),통새우와퍼세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라 제로L))',
#     'review_text': '맛은 있지만 배달이 너무 너무 너무 느려요'},
#    {'menus': '오리지널스 페퍼잭 싱글 세트/1(사이드변경(어니언링),음료변경(코카-콜라 제로L)),너겟킹4조각/1',
#     'review_text': '맛있어요 와퍼같으면서 아닌느낌'},
#    {'menus': '콰트로치즈와퍼주니어세트/1(음료변경(스프라이트R),사이드변경(프렌치프라이R - 기본)),콰트로치즈와퍼 세트/1(음료변경(코카-콜라R（변경 없음 ）),사이드변경(프렌치프라이R - 기본))',
#     'review_text': '늘 맛있는 버거킹 짱'},
#    {'menus': '블랙바비큐와퍼 세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라 제로L))',
#     'review_text': '괜찮은 온도, 괜찮은 맛, 빠른 배달'},
#    {'menus': '블랙바비큐콰트로치즈와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '맛잇게 먹었습니다!'},
#    {'menus': '오리지널스 페퍼잭 싱글 세트/1(사이드변경(해쉬브라운 교환),음료변경(아이스초코 교환)),너겟킹4조각/1',
#     'review_text': '맛있게 잘 먹엇어요 ^^'},
#    {'menus': '치즈와퍼주니어세트/1(사이드변경(프렌치프라이R - 기본),음료변경(스프라이트R)),치즈와퍼주니어세트/1(사이드변경(프렌치프라이R - 기본),음료변경(미닛메이드 오렌지)),너겟킹 8조각/1,21치즈스틱/1',
#     'review_text': '배송도 잘 왔고 맛있었어요~'},
#    {'menus': '블랙바비큐콰트로치즈와퍼 세트/1(사이드변경(너겟킹 4조각),음료변경(레몬라임맛 제로 교환)),치즈와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '블랙바비큐콰트로치즈와퍼 단품/1,몬스터와퍼/1,코울슬로/2',
#     'review_text': '맛있어요 ~~~\n배달도 빠르고 좋아요 ~~'},
#    {'menus': '콰트로치즈와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),통새우와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),치즈와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '맛이야 검증됐고, 배달이 넘 늦었어요. 한시간 걸렸네요'},
#    {'menus': '통새우와퍼세트/1(사이드변경(치즈스틱),음료변경(아이스아메리카노)),바삭킹4조각/1',
#     'review_text': '할인 이벤트 자주 해서 좋네요'},
#    {'menus': '치즈와퍼세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라R（변경 없음 ）)),불고기와퍼세트/1(사이드변경(너겟킹 4조각),음료변경(아이스아메리카노)),통새우와퍼/1,너겟킹4조각/1',
#     'review_text': '배달 빠르고, 양은 역시 혜자롭게 많았어요.^^\n커피를 늦게 마실꺼라 얼음 빼달라 요청드렸는데\n아아로 주문해 황당하셨을텐데,\n센스있게 보내주셨어요.'},
#    {'menus': 'HELL로 디아블로 와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),갈릭불고기와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),바비큐치킨버거 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),몬스터와퍼/1',
#     'review_text': '디아블로 매워서 맛있네요. 잘먹었습니다!!!'},
#    {'menus': '블랙바비큐콰트로치즈와퍼 세트/1(사이드변경(코울슬로),음료변경(코카-콜라 제로R)),갈릭불고기와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(레몬라임맛 제로 교환)),콘샐러드/1,스위트칠리소스/1,구운갈릭 시즈닝/1,스윗어니언 시즈닝/1',
#     'review_text': '맛있게 잘 먹었습니다 -!'},
#    {'menus': '치즈와퍼주니어/1,롱치킨버거/1,너겟킹 8조각/1,디아블로소스/1',
#     'review_text': '맛있게 잘 먹었습니다!'},
#    {'menus': '통새우와퍼세트/1(사이드변경(어니언링),음료변경(코카-콜라R（변경 없음 ）)),통새우 슈림프버거 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '식어서 본맛은 좀 부족했지만 버거는 버거킹 이죠~~~^^'},
#    {'menus': '몬스터와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(레몬라임맛 제로 교환)),너겟킹4조각/1',
#     'review_text': '언제먹어도 맛있어요 버거킹'},
#    {'menus': '이나리우스 스페셜 세트/1,크리미모짜볼10조각/1',
#     'review_text': '이벤트 때문에 디아블로 세트 먹었는데.. 배달은 해당이 안되나 보네요. 카드가 안들어있네오. 배달 시켜 드실분들 참고 하세용.'},
#    {'menus': '치즈와퍼주니어세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라R（변경 없음 ）)),더블비프불고기버거 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로L)),바삭킹2조각/1,바삭킹4조각/1',
#     'review_text': '따뜻하게 빠르게 와서 잘 먹었습니다.'},
#    {'menus': '콰트로치즈와퍼 세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라L))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '치즈와퍼세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로L)),어니언링/1,바삭킹2조각/1',
#     'review_text': '맛있게 잘 먹었습니다.'},
#    {'menus': '콰트로 맥시멈…이하생략 4 세트/1(사이드변경(콘샐러드),음료변경(아메리카노 교환))',
#     'review_text': '빠른 배송 감사합니다!'},
#    {'menus': '콰트로 맥시멈…이하생략 4 세트/1(사이드변경(쉐이킹프라이 매콤치즈),음료변경(코카-콜라L))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '스모키 바비큐 X 세트/1(사이드변경(코울슬로),음료변경(코카-콜라 제로R)),치즈 프라이/1',
#     'review_text': '맛있게 먹었습니다.'},
#    {'menus': '치킨킹 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(코카-콜라 제로L)),바삭킹4조각/1',
#     'review_text': '맛있게 잘 먹었습니다.'},
#    {'menus': '몬스터X 세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라L)),디아블로소스/1',
#     'review_text': '배달도 빠르고 맛있어요'},
#    {'menus': '롱치킨버거세트/1(사이드변경(어니언링),음료변경(코카-콜라L)),바삭킹4조각/1,디아블로소스/1',
#     'review_text': '배달도 빠르고 맛있습니다'},
#    {'menus': '스태커 2 와퍼 세트/1(사이드변경(어니언링),음료변경(아메리카노 교환)),바삭킹4조각/1',
#     'review_text': '빠른 배달과 함께 맛있습니다'},
#    {'menus': '통새우와퍼주니어세트/1(사이드변경(치즈스틱),음료변경(코카-콜라R（변경 없음 ）)),몬스터와퍼/2,불고기와퍼주니어/1,프렌치프라이 （L）/1',
#     'review_text': '보통입니다 ~ 가끔 시켜먹어요 ~'},
#    {'menus': '불고기와퍼주니어세트/1(사이드변경(어니언링),음료변경(코카-콜라R（변경 없음 ）)),비프불고기버거 세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라R（변경 없음 ）))',
#     'review_text': '배달도 빠르고 맛있게 잘먹었어요'},
#    {'menus': '와퍼 세트/1(사이드변경(쉐이킹프라이 매콤치즈),음료변경(코카-콜라R（변경 없음 ）)),바삭킹4조각/1',
#     'review_text': '맛있게잘먹었어요귯ㅎㅎ'},
#    {'menus': '콰트로치즈와퍼 세트/1(사이드변경(콘샐러드),음료변경(아이스초코 교환)),할라피뇨와퍼/1',
#     'review_text': '할라피뇨버거 굿입니다♡ 안짜고 담백하게맛있네요'},
#    {'menus': '콰트로치즈와퍼 세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라 제로L)),와퍼/1',
#     'review_text': '버거킹 맛나게 잘먹구 있습니다\n화이팅'},
#    {'menus': '불고기와퍼세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라 제로L)),치킨킹BLT 세트/1(사이드변경(프렌치프라이L),음료변경(코카-콜라 제로R))',
#     'review_text': '문을 노크 하지도 않고 그냥 두고 가서 다 식었네요'},
#    {'menus': '와퍼 세트/1(사이드변경(프렌치프라이R - 기본),음료변경(스프라이트R)),와퍼 세트/1(사이드변경(어니언링),음료변경(스프라이트R))',
#     'review_text': '주문한지 2시간만에 음식 도착\n당연히 음식은 다식었고 음료는 얼음이 녹아서  밋밋해짐'},
#    {'menus': '콰트로치즈와퍼주니어/1,블랙 어니언 치킨버거/1,너겟킹4조각/1',
#     'review_text': '맛있게 먹음 \n배달 빨라서 좋았어요'}],
#   'url': 'https://www.yogiyo.co.kr/mobile/#/1031899/'},
#  {'_id': '1194514',
#   'restaurant': '덮스타',
#   'reviews': [{'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(양파（고기랑 같이 볶음）)),계란후라이/1',
#     'review_text': '리뷰는 역시 거짓말을 하지않는다,, 아주 흡족한 식사였습니다'},
#    {'menus': '간장 닭고기덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(마늘슬라이스추가),덮밥 토핑 추가선택(양파（고기랑 같이 볶음）))',
#     'review_text': '제가 너무 좋아하는 덮스타! 오랜만에 주문해서 죄송해요… 배달 주문 자체를 한동안 쉬었어요 ㅠㅠ 맛있게 보내주셔서 감사히 잘 먹었습니다 :)'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '맛있네요.\n고기도 많고 든든한 한끼네요.'},
#    {'menus': '고추장 닭고기덮밥 （RICE BOWL） 도시락/1', 'review_text': '맛있네요 감사합니다'},
#    {'menus': '매콤달달 제육덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X)),계란후라이/1',
#     'review_text': '제육덮밥도 넘 맛있습니다!'},
#    {'menus': '고추장 닭고기덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(양파（고기랑 같이 볶음）))',
#     'review_text': '정말 맛있었습니다 최고에요!!!'},
#    {'menus': '매콤달달 제육덮밥 （RICE BOWL） 도시락/1,토마토 파스타 （PASTA） 도시락/1(파스타 토핑 버섯 추가선택(버섯O))',
#     'review_text': '늘 사진 찍는 것도 잊고\n먹기 바쁜, 제 입맛에는 아주 맛난 덥스타입니다 ㅎㅎ'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(양파（고기랑 같이 볶음）))',
#     'review_text': '쵝오입니다! 맛있고 빠르고, 담엔 계란후라이도 주문할래요!'},
#    {'menus': '갈비맛 목살（고기만 600g）/1(고기 토핑 추가선택(마요네즈X),고기 토핑 추가선택(양파（고기랑 같이 볶음）)),공기밥/1',
#     'review_text': '재주문 4번째~~~'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1',
#     'review_text': '배달도 빠르고 맛있어요.ᐟ 혼자라 1인분 집이 잘 없어서 부담스러웠는데 여긴 그런 점에서 너무 좋고 감사해요 ㅠㅠ'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/2,＋고추장 목살덮밥（한정판매）＋/1,간장 닭고기덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '맛있게 잘먹었습니다!'},
#    {'menus': '간장 닭고기덮밥 （RICE BOWL） 도시락/1', 'review_text': '맛있어요 집밥먹는 느낌'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(양파（고기랑 같이 볶음）))',
#     'review_text': '양 많고 맛있어서 고기 먹고 싶을 때마다 주문합니다~!\n고추장 목살에 양파 꼭 추가 하세요!'},
#    {'menus': '고추장 닭고기덮밥 （RICE BOWL） 도시락/1', 'review_text': '정말 맛있게 잘먹었습니다'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1',
#     'review_text': '처음시키고 한입먹었는데 진짜 맛있네요ㄷㄷ\n숨은 맛집찾았습니다'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1', 'review_text': '맛있게 잘먹었습니다!'},
#    {'menus': '메인1＋사이드1＋음료1/1(메인 택1(고추장 목살덮밥),토핑 추가(덮밥 곱빼기 추가 （덮밥메뉴만）),사이드 메뉴 택1(날치알 주먹밥),음료 택1(펩시 캔 245ml)),간장 닭고기덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(덮밥 곱빼기))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1,맛감자튀김/1',
#     'review_text': '판교와서 처음 배달 시켰는데 진짜 맛있어요!'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(마늘슬라이스추가),덮밥 토핑 추가선택(양파（고기랑 같이 볶음）)),＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(양파（고기랑 같이 볶음）)),＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(김치X),덮밥 토핑 추가선택(양파（고기랑 같이 볶음）))',
#     'review_text': '감사합니다 잘먹었습니다 번창하세요'},
#    {'menus': '메인1＋사이드1＋음료1/1(메인 택1(갈비맛 목살덮밥),토핑 추가(덮밥 곱빼기 추가 （덮밥메뉴만）),토핑 추가(고기（100g）추가 （덮밥메뉴만）),사이드 메뉴 택1(한 입 핫도그 5개),음료 택1(아이스 아메리카노))',
#     'review_text': '맛있어요 다음에 또 시킬께요'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1', 'review_text': '항상 맛있게 먹고 있어요'},
#    {'menus': '로제 파스타 （PASTA） 도시락/1(파스타 토핑 버섯 추가선택(버섯O),파스타 토핑 추가선택(피클X))',
#     'review_text': '집에 밥밖에 없었는데 맛있게 먹었습니다.'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(마늘슬라이스추가)),마요네즈소스/1,계란후라이/1',
#     'review_text': '간도 적당하고 고기도 맛잇어요'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(양파（고기랑 같이 볶음）))',
#     'review_text': '맛있게 먹었습니다ㅎㅎ'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(고기추가（100g）))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/2,계란후라이/1,복숭아 아이스티/1',
#     'review_text': '맛있게 잘 먹었습니다.!!'},
#    {'menus': '로제 파스타 （PASTA） 도시락/1(파스타 토핑 버섯 추가선택(버섯O)),갈비맛 목살덮밥 （RICE BOWL） 도시락/1,장국/1,계란후라이/1',
#     'review_text': '맛잇게 잘 먹엇습니다!!!'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1', 'review_text': '💯💯💯💯💯💯'},
#    {'menus': '공기밥/3,＋고추장 목살（고기만 600g）/1(고기 토핑 추가선택(고기추가（100g）))',
#     'review_text': '정말 맛있어요!'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(고기추가（100g）))',
#     'review_text': '맛있어요 양념도 적당하고 극추천드려요!!!\n\n배달이 늦는 건 좀 아쉬워요ㅠ\n\n너무 늦더라구요ㅠ'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(덮밥 곱빼기))',
#     'review_text': '항상 맛있게 잘 먹고있습니다~'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(김치X))',
#     'review_text': '맛있어요 1인분씩 배달도 가능하고 좋아요.\n부추가 좀 적은건 아쉽네요'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1', 'review_text': '양도 많고 맛있게 잘먹었습니다~'},
#    {'menus': '매콤달달 제육덮밥 （RICE BOWL） 도시락/1', 'review_text': '양도 적당하고 맛있어요~'},
#    {'menus': '매콤달달 제육덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '맛있게잘먹었습니다 다음에 또 시킬께요'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1', 'review_text': '오랜만에 시켜서 맛잇게 먹엇음'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1',
#     'review_text': '배고프면 생각나는 덮스타 덥밥..오늘도 게눈감추듯 싹~ 잘먹겠습니다!'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(김치X))',
#     'review_text': '너무 맛있고 배불러요!! 고기 먹고 싶을 때 최고!'},
#    {'menus': '간장 닭고기덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(김치X))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '메인1＋사이드1＋음료1/1(메인 택1(크림 파스타),토핑 추가(베이컨 추가 （파스타메뉴만）),토핑 추가(버섯 추가 （파스타메뉴만）),빼주세요~(피클 X （파스타 메뉴）),사이드 메뉴 택1(맛감자튀김),음료 택1(아이스 바닐라라떼))',
#     'review_text': '맛있어요. 아바라 강추'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(마늘슬라이스추가),덮밥 토핑 추가선택(양파（고기랑 같이 볶음）),덮밥 토핑 추가선택(덮밥 곱빼기),덮밥 토핑 추가선택(고기추가（100g）))',
#     'review_text': '맛있게 잘 먹었습니다.'},
#    {'menus': '메인1＋사이드1＋음료1/1(메인 택1(고추장 목살덮밥),사이드 메뉴 택1(맛감자튀김),음료 택1(펩시 캔 245ml)),치즈볼 4개/1',
#     'review_text': '덮밥에서 알수없는 딱딱한 씹히지않는 물체가 나왔습니다 뼈 인가요...'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1,갈비맛 목살덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '고기가 도톰해서 맛있었어요!'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(김치X)),매콤달달 제육덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(김치X),덮밥 토핑 추가선택(마늘슬라이스추가))',
#     'review_text': '늘 너무 잘 먹고잇습니다ㅎㅎ 점심으로 최고에요'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1,갈비맛 목살덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '맛있게 잘먹었습니다 ㅎㅎ'},
#    {'menus': '매콤달달 제육덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(부추X),덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(김치X))',
#     'review_text': '잘먹었습니다 ㅎㅎㅎ'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(덮밥 곱빼기))',
#     'review_text': '맛잇었습니다. 다음에 또 시킬게요'},
#    {'menus': '＋고추장 목살（고기만 600g）/1(고기 토핑 추가선택(양파（고기랑 같이 볶음）)),공기밥/1',
#     'review_text': '항상 맛있게 먹고 있습니다. 고추장 메뉴들이 진짜 맛있어요.'},
#    {'menus': '고추장 닭고기덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(양파（고기랑 같이 볶음）))',
#     'review_text': '배달도 빠른 편이고 맛있어요!'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(장국X)),고추장 닭고기덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X))',
#     'review_text': '감동적으로 맛있어요!'},
#    {'menus': '매콤달달 제육덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(김치X))',
#     'review_text': '늘 싸고 맛있는 밥 팔아주셔서 감사합니다!'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1', 'review_text': '맛있었어요~ 또 시켜먹을게요'},
#    {'menus': '메인1＋사이드1＋음료1/1(메인 택1(갈비맛 목살덮밥),토핑 추가(덮밥 곱빼기 추가 （덮밥메뉴만）),사이드 메뉴 택1(날치알 주먹밥),음료 택1(펩시 제로 뚱캔 355ml))',
#     'review_text': '너무맛있어용 또 시킬게요 ㅎㅎ'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1', 'review_text': '늘 너무 맛있게 먹고 있습니다'},
#    {'menus': '토마토 파스타 （PASTA） 도시락/1(파스타 토핑 버섯 추가선택(버섯O)),크림 파스타 （PASTA） 도시락/1(파스타 토핑 버섯 추가선택(버섯O)),케이준 감자튀김/1',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1', 'review_text': '잘먹었어요 감사합니다 ㅎㅎㅎ'},
#    {'menus': '고추장 닭고기덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '가끔가다 시키는데 매번 맛있는거 같아요'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(마늘슬라이스추가),덮밥 토핑 추가선택(양파（고기랑 같이 볶음）)),갈비맛 목살덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(양파（고기랑 같이 볶음）)),＋고추장 목살덮밥（한정판매）＋/1,＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(장국X))',
#     'review_text': '잘먹었습니다 번창하세요'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(양파（고기랑 같이 볶음）))',
#     'review_text': '마침 너무  배고프던차에 영수증에 적어주신글이랑 \n음식이 너무 맛있었어용 잘먹었습니다~~!!'},
#    {'menus': '매콤달달 제육덮밥 （RICE BOWL） 도시락/1,아이스티 샷추가（아샷추）/1,날치알 주먹밥/1',
#     'review_text': '맛있게 먹었는데 배달이 좀 늦네요'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1',
#     'review_text': '배달도 빠른 편이고 고기 양도 푸짐하고 맛있어요!'},
#    {'menus': '메인1＋사이드1＋음료1/1(메인 택1(갈비맛 목살덮밥),사이드 메뉴 택1(참치마요 주먹밥),음료 택1(펩시 캔 245ml)),간장 닭고기덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '맛있게 잘먹었습니다.\n가성비도 나쁘지 않네요.'},
#    {'menus': '매콤달달 제육덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(김치X),덮밥 토핑 추가선택(고기추가（100g）))',
#     'review_text': 'ㅠㅠ밥사진을 못찍었어요 정줄놓고 흡입하느라.. 전 제육은 가끔먹지만 제육볶음먹을땐 여기서만 시켜요!\n살코기부분이 꽤 많아서 비계살이 아주 많지도 않고, 제목그대로 매콤달달해서 완전 밥도둑 흑흑\n여기가 젤 맛있어요!!! 저는 딱 좋은데 생각해보니 매운거좋아하시는 분들을 위해  맵기조절옵션같은거 해도 좋을듯해요ㅎㅎ 암튼 넘 맛나요\n밥은 덮밥에 잘어울리게 보드라운 느낌입니당 밥이 달아요ㅎㅎ'},
#    {'menus': '메인1＋사이드1＋음료1/1(메인 택1(고추장 목살덮밥),토핑 추가(고기（100g）추가 （덮밥메뉴만）),빼주세요~(장국 X （덮밥 메뉴）),빼주세요~(김치 X （덮밥 메뉴）),사이드 메뉴 택1(참치마요 주먹밥),음료 택1(아이스 아메리카노))',
#     'review_text': '양도많고 잘먹었습니다'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '밥양이 많아서 든든하고 고기양도 진짜 푸짐해요!!'},
#    {'menus': '매콤달달 제육덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X))',
#     'review_text': '잘먹었습니다 배달빨라요'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1', 'review_text': '늘 맛잇는 맛으러 보내주셔서 감사합니다'},
#    {'menus': '아이스 아메리카노/1,미니핫도그5개/1,매콤달달 제육덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(고기추가（100g）))',
#     'review_text': '맛있었어요~ 또 시킬께요~!'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1,고추장 닭고기덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '맛있게 잘 먹었습니다 가격도 좋아요'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(양파（고기랑 같이 볶음）),덮밥 토핑 추가선택(고기추가（100g）))',
#     'review_text': '늘 재주문하고 있습니다'},
#    {'menus': '메인1＋사이드1＋음료1/1(메인 택1(고추장 목살덮밥),빼주세요~(부추 X （목살, 닭고기 덮밥 메뉴）),빼주세요~(장국 X （덮밥 메뉴）),빼주세요~(김치 X （덮밥 메뉴）),사이드 메뉴 택1(한 입 핫도그 5개),음료 택1(펩시 캔 245ml))',
#     'review_text': '잘 먹었습니다!!!'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(덮밥 곱빼기))',
#     'review_text': '오랜만에 시켜먹었는데 맛있습니다'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(부추X))',
#     'review_text': '덮스타의 갈비목살 덮밥을 애정하는데 정말 고기양이 푸짐하고 맛있어서 좋습니다 !'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(덮밥 곱빼기))',
#     'review_text': '항상 맛있게 잘 먹고있습니다ㅎㅎ'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(양파（고기랑 같이 볶음）),덮밥 토핑 추가선택(고기추가（100g）))',
#     'review_text': '항상 맛있게 먹고 있습니다'},
#    {'menus': '고추장 닭고기（고기만 600g）/1,날치알 주먹밥/1',
#     'review_text': '집밥처럼 맛있네요! 날치알 밥 와사비 너무 잘 맞고 닭갈비 맵지않고 좋아요!!'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(장국X))',
#     'review_text': '맛있게 잘 먹어서 기분도 좋습니다!'},
#    {'menus': '메인1＋사이드1＋음료1/1(메인 택1(갈비맛 목살덮밥),사이드 메뉴 택1(맛감자튀김),음료 택1(펩시 제로 뚱캔 355ml))',
#     'review_text': '생각보다 양 많아서 만족'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(김치X)),간장 닭고기덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(김치X))',
#     'review_text': '맛있어요🥹🥹 담번엔 고기만으로 재구매 해봐야겠어요'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1,로제 파스타 （PASTA） 도시락/1(파스타 토핑 버섯 추가선택(버섯O))',
#     'review_text': '덮밥 푸짐하고 맛나용'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1,토마토 파스타 （PASTA） 도시락/1(파스타 토핑 버섯 추가선택(버섯O)),미니핫도그5개/1',
#     'review_text': '배달빠르고 맛있네요'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(마늘슬라이스추가),덮밥 토핑 추가선택(양파（고기랑 같이 볶음）)),계란후라이/1',
#     'review_text': '고기가 빈약하거나 뻑뻑하지 않고 완전 맛있어요! 양도 엄청엄천 많아요!!!!!'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(양파（고기랑 같이 볶음）))',
#     'review_text': '양이 되게 많고 간도 적당했어요 잘 먹었습니다~~'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(김치X),덮밥 토핑 추가선택(양파（고기랑 같이 볶음）))',
#     'review_text': '평점이 높은 이유가 있네요! 맛있게 잘 먹었습니다~ 영수증에 써주신 멘트 덕분에 기분 좋은 하루가 될 것 같아요! 번창하세요~!'},
#    {'menus': '로제 파스타 （PASTA） 도시락/1(파스타 토핑 버섯 추가선택(버섯X)),메인1＋사이드1＋음료1/1(메인 택1(갈비맛 목살덮밥),사이드 메뉴 택1(치즈볼 4개),음료 택1(펩시 캔 245ml))',
#     'review_text': '양은 많은 편 같아요 셋이 먹는데 딱 맞았어요 근데 고기가 좀 많이 짰어요 오늘만 그런거길..ㅜ\n배달이 늦은건지 뭔지 모르겠지만 스파게티는 보통 국물소스가 자작히 있어야 좋은데 너무  꾸덕하니 좀 마른 듯 떡진 상태였어요 저흰 소스가 좀 자작하게 있는걸 좋아해서리.. 음식도 따뜻함이 거의 없어 아쉬움이 좀 많았네요..'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(덮밥 곱빼기))',
#     'review_text': '배달항상 빠릅니다 리뷰에벤트 아이스티 잘마실게요!'},
#    {'menus': '고추장 닭고기덮밥 （RICE BOWL） 도시락/1,치즈볼 4개/1',
#     'review_text': '아이가 맛있게 잘 먹었다고 하네요.\n감사합니다.'},
#    {'menus': '고추장 닭고기덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(김치X)),맛감자튀김/1',
#     'review_text': '오늘도 맛있게 잘 먹었습니다!'},
#    {'menus': '간장 닭고기덮밥 （RICE BOWL） 도시락/1,＋고추장 목살덮밥（한정판매）＋/2,고추장 닭고기덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '간편하게 먹기 좋았아요^^\n사장님도 친절하세요~'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1',
#     'review_text': '맛있게 잘먹었습니다 다음에는 아이디 꼭 적을게요'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(고기추가（100g）))',
#     'review_text': '맛있네요 자주 시켜먹을게요~!'},
#    {'menus': '매콤달달 제육덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(양파（고기랑 같이 볶음）),덮밥 토핑 추가선택(덮밥 곱빼기))',
#     'review_text': '달달하고 맛납니다! 제육덮밥 추천'},
#    {'menus': '토마토 파스타 （PASTA） 도시락/4(파스타 토핑 버섯 추가선택(버섯X)),치즈볼 4개/1,계란후라이/4,복숭아 아이스티/4',
#     'review_text': '짱~ 맛  감사합니다'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(덮밥 곱빼기))',
#     'review_text': '배달 빠르고 집밥처럼 먹어도 속이 편함\n맛있어요'},
#    {'menus': '간장 닭고기덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(김치X)),미니핫도그5개/1',
#     'review_text': '또 생각 나서 이틀 연속 주문했네요 ㅎㅎ 오늘도 맛있게 잘 먹었습니다! 사장님도 Shalom하세요 :)'},
#    {'menus': '고추장 닭고기덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(김치X))',
#     'review_text': '맛있게 잘 먹었습니다! 저녁 시간 이후에 급 배고파지면서 덮스타가 넘 생각났어요~ 잘 먹었습니다 :)'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(장국X)),고추장 닭고기덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '너무너무 맛있어요!'},
#    {'menus': '토마토 파스타 （PASTA） 도시락/1(파스타 토핑 버섯 추가선택(버섯X)),참이슬 후레쉬/1,장국/1,계란후라이/1',
#     'review_text': '면빨에 섞인 토마토 최고의 맛'},
#    {'menus': '메인1＋사이드1＋음료1/1(메인 택1(고추장 목살덮밥),빼주세요~(장국 X （덮밥 메뉴）),사이드 메뉴 택1(맛감자튀김),음료 택1(펩시 캔 245ml)),아이스 바닐라라떼/1',
#     'review_text': '역시 팬피자 보다는 일반 도우가 맛있네요 콤비네이션 최고입니다'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1', 'review_text': '맛있어요 잘먹었어요'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1,로제 파스타 （PASTA） 도시락/1(파스타 토핑 버섯 추가선택(버섯O),파스타 토핑 추가선택(마늘슬라이스),파스타 토핑 추가선택(체다치즈추가))',
#     'review_text': '맛있게 잘먹었습니다~'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1', 'review_text': '맛잇습니다 ㅎㅎㅎㅎ'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(덮밥 곱빼기))',
#     'review_text': '맛있게 잘먹었습니다'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/2(덮밥 토핑 추가선택(장국X),덮밥 토핑 추가선택(김치X)),계란후라이/1',
#     'review_text': '맛잇고배불러요 여기진짜 고추장목살 대박 개맛집'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(덮밥 곱빼기)),맛감자튀김/1,테라/1',
#     'review_text': '맛잇게 잘먹었습니다🤗'},
#    {'menus': '메인1＋사이드1＋음료1/1(메인 택1(고추장 목살덮밥),토핑 추가(마늘슬라이스 추가),사이드 메뉴 택1(케이준 감자튀김),음료 택1(펩시 캔 245ml)),매콤달달 제육덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '맛있고 간편하게 배달해먹기 좋은 것 같아요'},
#    {'menus': '간장 닭고기덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(덮밥 곱빼기))',
#     'review_text': '맛있게 잘 먹었습니다~'},
#    {'menus': '갈비맛 목살덮밥 （RICE BOWL） 도시락/1,매콤달달 제육덮밥 （RICE BOWL） 도시락/1(덮밥 토핑 추가선택(고기추가（100g）)),간장 닭고기덮밥 （RICE BOWL） 도시락/2,고추장 닭고기덮밥 （RICE BOWL） 도시락/1',
#     'review_text': '다른집들 배달이 안돼서 선택지가 없었는데 너무 잘됐어요! 값도 싸고 맛있고 배달 엄청 빨랐습니다. 또 시킬게요'},
#    {'menus': '미니핫도그5개/1,＋고추장 목살덮밥（한정판매）＋/1', 'review_text': '가격도착하고 맛있어요~!!'},
#    {'menus': '＋고추장 목살덮밥（한정판매）＋/1(덮밥 토핑 추가선택(덮밥 곱빼기))',
#     'review_text': '항상 맛있습니다 감사합니다'}],
#   'url': 'https://www.yogiyo.co.kr/mobile/#/1194514/'},
#  {'_id': '1342658',
#   'restaurant': '인생맛죽-분당점',
#   'reviews': [{'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 한우 소고기죽),죽 선택2(인생 보양삼계죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '양도 많고 합리적인 가격에 두가지 죽을 먹을 수 있어 좋았어요 삼계죽, 소고기죽 둘 다 맛있었습니다'},
#    {'menus': '죽(1인분)+사이드1+음료1+3종반찬/1(죽 선택1(인생 보양삼계죽),죽용기 선택(500g(250g+250g) : 작은용기2개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),사이드 선택 (세트메뉴)(인기만점 모듬만두(8p)),음료 선택 (세트메뉴)(코카콜라 제로 (500mL)),[후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜))',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '인생 신선야채죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 달콤호박죽(새알3알)/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '양도 많고 맛있어서 좋습니다.\n입맛이 없어서 죽을 한번 시켜봤는데\n맛있네요. 덕분에 입맛이 돌아왔습니다. :)'},
#    {'menus': '인생 새우계란죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '따끈하게 받을 수 있도록 포장도 센스 입니다'},
#    {'menus': '인생 차된장죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '가끔 아플 때 주문했는데 맛있어요'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 한우 소고기죽),죽 선택2(인생 새우계란죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '잘먹었습니다 아프면 또먹을게요'},
#    {'menus': '죽(1인분)+음료1+3종반찬/1(죽 선택1(인생 보양삼계죽),죽용기 선택(500g : 큰용기1개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),음료 선택 (세트메뉴)(비락식혜 plus (340ml)),사이드메뉴(1) 만두 추가 선택(인기만점 모듬만두(8p) 추가),사이드메뉴(3) 샌드위치 추가 선택(햄&치즈 샌드위치),[후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜)),인생 새우계란죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '배달 트러블이 살~짝있었지만 보온포장이 워낙 잘되있어서 뜨끈한 상태로 잘먹었습니다\n맛있었어요'},
#    {'menus': '죽(1인분)+음료1+3종반찬/1(죽 선택1(인생 영양닭죽),죽용기 선택(500g : 큰용기1개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),음료 선택 (세트메뉴)(칠성사이다 (500mL)),[후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜))',
#     'review_text': '어우 죽 맛있어요!! 계란찜도요 ㅎ'},
#    {'menus': '인생 보양삼계죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '배달 빠르고 음식도 따듯해서 좋습니다'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 매운낙지죽),죽 선택2(인생 해장짬뽕죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛있어요👍👍👍👍👍👍👍👍👍👍👍👍'},
#    {'menus': '죽(1인분)+음료1+3종반찬/1(죽 선택1(인생 보양삼계죽),죽용기 선택(500g : 큰용기1개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),음료 선택 (세트메뉴)(코카콜라 제로 (500mL)),[후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 얼음동동 전통식혜 (500mL)))',
#     'review_text': '💯💯💯💯💯'},
#    {'menus': '인생 신선야채죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(1000g(500g+500g) : 큰용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '아이가 아파서 죽집 찾다가 시켰는데 너무 잘먹네요.\n사업 번창하세요 ㅎ'},
#    {'menus': '인생 한우소고기죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛있어요. 깔끔하게 나와 좋습니다.'},
#    {'menus': '인생 영양닭죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '따뜻하게 보온팩에 배달와서 정말 따뜻하게 먹었습니다. 양도 적당하고 맛있었습니다 :)'},
#    {'menus': '죽(1인분)+음료1+3종반찬/1(죽 선택1(인생 한우 소고기죽),죽용기 선택(500g : 큰용기1개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),음료 선택 (세트메뉴)(비락식혜 plus (340ml))),인생 명품 완도전복죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '두번째 주문이고 괜찮아유'},
#    {'menus': '죽(1인분)+음료1+3종반찬/1(죽 선택1(인생 한우 소고기죽),죽용기 선택(500g : 큰용기1개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),음료 선택 (세트메뉴)(비락식혜 plus (340ml)),[후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜))',
#     'review_text': '배달도 빠르고 따뜻하게 잘 먹었습니다!'},
#    {'menus': '인생 보양삼계죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 얼음동동 전통식혜 (500mL)),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공),사이드메뉴(3) 샌드위치 추가 선택(햄&치즈 샌드위치))',
#     'review_text': '💯💯💯💯💯'},
#    {'menus': '인생 영양닭죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 보양삼계죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '양도많고 맛있었어요'},
#    {'menus': '죽(1인분)+사이드1+음료1+3종반찬/1(죽 선택1(인생 영양닭죽),죽용기 선택(500g : 큰용기1개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),사이드 선택 (세트메뉴)(햄&치즈 샌드위치),음료 선택 (세트메뉴)(코카콜라 제로 (500mL)))',
#     'review_text': '잘 먹었습니다\n감사합니다'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 오징어젓갈),죽 선택1(인생 김치낙지죽),죽 선택2(인생 한우 소고기죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '잘먹었습니다 또 주문할게요'},
#    {'menus': '인생 명품 완도전복죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 김치낙지죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맞짱. 양이 너무 적어요. 섭스 계난찜 감사합니다.'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽 선택1(인생 신선야채죽),죽 선택2(인생 신선야채죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다(3종반찬)),오징어젓갈/1',
#     'review_text': '맛있어요. 담에또 시키려구요.'},
#    {'menus': '인생 달콤호박죽(새알3알)/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '장염으로 고생중에 먹었는데 맛있네요~'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 오징어젓갈),죽 선택1(인생 김치낙지죽),죽 선택2(인생 전통 동지팥죽(새알3알)),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '괜찮았어요 팥죽안단거딱찾던거 양이좀적어요'},
#    {'menus': '인생 영양닭죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '와~~ 계란찜도 챙겨주셔서 감사합니다 ㅠㅠ 출근하는데 배가 너무 아팠어서 사게 되었는데 죽도 든든하니 맛있고 너무 잘 먹었습니다~!!'},
#    {'menus': '인생 영양닭죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 한우소고기죽/1(죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '몸이 안좋아서 죽을 먹었는데 괜찮았어요'},
#    {'menus': '죽(1인분)+음료1+3종반찬/1(죽 선택1(인생 한우 소고기죽),죽용기 선택(500g(250g+250g) : 작은용기2개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),음료 선택 (세트메뉴)(비락식혜 plus (340ml)),[후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜)),메추리알 조림/1',
#     'review_text': '양 맛 모두 좋고 배달도 빨라요'},
#    {'menus': '인생 새우계란죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '배달이 30분이상 늦어서 죽이 다 식었어요ㅠㅠ 하지만 맛있었습니다:)'},
#    {'menus': '인생 고소한참치죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '고소하고 맛있어요! 오자마자 급하게 먹어서 사진을 깜빡했는데 ㅜㅜ 반찬도 괜찮고 만족스러운 식사였어요'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 신선야채죽),죽 선택2(인생 한우 소고기죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '고소하고 너무 맛있어요!!'},
#    {'menus': '죽(1인분)+음료1+3종반찬/1(죽 선택1(인생 영양닭죽),죽용기 선택(500g(250g+250g) : 작은용기2개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),음료 선택 (세트메뉴)(얼음동동 전통식혜 (500mL)),[후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜))',
#     'review_text': '감사히 잘 먹었습니다'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 얼음동동 전통식혜 (500mL)),죽 선택1(인생 신선야채죽),죽 선택2(인생 고소한참치죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '죽이랑 식혜가 정말 맛있어요! \n앞으로 죽은 여기 먹을 것 같아요.'},
#    {'menus': '인생 달콤호박죽(새알3알)/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '달콤하고 부드러워서 맛있게 먹었습니다'},
#    {'menus': '죽(1인분)+음료1+3종반찬/1(죽 선택1(인생 영양닭죽),죽용기 선택(500g : 큰용기1개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),음료 선택 (세트메뉴)(코카콜라 제로 (500mL))),인생 보양삼계죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛잇게 잘먹었습니다\n맵고 짜고하지않게 슴슴하니 좋았습니다'},
#    {'menus': '인생 한우소고기죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 오징어젓갈),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 매운낙지죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '가끔 주문하는데 서비스 든든하게 주셔서 감사합니다'},
#    {'menus': '골라담아 2가지/1(죽 선택1(인생 달콤호박죽(새알3알)),죽 선택2(인생 표고버섯죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛도 양도 그저 그래요'},
#    {'menus': '인생 김치낙지죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공),사이드메뉴(1) 만두 추가 선택(쫀득 김치만두 (8p)추가))',
#     'review_text': '김치낙지죽 너무 먹고 싶었는데 주문 되는 곳이 없더라구요.. 인생맛죽에서 다행히 주문 돼가지구 잘 받아서 너무 맛있게 먹었습니당 ㅠ 김치낙지죽은 물론이고 계란찜이랑 김치만두도 넘넘 맛있게 잘 먹었어요!! 포장도 깔끔하고요\n사이드 메뉴도 맛나서 죽은 여기서만 시켜먹을 것 같아요 ㅎㅎㅎ'},
#    {'menus': '인생 영양닭죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 명품 완도전복죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '배달빠르고 맛도 너무좋아요'},
#    {'menus': '골라담아 3가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 한우 소고기죽),죽 선택2(인생 한우 소고기죽),죽 선택3(인생 고소한참치죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛있습니다~ 배달이 너무오래걸렸네요..ㅜㅜ'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 영양닭죽),죽 선택2(인생 김치낙지죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 한우소고기죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 보양삼계죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛은 있으나\n타지점은 오징어젓갈 사이드로 주는데\n여기는 죽을 네개 시켜도 후리가케 세개만오고\n가게배달도 예상보다 늦게와서 점심시간이 20분밖에없는데 결국 다들 못먹었네요'},
#    {'menus': '죽(1인분)+사이드1+음료1+3종반찬/1(죽 선택1(인생 한우 소고기죽),죽용기 선택(500g : 큰용기1개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),사이드 선택 (세트메뉴)(햄&치즈 샌드위치),음료 선택 (세트메뉴)(코카콜라 제로 (500mL)))',
#     'review_text': '💯💯💯💯💯'},
#    {'menus': '인생 신선야채죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '조카가 맛있게 잘 먹었습니다'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 신선야채죽),죽 선택2(인생 명품 완도전복죽),죽용기 선택(500g(250g+250g) : 작은용기4개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '어머니 편찮으셔서 주문했는데 배달이 조금 느린것 빼고 다 좋았어요\n맛있다고 하시네요'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 고소한참치죽),죽 선택2(인생 표고버섯죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '내용물도 훌륭하고 너무 맛있네요 양도 넉넉해서 더 좋아요~ 서비스로 보내주신 계란찜도 너무 부드럽고 맛있었어요~'},
#    {'menus': '인생 명품 완도전복죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛있습니다\n그 어떤 집보다도 추천해요~~'},
#    {'menus': '인생 전통 동지팥죽(새알3알)/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '팥죽 담백하게 맛있어요\n계란 찜도 맛있네요 \n많이 파세요'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 오징어젓갈),죽 선택1(인생 한우 소고기죽),죽 선택2(인생 명품 완도전복죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '몸아플때 먹기 딱이네요 부드럽고 양도 딱 좋구요\n소고기죽 전복죽 둘다 맛있었어요!!'},
#    {'menus': '인생 김치낙지죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '오랜만에 아파서 빌빌대는데 따뜻하고 맛있는 죽 먹으니 힘이 나네요. 감사합니다.'},
#    {'menus': '인생 보양삼계죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(1000g(500g+500g) : 큰용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '몸아픈데 잘 넘어갑니당'},
#    {'menus': '인생 달콤호박죽(새알3알)/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 오징어젓갈),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 고소한참치죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛있게 잘 먹었습니다사진은 못찍어서. 아ㅛㅢㅂ네요'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 얼음동동 전통식혜 (500mL)),죽 선택1(인생 한우 소고기죽),죽 선택2(인생 보양삼계죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '죽이 참 맛있고 따뜻해요'},
#    {'menus': '인생 한우소고기죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 달콤호박죽(새알3알)/1(죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다(3종반찬))',
#     'review_text': '맛있게 잘 먹었습니다~'},
#    {'menus': '인생 고소한참치죽/1(죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다(3종반찬),반찬 추가선택(3종반찬))',
#     'review_text': '맛있고 배송도 빨라서 좋아여'},
#    {'menus': '죽(1인분)+음료1+3종반찬/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 오징어젓갈),죽 선택1(인생 보양삼계죽),죽용기 선택(500g(250g+250g) : 작은용기2개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),음료 선택 (세트메뉴)(아이스아메리카노(+얼음컵)))',
#     'review_text': '맛있었어요! 다음에 또 시켜먹을게요'},
#    {'menus': '죽(1인분)+사이드1+음료1+3종반찬/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 새우계란죽),죽용기 선택(500g : 큰용기1개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),사이드 선택 (세트메뉴)(인기만점 모듬만두(8p)),음료 선택 (세트메뉴)(코카콜라 제로 (500mL)))',
#     'review_text': '맛있게 잘 먹았습니다'},
#    {'menus': '죽(1인분)+음료1+3종반찬/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 옛날된장죽),죽용기 선택(500g(250g+250g) : 작은용기2개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),음료 선택 (세트메뉴)(탄산수 (레몬) 350mL)),햄&치즈 샌드위치/1',
#     'review_text': '배달이좀 늦었지만 맛있었습니다'},
#    {'menus': '인생 해장짬뽕죽/1(죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '카메라가 안되서 글만씁니다ㅎ\n짬뽕죽 덕분에 기력많이 회복했습니다ㅎ\n숙취로 힘들때 최고의 음식이네요'},
#    {'menus': '인생 고소한참치죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '배탈이 안나아서 오늘도 주문했는데 맛있었어요.'},
#    {'menus': '인생 영양닭죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '애들이 좋아합니다.'},
#    {'menus': '인생 새우계란죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '오늘 배탈이 나서 주문했는데 맛있었어요...!'},
#    {'menus': '인생 일품게살죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공),사이드메뉴(1) 만두 추가 선택(인기만점 모듬만두(8p) 추가))',
#     'review_text': '오늘 점심, 저녁 각각 주문해서 두 번 연속으로 먹었네요~ 종류가 다양하고 다 맛있으면서 든든해요 :) 잘 먹었습니다 ^^'},
#    {'menus': '인생 명품 완도전복죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '아픈 날 든든하게 잘 먹었습니다! 맛도 양도 넘 좋고, 계란찜도 감사해요! 죽과 계란찜 다 맛있어요 :)'},
#    {'menus': '인생 깔끔흰죽/2([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛있습니다\n정갈한 포장도 맘에 듭니다\n추천해요\n다음에 또 이용하겠습니다'},
#    {'menus': '새우만두 (7p)/1,죽(1인분)+음료1+3종반찬(선택)/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 김치낙지죽),죽용기 선택(500g(250g+250g) : 작은용기2개),3종반찬 선택 (세트메뉴)(3종 반찬 미선택 (반찬X)),음료 선택 (세트메뉴)(코카콜라 제로 (500mL)))',
#     'review_text': '넵'},
#    {'menus': '인생 명품 완도전복죽/1(죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 한우소고기죽/1(죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '처음 먹어봤는데 소고기죽과 전복죽이 다 맛있네요.\n배달도 빨라서 좋았어요.'},
#    {'menus': '인생 영양닭죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛있게 잘 먹었습니다!'},
#    {'menus': '인생 영양닭죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다(3종반찬))',
#     'review_text': '첨 시켜먹는데 맛있네요!'},
#    {'menus': '죽(1인분)+음료1+3종반찬(선택)/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽 선택1(인생 신선야채죽),죽용기 선택(500g(250g+250g) : 작은용기2개),3종반찬 선택 (세트메뉴)(3종 반찬 미선택 (반찬X)),음료 선택 (세트메뉴)(생수 (500mL)),사이드메뉴(1) 만두 추가 선택(쫀득 김치만두 (8p)추가))',
#     'review_text': '넘  맛있게 잘먹었습니다'},
#    {'menus': '죽(2인분)+사이드1+음료2+3종반찬(선택)/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽 선택1(인생 한우 소고기죽),죽 선택2(인생 고소한참치죽),죽용기 선택(500g : 큰용기1개),3종반찬 선택 (세트메뉴)(3종 반찬 미선택 (반찬X)),사이드 선택 (세트메뉴)(인기만점 모듬만두(8p)),음료 선택 1(세트메뉴)(아이스아메리카노(+얼음컵)),음료 선택 2(세트메뉴)(아이스아메리카노(+얼음컵))),인생 김치낙지죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛납니다!! 아침메뉴로 최고'},
#    {'menus': '인생 표고버섯죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 영양닭죽/1(죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '첫 주문인데 맛있습니다.'},
#    {'menus': '인생 영양닭죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 얼음동동 전통식혜 (500mL)),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '서비스 계란찜 잘먹었습니다 정성이 느껴져서 좋았어요'},
#    {'menus': '인생 깔끔흰죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '첫주문인데 전반적으로 만족했습니다'},
#    {'menus': '새우만두 (7p)/1,인생 한우소고기죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공)),인생 영양닭죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '아이가 닭죽 맛있다고 하네요. 종종 시킬것같아요.'},
#    {'menus': '죽(1인분)+음료1+3종반찬(선택)/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽 선택1(인생 한우 소고기죽),죽용기 선택(500g(250g+250g) : 작은용기2개),3종반찬 선택 (세트메뉴)(3종 반찬 선택 (세트메뉴)),음료 선택 (세트메뉴)(비락식혜 plus (340ml)))',
#     'review_text': '덕분에 뜨끈하게 맛있게먹었습니다~'},
#    {'menus': '골라담아 2가지/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 3종 반찬 (1개)),죽 선택1(인생 신선야채죽),죽 선택2(인생 새우계란죽),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '맛있게 잘 먹었습니다.'},
#    {'menus': '인생 고소한참치죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '죽과 계란찜 맛있어요'},
#    {'menus': '인생 보양삼계죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 보들보들 계란찜),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '몸 아픈 이틀동안 잘먹었어요'},
#    {'menus': '인생 보양삼계죽/1([후ㄱ ㅣ약속] 주문 1회당 1개만 제공됩니다.([후ㄱ ㅣ약속] 얼음동동 전통식혜 (500mL)),죽용기 선택(500g : 큰용기1개),[반찬 선택] 선택하신 반찬만 제공됩니다([반찬X] 죽 단품만 제공))',
#     'review_text': '💯💯💯💯💯'},
#    {'menus': '인생 고소한참치죽/1(죽용기 선택(500g(250g+250g) : 작은용기2개),[반찬 선택] 선택하신 반찬만 제공됩니다(3종반찬 2개),반찬 추가선택(3종반찬))',
#     'review_text': '배송 빠르고 맛있고\n서비스도 좋아여'},
# ...
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '냉면세트/1(냉면선택(물냉면),세트선택(숯불고기)),500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p))',
#     'review_text': '언제나 최고에요!! 배달도 엄청 빠르네요\n아이가 매일 시켜달라고 합니다'},
#    {'menus': '냉면세트/2(냉면선택(비빔냉면),세트선택(숯불고기))', 'review_text': '배달빠르고 맛있어요'},
#    {'menus': '분당맛집／ 비빔냉면/1,（육회） 비빔밥/1,500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p))',
#     'review_text': '진짜 맛있어요! 오이 못먹어서 빼달라는 요청도 잘들어주시고 푸짐하고 깔끔하고 맛있었어요~! 다음에도 또 먹고싶습니다~'},
#    {'menus': '500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p)),냉면세트/1(냉면선택(물냉면),세트선택(숯불고기))',
#     'review_text': '사장님이 빠르고 배송이 맛있어요'},
#    {'menus': '커플냉면세트/1(냉면선택(비빔냉면),냉면2(비빔냉면),세트선택(숯불고기),세트2(숯불고기)),500원의행복❤/1(이달의이벤트(별5개약속~냉면미니육수)),（숯불고기）비빔밥/1',
#     'review_text': '배달빠르고 맛있어요'},
#    {'menus': '500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p)),냉면세트/1(냉면선택(해장 물냉면(매운맛++)),세트선택(날치알주먹밥),추가선택(면곱빼기),추가선택(갈비만두 8개)),콜라 1.25L/1',
#     'review_text': '배달 빨리오고 맛있네요'},
#    {'menus': '냉면세트/1(냉면선택(비빔냉면),세트선택(숯불고기)),500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p))',
#     'review_text': '양 엄청많아서 든든하게 잘먹었어요!!'},
#    {'menus': '냉면세트/1(냉면선택(물냉면),세트선택(숯불고기))',
#     'review_text': '즁2 아들이 자주 찾는곳이에요'},
#    {'menus': '500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p)),냉면세트/1(냉면선택(해장 비빔냉면(중간맛)),세트선택(날치알주먹밥),추가선택(면곱빼기),추가선택(떡갈비)),콜라 1.25L/1',
#     'review_text': '배달 빨리오고 맛있네요'},
#    {'menus': '냉면세트/1(냉면선택(물냉면),세트선택(숯불고기),추가선택(면곱빼기),추가선택(비빔양념장)),냉면세트/1(냉면선택(물냉면),세트선택(숯불고기),추가선택(면곱빼기),추가선택(대왕 냉면육수)),500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p)),갈비만두 8개/1,반반왕만두 5개/1',
#     'review_text': '정말 양도 많고 맛있었어요'},
#    {'menus': '냉면세트/1(냉면선택(물냉면),세트선택(숯불고기),추가선택(물만두))',
#     'review_text': '생각보다  괜찮음  \n면이  잘안풀림'},
#    {'menus': '500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p)),냉면세트/1(냉면선택(비빔냉면),세트선택(숯불고기),추가선택(면곱빼기))',
#     'review_text': '항상 매주 먹는 맛집ㅎㅎ'},
#    {'menus': '냉면세트/1(냉면선택(열무)물냉면),세트선택(고기왕만두2개)),500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p))',
#     'review_text': '밤에 배가 고파 열무냉면이랑 만두 시켜먹었는데 양도 많고 맛나요'},
#    {'menus': '숯불고기 100g/1,육회비빔냉면/1(추가선택(면곱빼기),추가선택(갈비만두 8개),추가선택(숯불고기 100g),추가선택(공기밥)),공기밥/1,갈비만두 8개/1',
#     'review_text': '허겁지겁먹었네요ㅜㅜ진심맛있어요♡♡'},
#    {'menus': '냉면세트/1(냉면선택(비빔냉면),세트선택(숯불고기)),500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p))',
#     'review_text': '받고 바로못먹어서 한참뒀다 먹었지만 맛있네요~^^'},
#    {'menus': '냉면세트/1(냉면선택(물냉면),세트선택(숯불고기)),500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p))',
#     'review_text': '두번째인데 진짜 맛있어요!!\n강추입니닷'},
#    {'menus': '커플냉면세트/1(냉면선택(해장 물냉면(중간맛)),냉면2(해장 물냉면(중간맛)),세트선택(숯불고기),세트2(숯불고기)),500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p))',
#     'review_text': '맛있게 잘먹었습니당'},
#    {'menus': '육회비빔냉면/1,500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p))',
#     'review_text': '냉면은 여기가 제일 맛있어요 먹고 싶으면 여기서만 시켜요'},
#    {'menus': '커플냉면세트/1(냉면선택(물냉면),냉면2(비빔냉면),세트선택(숯불고기),세트2(반반왕만두2개)),500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p)),메추리알（4알）/1',
#     'review_text': '너무 맛있게 먹었어요.\n요청사항도 \n꼼꼼히 잘 들어주셔서 좋았어요.'},
#    {'menus': '500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p)),냉면세트/1(냉면선택(물냉면),세트선택(숯불고기))',
#     'review_text': '역시 여기는 실망시키지않아!!맛나욤'},
#    {'menus': '（육회） 비빔밥/1,500원의행복❤/1(이달의이벤트(별5개약속~냉면미니육수)),숯불고기 100g/1',
#     'review_text': '맛있게 잘 먹었습니다'},
#    {'menus': '냉면세트/1(냉면선택(비빔냉면),세트선택(숯불고기)),500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p))',
#     'review_text': '잘 먹었습니다~~~!!\n냉면과 숯불고기는 모르겠는데,\n리뷰 이벤트 만두가 젤 맛있네요'},
#    {'menus': '냉면세트/1(냉면선택(물냉면),세트선택(숯불고기)),분당맛집／ 물냉면/1,500원의행복❤/1(이달의이벤트(별5개약속~갈비만두3p)),고기왕만두 5개/1',
#     'review_text': '시원하고 맛좋은 냉면'},
#    {'menus': '냉면세트/1(냉면선택(물냉면),세트선택(숯불고기))',
#     'review_text': '점심 잘 먹었습니다. 비계가 많아서 쫌.'},
#    {'menus': '냉면세트/1(냉면선택(물냉면),세트선택(숯불고기)),500원의행복❤/1(이달의이벤트(별5개약속~열무김치)),（다이어트）곤약 물냉면/1',
#     'review_text': '배달이 13분 만에 와서 깜짝 놀랐어요 ㅎㅎ 시원하고 맛있게 잘 먹었습니다'},
#    {'menus': '냉면세트/1(냉면선택(물냉면),세트선택(숯불고기))',
#     'review_text': '맛있게 잘 먹었습니다 다음에 또 구입 하도록 하겠습니다 오늘 하루도 즐겁게 보내세요'},
#    {'menus': '500원의행복❤/1(이달의이벤트(별5개약속~열무김치)),커플냉면세트/1(냉면선택(열무)물냉면),냉면2(열무)비빔냉면),세트선택(숯불고기),세트2(숯불고기)),（쭈꾸미） 비빔밥/1',
#     'review_text': '맛있게 잘먹었습니다!\n열무김치랑 같이 먹으니.더 맛있습니다!'},
#    {'menus': '냉면세트/1(냉면선택(물냉면),세트선택(갈비만두4개)),（육회） 비빔밥/1,500원의행복❤/1(이달의이벤트(별5개약속~냉면미니육수))',
#     'review_text': '맛있게 잘먹었습니다~~ 담에 또 주문할게요!'}],
#   'url': 'https://www.yogiyo.co.kr/mobile/#/359845/'},
#  {'_id': '1029960',
#   'restaurant': '샐러리아-판교점',
#   'reviews': [{'menus': '부채살스테이크 포케[415kcal]/1(부채살(100g),포케소스선택(오리지널소스))',
#     'review_text': '먹다가 사진찍어버려서 덜이쁘지만 넘넘 맛있게 잘먹었어용🤤🤤'},
#    {'menus': '스팀 닭가슴살 샐러드[175kcal]/1(드레싱소스 선택(오리엔탈 드레싱)),아보카도 샐러드[220kcal]/1(드레싱소스 선택(오리엔탈 드레싱))',
#     'review_text': '빠르게 잘 받았습니다.맛있게 잘 먹었습니다.'},
#    {'menus': '부채살 샐러드[220kcal]/1(부채살(200g),드레싱소스 선택(오리엔탈 드레싱))',
#     'review_text': '점심에 포케 먹고 맛있어서 저녁도 샐러드 시켰어용\n맛있어요 샐러드!!'},
#    {'menus': '훈제연어 포케[455kcal]/1(포케소스선택(오리지널소스),같이 주문시 반값 추가선택(ICE 아메리카노))',
#     'review_text': '포케 맛있네요! 다음에도 시켜먹을것같아요'},
#    {'menus': '훈제연어 포케[455kcal]/1(포케소스선택(멕시칸 치폴레 소스))',
#     'review_text': '와 진짜 배달도 너무 빠르고!! 양도 많아서 좋아요 ㅎㅎ 날치알도 듬뿍이라 먹는 내내 행복 ㅎㅎ 종종 많이 시켜먹을게용~~ 강추강추!!!'},
#    {'menus': '햄치즈 샌드위치/1(식빵선택(우유식빵),소스선택(기본소스)),매콤닭가슴살 샌드위치/1(식빵선택(우유식빵),소스선택(기본소스),같이 주문시 반값 추가선택(콤부차（히비스커스）))',
#     'review_text': 'n번째 구매입니다\n샌드위치 생각나면 그냥 샐러리아에요🤣'},
#    {'menus': '훈제오리 포케[440kcal]/1(포케소스선택(오리지널소스),토핑 추가선택(바질소스추가（뿌려져서나갑니다）))',
#     'review_text': '채소, 고기, 현미 다 맛있어요. 소스도 맛있고, 바질소스 추가 했는데 이것도 맛있어요.'},
#    {'menus': '／／ 건강한끼 ／／ 생연어 샐러드[275kcal]/1(생연어(100g),드레싱소스 선택(오리엔탈 드레싱),토핑 추가선택(와사비게살추가))',
#     'review_text': '항상 잘 먹고 있습니다.'},
#    {'menus': '햄치즈에그 샌드위치/1(식빵선택(통밀식빵),소스선택(기본소스)),베이컨스크램블 샌드위치/1(식빵선택(우유식빵),소스선택(기본소스)),컵스프 [단호박 크림]/1',
#     'review_text': '스프는 너무 너무 달아요.\n계란 껍질이 씹혔어요.'},
#    {'menus': '생과일 토마토 주스/1(사이즈 선택(550mL)),생과일 키위주스/1(사이즈 선택(550mL)),[식사대용] 생과일 아보카도바나나쉐이크/1(사이즈 선택(550mL)),부채살스테이크 포케[415kcal]/1(부채살(200g),포케소스선택(오리지널소스)),통통쉬림프 샐러드[140kcal]/1(드레싱소스 선택(오리엔탈 드레싱))',
#     'review_text': '신선합니다 잘받았습니다'},
#    {'menus': '훈제연어 포케[455kcal]/1(포케소스선택(오리지널소스),같이 주문시 반값 추가선택(ICE 아메리카노))',
#     'review_text': '연어 양도 많고 맛있게 배불리 먹었어요~ 아메리카노도 시원했고 맛있었어요^^'},
#    {'menus': '훈제연어 포케[455kcal]/2(포케소스선택(멕시칸 치폴레 소스))',
#     'review_text': '맛있어요...!!!'},
#    {'menus': '매콤닭가슴살 샌드위치/1(식빵선택(우유식빵),소스선택(기본소스),같이 주문시 반값 추가선택(힐링티 프로 빠른 수분충전 음료)),햄치즈 샌드위치/1(식빵선택(통밀식빵),소스선택(기본소스))',
#     'review_text': '배달 빠르고 맛있어요!!\n샌드위치 맛집입니다🤗\n힐링 수분 티가 원래 투명이었는데 색깔이 바뀐 것 같아요.'},
#    {'menus': '매콤닭가슴살 샌드위치/1(식빵선택(우유식빵),소스선택(기본소스),같이 주문시 반값 추가선택(힐링티 프로 빠른 수분충전 음료)),햄치즈 샌드위치/1(식빵선택(통밀식빵),소스선택(기본소스))',
#     'review_text': '샌드위치 맛있어서 자주 주문합니다!'},
#    {'menus': '매콤닭가슴살 샌드위치/1(식빵선택(우유식빵),소스선택(기본소스)),부채살스테이크 포케[415kcal]/1(부채살(100g),포케소스선택(오리지널소스),같이 주문시 반값 추가선택(힐링티 프로 빠른 수분충전 음료))',
#     'review_text': '두툼하고 신선해서 맛있게 먹었습니다!'},
#    {'menus': '베이컨스크램블 샌드위치/1(식빵선택(우유식빵),소스선택(기본소스)),햄치즈에그 샌드위치/1(식빵선택(우유식빵),소스선택(기본소스)),온리에그마요 샌드위치/1(소스선택(기본소스)),훈제연어리코타 샌드위치/1(식빵선택(우유식빵),소스선택(기본소스)),아보카도듬뿍 샌드위치/1(식빵선택(우유식빵),소스선택(기본소스))',
#     'review_text': '맛있어요\n채소도 알차게 잘 들어있고\n배 부르고 좋아요\n\n\n근데 에그마요가 살짝 달았어요!'},
#    {'menus': '부채살스테이크 포케[415kcal]/1(부채살(100g),포케소스선택(쌈장마요소스（New）)),데리야끼 닭가슴살 랩/1(소스선택(멕시칸 스파이시 소스)),컵스프 [단호박 크림]/1',
#     'review_text': '배달비가 5500원이었는데 이건 좀 실망이네요.'},
#    {'menus': '훈제오리 포케[440kcal]/1(포케소스선택(오리지널소스)),케이준 포케[440kcal]/1(포케소스선택(오리지널소스))',
#     'review_text': '훈제오리 포케 케이준치킨 포케 둘다 너무너무 맛있어요 배달해주셔서 감사해요!'},
#    {'menus': '치킨텐더 랩/1,스팀 매콤닭가슴살 포케[355kcal]/1(포케소스선택(오리지널소스))',
#     'review_text': '포케 날치알 빼달라고 요청드렸는데 \n그대로 넣어주셨더라고요 마감시간 다 되어서 시켜서 \n그냥 다 넣으신건지 ,, 다음엔 요청사항 꼭 잘 봐주셨음 합니다'},
#    {'menus': '훈제오리 포케[440kcal]/1(포케소스선택(매콤마요소스（와사비베이스）)),블루베리바나나 그릭요거트/1(꿀 선택(꿀O))',
#     'review_text': '야근하면서 한끼 먹기 딱 좋아요 ~\n양도 넉넉하고 중간중간 날치알 씹히는게 포인트인듯 넘 맛있네요'},
#    {'menus': '／／ 건강한끼 ／／ 생연어 샐러드[275kcal]/1(생연어(100g),드레싱소스 선택(파인요거트 드레싱)),베이컨스크램블 샌드위치/1(식빵선택(우유식빵))',
#     'review_text': '요즘 먹은 샐러드 중에 젤 맛있는것 같아요! 양도 많고 연어도 신선하고 굿굿👍 다음에 또 시켜먹으려구요:)'},
#    {'menus': '훈제연어 포케[455kcal]/1(포케소스선택(오리지널소스),같이 주문시 반값 추가선택(ICE 아메리카노)),누텔라 크로플/1',
#     'review_text': '정신없는 하루의 첫 끼였는데 덕분에 디저트까지 맛있게 먹었습니다.'},
#    {'menus': '훈제오리 샐러드[285kcal]/2(드레싱소스 선택(오리엔탈 드레싱),토핑 추가선택(훈제오리추가)),우삼겹 샐러드/1(우삼겹.풀드포크.통삼겹(200g),드레싱소스 선택(오리엔탈 드레싱),토핑 추가선택(소불고기추가))',
#     'review_text': '양 적당하고 신선해서 좋았어요'},
#    {'menus': '컵 스프 [버섯크림]/1,（한정수량） 생연어포케[470kcal]/1(포케소스선택(매콤마요소스（와사비베이스）),생연어(200g),같이 주문시 반값 추가선택(복숭아아이스티)),（한정수량） 생연어포케[470kcal]/1(포케소스선택(매콤마요소스（와사비베이스）),생연어(200g),토핑 추가선택(와사비게살추가),같이 주문시 반값 추가선택(복숭아아이스티))',
#     'review_text': '시간맞춰 잘 조내주셔서 감사합니다'},
#    {'menus': '단호박 듬뿍 샌드위치/1(식빵선택(우유식빵),같이 주문시 반값 추가선택(ICE 아메리카노)),햄치즈에그 샌드위치/1(식빵선택(우유식빵),같이 주문시 반값 추가선택(ICE 아메리카노))',
#     'review_text': '저의 최애 단호박샌드위치♡\n열번넘게 시켜먹은듯요ㅋㅋㅋ\n재료도 아낌없이 들어가서 맛있어요!!'},
#    {'menus': '생과일 토마토 주스/1(사이즈 선택(550mL)),부채살 샐러드[220kcal]/1(부채살(200g),드레싱소스 선택(발사믹 드레싱),드레싱 추가선택(오리엔탈 드레싱 추가)),[식사대용] 생과일 아보카도바나나쉐이크/1(사이즈 선택(550mL))',
#     'review_text': '샐러리아 아보카도 주스 정말 맛있어요~!'},
#    {'menus': '（한정수량） 생연어포케[470kcal]/1(포케소스선택(오리지널소스),생연어(100g),토핑 추가선택(소불고기추가))',
#     'review_text': '샐러드 맛집 찾았네요..!💕'},
#    {'menus': '컵 스프 [콘스프]/1,훈제오리 샐러드[285kcal]/1(드레싱소스 선택(파인요거트 드레싱),토핑 추가선택(리코타치즈 추가),토핑 추가선택(훈제오리추가))',
#     'review_text': '콘스프 냄새부터 짱입니다 맛잇어용'},
#    {'menus': '아보카도 샐러드[220kcal]/1(드레싱소스 선택(오리엔탈 드레싱)),단호박닭가슴살 샌드위치/1(식빵선택(우유식빵)),블루베리바나나 그릭요거트/1(꿀 선택(꿀O))',
#     'review_text': '리뷰 안쓰려고 했었는데 맛있어서 씁니다.\n맛있어요 ㅎㅎ 특히 요거트는 정말 강춥니다. \n사진 찍을껄'},
#    {'menus': '햄치즈에그 샌드위치/1(식빵 선택(통밀식빵),양상추 양(양상추 보통으로주세요（기본）)),과일 그레놀라 그릭 요거트/1(꿀 추가(꿀 추가)),케이준 샐러드 （치킨은 진리에요）/1(드레싱 소스 선택(오리엔탈))',
#     'review_text': '오 여기 맛있네요 ㅋㅋㅋㅋ 첨 시켜봤는데 싹싹 다 먹었어요'},
#    {'menus': '훈제오리포케/1(추가 가능 토핑(단호박 추가))',
#     'review_text': '야채도 신선하고 소스양도적당하고 맛있게먹었습니다'},
#    {'menus': '케이준 포케/1(소스선택(포케오리지널소스)),부채살스테이크포케/1(소스선택(포케매콤마요소스))',
#     'review_text': '오늘 점심 부터 너무 맛있게 잘먹었습니다!!!!!!\n맛도 양도 너무 짱짱!!!!!!\n \n그런데 밥이 너무 질어서 조금..ㅜ 섞기가 힘들었어요 ㅠ'},
#    {'menus': '한정））생 연어포케（100g）/1(소스선택(포케매콤마요소스),추가 가능 토핑(와사비 게살)),생연어샐러드）200g/1(드레싱 소스 선택(참깨),드레싱 추가(참깨 드레싱 추가),추가 가능 토핑(훈제연어 추가))',
#     'review_text': '오늘도 감사해요 \n잘먹었습니다'},
#    {'menus': '한정））생 연어포케（100g）/1(소스선택(포케매콤마요소스),추가 가능 토핑(훈제연어 추가)),훈제 연어 샐러드/1(드레싱 소스 선택(참깨),포크 추가 선택(포크 추가))',
#     'review_text': '비오는데 넘 잘챙겨주셔서\n감사합니다'},
#    {'menus': '한정））생 연어포케（100g）/1(소스선택(포케매콤마요소스),추가 가능 토핑(훈제연어 추가)),훈제 연어 샐러드/1(드레싱 소스 선택(참깨),포크 추가 선택(포크 추가))',
#     'review_text': '오늘도 감사합니다 \n음료를 챙겨주셔서 넘 감사해요'},
#    {'menus': '한정））생 연어포케（100g）/1(소스선택(포케오리지널소스),추가 가능 토핑(훈제연어 추가)),생연어샐러드）200g/1(드레싱 소스 선택(참깨),드레싱 추가(참깨 드레싱 추가),추가 가능 토핑(훈제연어 추가)),양송이 버섯크림  스프/2',
#     'review_text': '만난 연어덕에 하루가 즐거ㅝ요'},
#    {'menus': '한정））생 연어포케（100g）/1(소스선택(포케오리지널소스),추가 가능 토핑(훈제연어 추가)),양송이 버섯크림  스프/2,생연어샐러드）200g/1(드레싱 소스 선택(참깨),드레싱 추가(참깨 드레싱 추가),추가 가능 토핑(훈제연어 추가),같이 주문시 반값 추가 선택(ICE 헤이즐넛 아메리카노))',
#     'review_text': '오늘도 감사합니다 \n맛있어요'},
#    {'menus': '한정））생 연어포케（100g）/1(소스선택(포케오리지널소스),추가 가능 토핑(훈제연어 추가)),생연어샐러드）200g/1(드레싱 소스 선택(참깨),드레싱 추가(참깨 드레싱 추가),추가 가능 토핑(훈제연어 추가),포크 추가 선택(포크 추가)),양송이 버섯크림  스프/1,까망베르 감자  스프/1',
#     'review_text': '연어 포케먹고\n더 열띰히 운동을ㅋ'},
#    {'menus': '부채살스테이크포케/1(소스선택(포케매콤마요소스))',
#     'review_text': '건강하면서 맛있게먹기에 최고인 메뉴같아요. 정말맛있게 잘먹었습니다~~'},
#    {'menus': '한정））생 연어포케（100g）/1(소스선택(포케오리지널소스),추가 가능 토핑(훈제연어 추가),같이 주문시 반값 추가 선택(ice아메리카노 추가)),생연어샐러드）200g/1(드레싱 소스 선택(참깨),드레싱 추가(참깨 드레싱 추가),추가 가능 토핑(훈제연어 추가),포크 추가 선택(포크 추가)),양송이 버섯크림  스프/1,단호박 크림 스프/1',
#     'review_text': '간만에 시켜도\n언제나 신선신선\n맛있게 잘먹었습니다'},
#    {'menus': '햄치즈에그 샌드위치/1(식빵 선택(통밀식빵),양상추 양(양상추 보통으로주세요（기본）)),할라피뇨 스팀 닭가슴살 샐러드/1(드레싱 소스 선택(발사믹)),리코타 치즈 샐러드/1(드레싱 소스 선택(유자))',
#     'review_text': '항상 신선하고 풍성한 재료에\n맛은 최고.\n배달도 빠르고 다 모두 다\n만족'},
#    {'menus': '베이컨스크램블 샌드위치/1(식빵 선택(통밀식빵),양상추 양(양상추 조금만주세요),같이 주문시 반값 추가 선택(ice아메리카노 추가)),스팀 매콤닭가슴살 샐러드/1(드레싱 소스 선택(발사믹),추가 가능 토핑(훈제연어 추가))',
#     'review_text': '맛도 좋고 재료 밸런스도 좋은 것 같습니다.'},
#    {'menus': '리코타 치즈 샐러드/1(드레싱 소스 선택(발사믹)),할라피뇨 스팀 닭가슴살 샐러드/1(드레싱 소스 선택(발사믹))',
#     'review_text': '채소가 항상 신선해서 좋아요.'},
#    {'menus': '리코타 치즈 샐러드/1(드레싱 소스 선택(드레싱필요 없어용)),훈제연어포케/1,햄치즈에그 샌드위치/1(식빵 선택(통밀식빵),양상추 양(양상추 조금만주세요))',
#     'review_text': '연어훈제포케에 소스가 없이 배달됐어요.\n샐러드, 샌드위치 만족.\n포케도 소스가 추가 되었으면\n만점'},
#    {'menus': '햄치즈에그 샌드위치/1(식빵 선택(통밀식빵),양상추 양(양상추 보통으로주세요（기본）)),저분자 콜라겐 석류 아이스티 500mL 캔시머/1,리얼딸기라떼 500mL 캔시머/1',
#     'review_text': '샌드위치 양 어마어마해서 한번놀라고\n음료수도 양많아 만족합니다\n센스있는 쿠키! 맛있게 잘 먹겠습니다\n다음에도 또 시켜먹을게요~💛🧡💜💙'},
#    {'menus': '생연어샐러드）200g/1(드레싱 소스 선택(참깨),드레싱 추가(참깨 드레싱 추가),포크 추가 선택(포크 추가))',
#     'review_text': '간만에 주문해서\n맛있게 먹었습니다'},
#    {'menus': '핵마약김치볶음밥/1,데리야끼 닭가슴살 랩/1,소불고기 에그 랩/1',
#     'review_text': '사진을 늦게 찍어서...하나만 찍어요\n 맛있게 잘먹었습니다 감사합니다 \n사은품 과자도 감사합니다 ^^♡'},
#    {'menus': '훈제연어포케/1(소스선택(포케오리지널소스),추가 가능 토핑(훈제연어 추가),추가 가능 토핑(소불고기 추가),추가 가능 토핑(와사비 게살)),케이준 샐러드 （치킨은 진리에요）/1(드레싱 소스 선택(오리엔탈),추가 가능 토핑(훈제연어 추가))',
#     'review_text': '맛있어요!!!ㄷ ㅏ 때려넣고 쒜킷쒜킷JMT!!!!'},
#    {'menus': '블루베리 에너지음료/1,치킨텐더 랩/2,훈제오리 샐러드/1(포크 유무 선택(포크 주세요),드레싱소스 선택(발사믹)),목살스테이크 샐러드/1(포크 유무 선택(포크 주세요),드레싱소스 선택(발사믹))',
#     'review_text': '아니 음료가 안왔는데 뭐 어떻게 연락하는 방법도 없고 배달료가 싼것도 아니면서 진짜 어이없네요'},
#    {'menus': '브라운 치즈 크로플/1(포크 유무 선택(포크 주세요),세트메뉴 음료 반값 추가선택(ICE 아메리카노)),치킨텐더 랩/1',
#     'review_text': '오늘도 맛있었어요ㅎ'},
#    {'menus': '과일그래놀라 그릭요거트/2(꿀 선택(꿀 YES)),아메리카노 캔시머/1(HOT or ICE 선택(ICE))',
#     'review_text': '배달 빠르구 맛있어요!! 과일 상태도 좋구 다 먹고 배부를 정도로 양이 많았습니당💃🏻💃🏻'},
#    {'menus': '', 'review_text': '맛있어요!! 요거트는 냉동과일이라 좀 아쉬웠어요 ㅠㅠ'},
#    {'menus': '스팀 닭가슴살 샐러드/1(포크 유무 선택(포크 주세요),드레싱소스 선택(드레싱필요 없어용),음료추천 추가선택(옛날그맛미숫가루)),케이준 샐러드/1(포크 유무 선택(포크 주세요),드레싱소스 선택(드레싱필요 없어용),토핑 추가선택(닭가슴살추가))',
#     'review_text': '너무너무 맛있어요\n오늘 또 시켜먹을라구요\n소스도 삼삼덤덤한 맛으로 샐러드 본연이랑 잘 어우러짐\n너무 튀지않고 좋아요\n특히 미숫가루가 찜질방에서 갓 시켜서 나온 그 맛이랑 비슷해요 맛있습니당 오늘 1리터짜리로 또 시켜 먹을꺼에요'},
#    {'menus': '베이컨 크림파스타 샐러드/1(포크 유무 선택(포크 주세요),드레싱소스 선택(오리엔탈),토핑 추가선택(닭가슴살추가),세트메뉴 음료 반값 추가선택(ICE 아메리카노))',
#     'review_text': '점심으로 먹었는데 아주 구뤠잇 입니다…'},
#    {'menus': '플레인 슈가 크로플/1(포크 유무 선택(포크 주세요),세트메뉴 음료 반값 추가선택(ICE 아메리카노)),통통 쉬프림 듬뿍 샌드위치/1(빵 변경 선택(변경 안 함))',
#     'review_text': '맛있어서 자주 시켜먹어요'},
#    {'menus': '게살와사비마요 샌드위치/1(빵 변경 선택(변경 안 함)),아보카도 듬뿍 샌드위치/1(빵 변경 선택(통밀식빵)),햄치즈에그 토스트/1',
#     'review_text': '맛있네요 자주 주문할게요'},
#    {'menus': '브라운 치즈 크로플/1(포크 유무 선택(포크 주세요)),치킨텐더 랩/1(세트메뉴 음료 반값 추가선택(ICE 아메리카노)),데리야끼 닭가슴살 랩/1(세트메뉴 음료 반값 추가선택(ICE 아메리카노)),훈제오리 샐러드/1(포크 유무 선택(포크 주세요),드레싱소스 선택(드레싱필요 없어용)),목살스테이크 샐러드/1(포크 유무 선택(포크 주세요),드레싱소스 선택(오리엔탈),세트메뉴 음료 반값 추가선택(ICE 아메리카노))',
#     'review_text': '대존마탱 별 다섯갬돠'},
#    {'menus': '브라운 치즈 크로플/1(포크 유무 선택(포크 주세요)),치킨텐더 랩/1',
#     'review_text': '둘다 맛있고 양은 좀 적어요\n랩 담엔 두개시켜서 먹어야겠어요\n자주이용할게요!'},
#    {'menus': '훈제연어리코타샌드위치/1(빵 변경 선택(통밀식빵)),아보카도 듬뿍 샌드위치/1(빵 변경 선택(통밀식빵))',
#     'review_text': '점심으로 시켜먹었는데 알차고 맛있어요~'},
#    {'menus': '리코타 치즈 샐러드/1(포크 유무 선택(포크 주세요),드레싱소스 선택(발사믹),토핑 추가선택(연어추가))',
#     'review_text': '맛있었는데 추가메뉴 확인 잘 부탁드려용'},
#    {'menus': '치킨텐더 랩/2', 'review_text': '항상 잘 먹고 있어요 일요일도 문열면 좋으련만 ㅜㅜ'},
#    {'menus': '플레인 슈가 크로플/1(포크 유무 선택(포크 주세요)),훈제연어리코타샌드위치/1(빵 변경 선택(통밀식빵))',
#     'review_text': '토마토 빼달라는 글을 못보셨나봐요ㅠㅠㅠ'},
#    {'menus': '훈제연어리코타샌드위치/1(빵 변경 선택(변경 안 함),세트메뉴 음료 반값 추가선택(ICE 헤이즐넛 아메리카노))',
#     'review_text': '먹느라 사진을 못찍었는데\n너무맛잇게 잘먹었어요:)\n근처 생긴지 얼마 안된 가게 같은데 또 주문할게요!\n\n훈제연어리코타 샌드위치 정말 맛있네요~\n커피도 양이 많아 좋아요~♡'},
#    {'menus': '목살스테이크 샐러드/3(포크 유무 선택(포크 주세요),드레싱소스 선택(드레싱필요 없어용)),스파이시 쉬림프 베이컨샌드위치/1(빵 변경 선택(변경 안 함)),훈제연어리코타샌드위치/2(빵 변경 선택(변경 안 함)),아보카도 듬뿍 샌드위치/1(빵 변경 선택(변경 안 함))',
#     'review_text': '신선하고 맛있게 잘 먹었습니다 ^^\n샌드위치 하나 만 먹어도 완전 든든해서 좋았습니다 ㅎㅎ'},
#    {'menus': '브라운 치즈 크로플/1(포크 유무 선택(포크 주세요)),햄치즈에그 토스트/1',
#     'review_text': '점심이라 배달이 늦었지만 맛있게 먹었어요'},
#    {'menus': '스팀 매콤닭가슴살 샐러드/1(포크 유무 선택(포크 주세요),드레싱소스 선택(오리엔탈),토핑 추가선택(단호박추가,연어추가))',
#     'review_text': '맛있어요 토핑 추가 금액이 다른 곳 보다 저렴해서 다양하게 먹을 수 있어 좋네요 ㅎㅎ'},
#    {'menus': '데리야끼 닭가슴살 랩/1,소불고기 에그 랩/1',
#     'review_text': '일주일에 여러번 시켜먹을 정도로 괜찮아요 다이어트때 강추'},
#    {'menus': '치킨텐더 랩/1,소불고기 에그 랩/1',
#     'review_text': '배달 빠르고 맛있어요! 소스를 고르게 발라주시면 더 좋을거 같아요'},
#    {'menus': '훈제오리 샐러드/1(포크 유무 선택(포크 안주셔도되요),드레싱소스 선택(오리엔탈),토핑 추가선택(연어추가))',
#     'review_text': '포크 안받는다고 체크했는데 보내주셨네요'},
#    {'menus': '과일그래놀라 그릭요거트/1(꿀 선택(꿀 YES)),소불고기 에그 랩/1(세트메뉴 음료 반값 추가선택(힐링티 프로 빠른 수분충전 음료))',
#     'review_text': '메뉴도 다양하고 맛도 좋아요. 모든 메뉴 하나씩 다 시켜먹어보려구용.'},
#    {'menus': '플레인 슈가 크로플/1(포크 유무 선택(포크 주세요)),치킨텐더 랩/1,데리야끼 닭가슴살 랩/1',
#     'review_text': '맛있고 배달도 빨라요'},
#    {'menus': '과일그래놀라 그릭요거트/1(꿀 선택(꿀 YES)),치킨텐더 랩/1',
#     'review_text': '너무 맛있었어요~! 특히 랩은 너무 커서 깜짝 놀랐어요 ㅎㅎ'},
#    {'menus': '훈제 연어 샐러드/1(포크 유무 선택(포크 주세요),드레싱소스 선택(발사믹),토핑 추가선택(리코타치즈 추가)),단호박닭가슴살 샌드위치/1(빵 변경 선택(통밀식빵))',
#     'review_text': '재료 모두 신선하고 맛있어요 ㅎㅎ\n다른 메뉴도 시켜먹고 싶네요'},
#    {'menus': '과일그래놀라 그릭요거트/1(꿀 선택(꿀 YES)),훈제오리 샐러드/1(포크 유무 선택(포크 안주셔도되요),드레싱소스 선택(드레싱필요 없어용))',
#     'review_text': '배달도 빠르고 재료도 신선하고 맛도 있어요.\n\n사진을 찍어뒀어야 했는데...\n\n잘먹었습니다!'}],
#   'url': 'https://www.yogiyo.co.kr/mobile/#/1029960/'}]

# %% [markdown]
# ## menu_db 만들기
# - menu split
# - filter review_related

# %%
'''
"1367138_1" : {
    "restaurant": "88곱창-분당점",
    "menu": "수박주스x3",
    "url": "https://www.yogiyo.co.kr/mobile/#/1367138/",
    "keywords": ["해장", "숙취해소"],
    "embeddings": [
        ...
    ]
}
'''
# Out:
# '\n"1367138_1" : {\n    "restaurant": "88곱창-분당점",\n    "menu": "수박주스x3",\n    "url": "https://www.yogiyo.co.kr/mobile/#/1367138/",\n    "keywords": ["해장", "숙취해소"],\n    "embeddings": [\n        ...\n    ]\n}\n'

# %%
KEYWORDS_BLACKLIST = ['리뷰', 'zㅣ쀼', 'ZI쀼', 'Zl쀼', '리쀼', '찜', '이벤트', '추가', '소스']
KEYWORDS_CONTEXT = [
    '해장', '숙취',
    '다이어트'
]

# %%
def is_valid_menu(menu_name):
    return True if not any(keyword in menu_name for keyword in KEYWORDS_BLACKLIST) else False

is_valid_menu('[리쀼] 수박 추가')
# Out:
# False

# %%
def extract_keywords(review_text):
    keywords = []

    for word in review_text.split():
        if any(keyword in word for keyword in KEYWORDS_CONTEXT):
            keywords.append(word)
    return keywords

extract_keywords('완전 맛있었어요. 역시 해장에는 수박주스가 답이네요.')
# Out:
# ['해장에는']

# %%
KEYWORDS_BLACKLIST = ['리뷰', 'zㅣ쀼', 'ZI쀼', 'Zl쀼', '찜', '이벤트', '추가']
KEYWORDS_CONTEXT = [
    '해장', '숙취',
    '다이어트'
]

menu_name2id = {}
menu_db = {}

unique_menus = set()
for index, restaurant in enumerate(restaurants_info):
    menu_name2id = {}
    for reviews in restaurant['reviews']:
        menus = reviews["menus"].split(',')
        review_text = reviews["review_text"]

        # 리뷰에 컨텍스트 관련 키워드 있는 지 확인
        keywords = extract_keywords(review_text)

        # 리뷰에 컨텍스트 관련 키워드 없으면 해당 리뷰 스킵
        if keywords == []:
            continue

        for menu in menus:
            menu_name = menu.split('/')[0]
            # 리뷰 이벤트 관련 메뉴 필터링
            if is_valid_menu(menu_name):
                if not menu_name in menu_name2id:
                    menu_idx = len(menu_name2id)
                    menu_id = '_'.join([restaurant['_id'], str(menu_idx)])
                    menu_name2id[menu_name] = menu_id

                    # Menu DB instances format
                    menu_db[menu_id] = {
                        "restaurant": restaurant["restaurant"],
                        "menu": menu_name,
                        "url": restaurant["url"],
                        "keywords": menu_name.split(),
                        "embeddings": None
                    }
                else:
                    menu_id = menu_name2id[menu_name]

                menu_db[menu_id]["keywords"].extend(keywords)

# %%
len(menu_db)
# Out:
# 5

# %%
import sys
sys.path.insert(0, "..")

from utils import get_embedding

for menu_id in menu_db:
    keywords = menu_db[menu_id]["keywords"] + [menu_db[menu_id]["menu"]]
    embedding = get_embedding(" ".join(keywords), model='text-embedding-3-large')
    menu_db[menu_id]["embeddings"] = embedding

# %%
db = client.menu_db
collection = db.menu_info

# %%
for menu_id in menu_db:
    result = collection.update_one({"_id": menu_id}, {"$set": menu_db[menu_id]}, upsert=True)
