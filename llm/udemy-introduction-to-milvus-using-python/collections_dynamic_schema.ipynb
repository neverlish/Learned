# %%
from pymilvus import Collection, FieldSchema, CollectionSchema, DataType, connections, utility
import pandas as pd
import random
import json
import numpy as np

# %%
connections.connect(
  alias="default",
  host='localhost',
  port='19530'
)
utility.drop_collection("dynamic_schema_example")

# %%
## Field Schema

name = FieldSchema(
  name="name",
  dtype=DataType.VARCHAR,
  max_length=200,
)
id = FieldSchema(
  name="id",
  dtype=DataType.INT64,
  is_primary=True,
)
count = FieldSchema(
  name="count",
  dtype=DataType.INT64,
)
vec = FieldSchema(
  name="vector",
  dtype=DataType.FLOAT_VECTOR,
  dim=64
)

# %%
# Collection schema
collection_schema = CollectionSchema(
  fields=[name, id, count, vec],
  description="Dynamic Schema Example",
    enable_dynamic_field=True
)

# %%
# Create collection

collection = Collection(
    name="dynamic_schema_example",
    schema=collection_schema,
    using='default')
utility.list_collections()
# Out:
# ['Album1', 'dynamic_schema_example']

# %%
index_params = {
  "metric_type":"L2",
  "index_type":"IVF_SQ8",
  "params":{"nlist":64},
  "index_name": "vector_index"
}

collection.create_index(
  field_name="vector", 
  index_params=index_params
)
collection.load()

# %%
# Data to be inserted

data = [ {'name': 'a', 'id': 1, 'count': 10, 'vector': [random.uniform(0, 64) for x in range(64)], 'rand':1},
        {'name': 'b', 'id': 2, 'count': 10, 'vector': [random.uniform(0, 64) for x in range(64)], 'rand':2},
        {'name': 'c', 'id': 3, 'count': 10, 'vector': [random.uniform(0, 64) for x in range(64)], 'rand':3},
        {'name': 'd', 'id': 4, 'count': 10, 'vector': [random.uniform(0, 64) for x in range(64)], 'rand':4}]

# %%
# Insert the data in to the collection
collection.insert(data)
# Out:
# (insert count: 4, delete count: 0, upsert count: 0, timestamp: 465515708914860035, success count: 4, err count: 0)

# %%
utility.list_collections()
# Out:
# ['Album1', 'dynamic_schema_example']
