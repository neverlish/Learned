# %%
from pymilvus import connections, utility

# %%
# connections.connect(
#   alias="default",
#   user='username',
#   password='password',
#   host='localhost',
#   port='19530'
# )

# %%
connections.connect(
  alias="default",
  host='localhost',
  port='19530'
)

# %%
utility.list_collections()
# Out:
# []
