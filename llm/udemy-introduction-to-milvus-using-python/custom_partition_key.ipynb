# %%
from pymilvus import Collection, FieldSchema, CollectionSchema, DataType, connections, utility

# %%
connections.connect(
  alias="default",
  host='localhost',
  port='19530'
)
utility.drop_collection("partition_key_collection")

# %%
## Field Schema

song_name = FieldSchema(
  name="song_name",
  dtype=DataType.VARCHAR,
  max_length=200,
)
song_id = FieldSchema(
  name="song_id",
  dtype=DataType.INT64,
  is_primary=True,
)
listen_count = FieldSchema(
  name="listen_count",
  dtype=DataType.INT64,
)
song_vec = FieldSchema(
  name="song_vec",
  dtype=DataType.FLOAT_VECTOR,
  dim=2
)
language = FieldSchema(
  name="language",
  dtype=DataType.VARCHAR,
  max_length=64,
  is_partition_key=True
)

# Collection schema
collection_schema = CollectionSchema(
  fields=[song_name, song_id, listen_count, song_vec, language],
  description="Album Songs"
)

# Create collection

collection = Collection(
    name="partition_key_collection",
    schema=collection_schema,
    partition_key_field="language",
    using='default')

utility.list_collections()
# Out:
# ['Album1', 'dynamic_schema_example', 'partition_key_collection']

# %%
## Vector Similarity Search

results = collection.search(
	data=[[0.1, 0.2]], 
	anns_field="song_vec", 
	param={"metric_type": "L2", "params": {"search_k": 64}},
	limit=5, 
	expr='language=="english"', # Limit the search for a partition key
	output_fields=['song_name']
)

for result in results[0]:
    print (result)
# Out:
# RPC error: [load_collection], <MilvusException: (code=700, message=index not found[collection=partition_key_collection])>, <Time:{'RPC start': '2026-04-10 15:15:17.565198', 'RPC error': '2026-04-10 15:15:17.567051'}>
# ---------------------------------------------------------------------------
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[9], line 5
#       4 # Load the collection in to the memory
# ----> 5 collection.load(replica_number=1)
#       7 results = collection.search(
#       8 	data=[[0.1, 0.2]],
#       9 	anns_field="song_vec",
#    (...)     13 	output_fields=['song_name']
#      14 )
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/orm/collection.py:419, in Collection.load(self, partition_names, replica_number, timeout, **kwargs)
#     418 else:
# --> 419     conn.load_collection(
#     420         collection_name=self._name,
#     421         replica_number=replica_number,
#     422         timeout=timeout,
#     423         **kwargs,
#     424     )
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:140, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     139     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 140     raise e from e
#     141 except grpc.FutureTimeoutError as e:
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:136, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     135     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 136     return func(*args, **kwargs)
#     137 except MilvusException as e:
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:175, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     174     self.set_onetime_request_id(req_id)
# --> 175 return func(self, *args, **kwargs)
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:115, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     114     else:
# --> 115         raise e from e
#     116 except Exception as e:
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:86, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      85 try:
# ---> 86     return func(*args, **kwargs)
#      87 except grpc.RpcError as e:
#      88     # Do not retry on these codes
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/client/grpc_handler.py:1046, in GrpcHandler.load_collection(self, collection_name, replica_number, timeout, **kwargs)
#    1045 response = rf.result()
# -> 1046 check_status(response)
#    1047 _async = kwargs.get("_async", False)
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/client/utils.py:54, in check_status(status)
#      53 if status.code != 0 or status.error_code != 0:
# ---> 54     raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=700, message=index not found[collection=partition_key_collection])>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[9], line 5
#       4 # Load the collection in to the memory
# ----> 5 collection.load(replica_number=1)
#       7 results = collection.search(
#       8 	data=[[0.1, 0.2]],
#       9 	anns_field="song_vec",
#    (...)     13 	output_fields=['song_name']
#      14 )
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/orm/collection.py:419, in Collection.load(self, partition_names, replica_number, timeout, **kwargs)
#     418 else:
# --> 419     conn.load_collection(
#     420         collection_name=self._name,
#     421         replica_number=replica_number,
#     422         timeout=timeout,
#     423         **kwargs,
#     424     )
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:140, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     139     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 140     raise e from e
#     141 except grpc.FutureTimeoutError as e:
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:136, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     135     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 136     return func(*args, **kwargs)
#     137 except MilvusException as e:
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:175, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     174     self.set_onetime_request_id(req_id)
# --> 175 return func(self, *args, **kwargs)
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:115, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     114     else:
# --> 115         raise e from e
#     116 except Exception as e:
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:86, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      85 try:
# ---> 86     return func(*args, **kwargs)
#      87 except grpc.RpcError as e:
#      88     # Do not retry on these codes
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/client/grpc_handler.py:1046, in GrpcHandler.load_collection(self, collection_name, replica_number, timeout, **kwargs)
#    1045 response = rf.result()
# -> 1046 check_status(response)
#    1047 _async = kwargs.get("_async", False)
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/client/utils.py:54, in check_status(status)
#      53 if status.code != 0 or status.error_code != 0:
# ---> 54     raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=700, message=index not found[collection=partition_key_collection])>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
# Cell In[9], line 5
#       2 collection.compact()
#       4 # Load the collection in to the memory
# ----> 5 collection.load(replica_number=1)
#       7 results = collection.search(
#       8 	data=[[0.1, 0.2]],
#       9 	anns_field="song_vec",
#    (...)     13 	output_fields=['song_name']
#      14 )
#      16 for result in results[0]:
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/orm/collection.py:419, in Collection.load(self, partition_names, replica_number, timeout, **kwargs)
#     411     conn.load_partitions(
#     412         collection_name=self._name,
#     413         partition_names=partition_names,
#    (...)    416         **kwargs,
#     417     )
#     418 else:
# --> 419     conn.load_collection(
#     420         collection_name=self._name,
#     421         replica_number=replica_number,
#     422         timeout=timeout,
#     423         **kwargs,
#     424     )
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:140, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     138     record_dict["RPC error"] = str(datetime.datetime.now())
#     139     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 140     raise e from e
#     141 except grpc.FutureTimeoutError as e:
#     142     record_dict["gRPC timeout"] = str(datetime.datetime.now())
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:136, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     134 try:
#     135     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 136     return func(*args, **kwargs)
#     137 except MilvusException as e:
#     138     record_dict["RPC error"] = str(datetime.datetime.now())
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:175, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     173 if req_id:
#     174     self.set_onetime_request_id(req_id)
# --> 175 return func(self, *args, **kwargs)
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:115, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     113         back_off = min(back_off * back_off_multiplier, max_back_off)
#     114     else:
# --> 115         raise e from e
#     116 except Exception as e:
#     117     raise e from e
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/decorators.py:86, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      84 while True:
#      85     try:
# ---> 86         return func(*args, **kwargs)
#      87     except grpc.RpcError as e:
#      88         # Do not retry on these codes
#      89         if e.code() in IGNORE_RETRY_CODES:
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/client/grpc_handler.py:1046, in GrpcHandler.load_collection(self, collection_name, replica_number, timeout, **kwargs)
#    1044 rf = self._stub.LoadCollection.future(request, timeout=timeout)
#    1045 response = rf.result()
# -> 1046 check_status(response)
#    1047 _async = kwargs.get("_async", False)
#    1048 if not _async:
#
# File ~/Desktop/dev/Learned/llm/udemy-introduction-to-milvus-using-python/.venv/lib/python3.11/site-packages/pymilvus/client/utils.py:54, in check_status(status)
#      52 def check_status(status: Status):
#      53     if status.code != 0 or status.error_code != 0:
# ---> 54         raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=700, message=index not found[collection=partition_key_collection])>
