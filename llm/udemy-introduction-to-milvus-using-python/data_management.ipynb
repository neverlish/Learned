# %%
from pymilvus import Collection, FieldSchema, CollectionSchema, DataType, connections, utility
import string
import random

# %%
connections.connect(
  alias="default",
  host='localhost',
  port='19530',
)

# %%
collection = Collection("Album1")
utility.list_collections()
# Out:
# ['Album1']

# %%
## Prepare data to be inserted
num_entities = 5
data = [
  [''.join(random.choices(string.ascii_uppercase, k=7)) for i in range(num_entities)], #song name
  [i for i in range(num_entities)], # Song ID
  [random.randint(0, 100000) for i in range(num_entities)], # Listen Count
  [[random.random() for _ in range(2)] for _ in range(num_entities)] # song_vec - 2d vector
]
print (data)
# Out:
# [['PSQGTUN', 'BALORHM', 'BIUQUGN', 'YAIJTYF', 'AVTLGAE'], [0, 1, 2, 3, 4], [83638, 74074, 84576, 82884, 89948], [[0.0030584825723168896, 0.43588666164833634], [0.16818210972272507, 0.017917652846396903], [0.31162265719023785, 0.7328200849181958], [0.2728336747472827, 0.6484834826652759], [0.9957025623651127, 0.8948508223167612]]]

# %%
# Insert entities
data_insert = collection.insert(data)

# %%
# Delete Entities

expr = "song_id in [0, 20]"
collection.delete(expr)
# Out:
# (insert count: 0, delete count: 2, upsert count: 0, timestamp: 0, success count: 0, err count: 0)

# %%
# Compact collection
collection.compact()
