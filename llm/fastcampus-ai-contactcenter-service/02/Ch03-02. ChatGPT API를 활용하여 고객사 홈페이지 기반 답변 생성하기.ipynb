# %%
# %pip install beautifulsoup4
# %pip install openai
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Collecting openai
#   Downloading openai-1.23.2-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.7 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.1)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.23.2

# %% [markdown]
# ### ChatGPT API를 활용하여 고객사 홈페이지 기반 답변 생성하기

# %% [markdown]
# ##### 1. 홈페이지에서 정보 가져오기

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://fastcampus.co.kr/data_online_aicc?utm_source=facebook&utm_medium=viral&utm_campaign=prd%5E240402%5E236246&utm_content=teacher%5Ekim%5E236246'

response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    print(soup)

else :
    print(response.status_code)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="XVod7Mj_tr8wCzN7n6MEDGH_mFXQbYOWMK0gWzQ7UNc" name="google-site-verification"/>
# <title>25개 실습으로 끝내는 AI 고객센터 서비스 구축 | 패스트캠퍼스</title>
# <meta content="LLM 모델을 통해 Full-Finetuning이 가능한 AI 고객센터 서비스 구축하기" name="description"/>
# <meta content="성인교육, 직무교육, 교육, 교육콘텐츠, 교육서비스, 패스트캠퍼스, 학원, fastcampus, 컨퍼런스, 퓨처콘, futurecon, 온라인, 싱글팩, 프로그래밍, 데이터사이언스, 파이낸스, 마케팅, 비즈니스, 온라인교육, 개발자, 디자이너, 기획자, 마케터, 프로덕트매니저, 디벨로퍼, 퍼포먼스마케터, 데이터사이언티스트, 패스트원, education, conference, programming, developer, finance, business, design, designer, marketing, marketer," name="keywords"/>
# <meta content="25개 실습으로 끝내는 AI 고객센터 서비스 구축 | 패스트캠퍼스" property="og:title"/>
# <meta content="ChatGPT, RAG를 포함한 대표 18가지 기술을 활용한 25개의 실습으로 끝내는 AI 고객센터 서비스 구축의 모든 것
# AI 서비스의 출발점이 되는 AICC, LLM 트레이닝으로 앞으로 발전하는 기술의 보다 빠른 팔로업이 가능해집니다!" property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/221519-1428/light-active-thumb.png" property="og:image"/>
# <meta content="600" property="og:image:width"/>
# <meta content="315" property="og:image:height"/>
# <meta content="https://fastcampus.co.kr/data_online_aicc?utm_source=facebook&amp;utm_medium=viral&amp;utm_campaign=prd%5E240402%5E236246&amp;utm_content=teacher%5Ekim%5E236246" property="og:url"/>
# <meta content="9b30c115aefea86bb156f98c2f214dee71b947c8" name="naver-site-verification"/>
# <link href="https://fastcampus.co.kr/data_online_aicc?utm_source=facebook&amp;utm_medium=viral&amp;utm_campaign=prd%5E240402%5E236246&amp;utm_content=teacher%5Ekim%5E236246" rel="canonical"/>
# <link href="https://storage.googleapis.com/gcs-fastcampus-production-www/assets/img/favicon/favicon-large.ico?2cc0ce3926ad1b32531c53faf7d6adc2" rel="apple-touch-icon"/>
# <link href="https://storage.googleapis.com/gcs-fastcampus-production-www/assets/img/favicon/favicon-large.ico?2cc0ce3926ad1b32531c53faf7d6adc2" rel="shortcut icon" sizes="192x192" type="image/png"/>
# <link href="https://storage.googleapis.com/gcs-fastcampus-production-www/assets/img/favicon/favicon-prod.ico?2cc0ce3926ad1b32531c53faf7d6adc2" rel="shortcut icon" sizes="16x16 32x32 64x64" type="image/x-icon"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="https://storage.googleapis.com/gcs-fastcampus-production-www/assets/img/favicon/favicon-large.ico?2cc0ce3926ad1b32531c53faf7d6adc2" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="https://storage.googleapis.com/gcs-fastcampus-production-www/assets/css/20240403-1712120699777.main.css?2cc0ce3926ad1b32531c53faf7d6adc2" rel="stylesheet"/>
# <script defer="" src="https://storage.googleapis.com/gcs-fastcampus-production-www/assets/js/20240403-1712120699777.main.js?2cc0ce3926ad1b32531c53faf7d6adc2"></script>
# <script src="https://code.jquery.com/jquery-3.5.1.min.js"></script>
# <script src="https://developers.kakao.com/sdk/js/kakao.js"></script>
# <script>
#       const ldJson = `
#     {
#       "@context": "https://schema.org",
#       "@type": "Course",
#       "name": "25개 실습으로 끝내는 AI 고객센터 서비스 구축",
#       "description": "ChatGPT, RAG를 포함한 대표 18가지 기술을 활용한 25개의 실습으로 끝내는 AI 고객센터 서비스 구축의 모든 것",
#       "url": "${window.location.href}",
#       "provider": {
#         "@type": "Organization",
#         "name": "패스트캠퍼스 - Fast campus",
#         "sameAs": "https://fastcampus.co.kr/"
#       }
#     }
#     `;
#       const script = document.createElement('script');
#       script.setAttribute('type', 'application/ld+json');
#       script.textContent = ldJson;
#       document.head.appendChild(script);
#     </script>
# <script type="application/ld+json">
#       {
#         "@context": "https://schema.org",
#         "@type": "FAQPage",
#         "mainEntity": [
#           {
#             "@type": "Question",
#             "name": "결제 취소나 환불은 어떻게 하나요?",
#             "acceptedAnswer": {
#               "@type": "Answer",
#               "text": "결제 취소 및 환불이 필요하신 경우, 고객센터를 통해서 요청해주시기 바랍니다결제 취소 및 환불 내역은 ‘마이페이지 > 거래내역’에서 확인이 가능합니다.<b>환불 신청 절차 안내</b>1. 고객센터(help@fastcampus.co.kr)로 수강생 정보(성함 및 아이디), 강의명을 기재하시어 이메일로 환불 접수를 해주세요.2. 결제 수단에 맞춰 환불이 진행되며, 계좌 입금으로 결제하신 경우에는 환불받으실 계좌도 함께 기재해주시기 바랍니다.3. 이메일로 환불을 요청하신 경우, 카드/가상계좌/이니계좌 환불은 메일 답변 후 바로 취소 처리되며 결제사를 통해 실 환불이 진행되기 때문에 환불완료까지는 최대 3~7일 정도 소요될 수 있습니다.4. 무통장 결제건은 목요일까지 환불계좌정보와 함께 help@fastcampus.co.kr 로 환불 접수해주셨을 경우 다음 주 수~목요일 사이쯤 입금될 예정이오니 참고하셔서 추후 확인해 주시기 바랍니다."
#             }
#           },
#           {
#             "@type": "Question",
#             "name": "온, 오프라인 강의 취소/환불 정책?",
#             "acceptedAnswer": {
#               "@type": "Answer",
#               "text": "<a href = https://fastcampus.co.kr/info/cs/faq>클릭</a>"
#             }
#           },
#           {
#             "@type": "Question",
#             "name": "현금영수증은 어디에서 발급 요청이 가능한가요?",
#             "acceptedAnswer": {
#               "@type": "Answer",
#               "text": "현금영수증은 온라인 결제 시스템을 통해 결제를 진행하실 때, 해당 결제 시스템을 통해 신청이 가능하며 소득공제용(개인), 지출증빙용(사업자) 중 선택하실 수 있습니다.무통장 입금[우리 1005-902-393657 ㈜패스트캠퍼스)]으로 입금을 해주신 경우에는 고객센터(help@fastcampus.co.kr) 이메일 주소로 현금영수증 혹은 지출증빙 영수증을 발급하실 정보(핸드폰 번호 혹은 사업자번호)를 기재하여 따로 요청해주시기 바랍니다."
#             }
#           },
#           {
#             "@type": "Question",
#             "name": "회사 비용으로 처리하기 위해 전자세금계산서를 발급받고 싶습니다.",
#             "acceptedAnswer": {
#               "@type": "Answer",
#               "text": "전자세금계산서 발급을 원하실 경우, 무통장입금 방식으로 결제를 해주셔야 하며 입금하실 전용 계좌번호는 다음과 같습니다.패스트캠퍼스는 면세 사업자로 수강료에 별도의 부가세가 부과되지 않습니다.<b> 수강료 입금 계좌 </b>우리은행 1005-902-393657 패스트캠퍼스㈜전자세금계산서를 발급하실 귀사의 사업자등록증을 파일로 첨부하시어 고객센터 이메일 주소로 전자세금계산서 발행을 요청해주시기 바랍니다. 입금 시, 수강생명 혹은 계산서를 발급하신 회사명과 상이한 정보로 입금하시면 꼭 알려주시기 바랍니다. <b> 상세 안내 </b>1) 수강료 입금 후 발행을 원하실 경우전자계산서 발급을 위해 귀사의 사업자등록증을 PDF파일로 첨부하신 후 '수강생명/교육과정명 / 아이디(계정정보) / 전자계산서를 발급 받을 담당자 이메일 주소 '를 기재하여 고객센터(help@fastcampus.co.kr)로 요청해주세요.2) 수강료 입금 전 청구 발행 요청 시수강하고자 하는 과정의 '수강신청서 제출 '을 먼저 완료 해 주신 후, 전자계산서 발급을 위해 귀사의 사업자등록증을 PDF파일로 첨부하신 후 '수강생명 / 교육과정명 / 아이디(계정정보) / 입금액(수강료) / 입금예정일자 / 전자계산서를 발급 받을 담당자 이메일 주소 '를 상세 기재하여 고객센터(help@fastcampus.co.kr)로 요청해 주시면 입금하실 전용 계좌정보를 안내드립니다. 얼리버드 할인의 경우 결제일자 기준으로 적용됩니다.따라서 전자세금계산서만 발급하시고 입금완료가 되지 않을 경우 수강료는 추후 상향조정될 수 있는 점 참고하시어 할인 마감일을 지켜주시기 바랍니다."
#             }
#           },
#           {
#             "@type": "Question",
#             "name": "수강신청확인서 및 수료증은 어디에서 발급 요청이 가능한가요?",
#             "acceptedAnswer": {
#               "@type": "Answer",
#               "text": "수강신청확인증은 수강료 결제가 완료된 경우, 수강신청을 증빙하기 위해 발급해드리는 증빙 서류이며수료증명서는 강의를 완강하신 경우에 강의 수료를 증빙하기 위해 발급해드리는 증빙 서류입니다. <b>수료증명서 발급 기준 안내 </b>1) 오프라인 강의의 경우 : 강의를 완강하신 경우 발급2) 온라인 강의의 경우 : 80% 이상 수강하신 경우에 발급위 증빙 서류 발급을 희망하실 경우 저희 고객센터(help@fastcampus.co.kr) 이메일 주소로 아이디/수강생명 / 과정명을 기재하여 발급을 요청해주시면 PDF 파일을 첨부하여 메일로 안내해드리고 있습니다."
#             }
#           }
#         ]
#       }
#     </script>
# </head>
# <body>
# <aside class="top-most-banner" style="background-color: #000000;">
# <div class="vn-grid-medium">
# <input class="top-most-banner__input a11y" id="top-most-banner--trigger" type="checkbox"/>
# <div class="top-most-banner__item">
# <a class="top-most-banner__link" href="https://fastcampus.co.kr/event_online_payback_2404">
# <picture class="top-most-banner__picture">
# <source media="(min-width: 960px)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/005131-397/최상단띠배너-pc--4월-페이백-edit01.gif"/>
# <source media="(max-width: 959px)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/005913-397/최상단띠배너-mo--4월-100--페이백.gif"/>
# <img alt="" class="top-most-banner__img" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/005131-397/최상단띠배너-pc--4월-페이백-edit01.gif"/>
# </picture>
# <span class="a11y">2024/4/19-4/25 : [4월 100% 페이백] 최상단 띠배너 </span>
# </a>
# <label class="top-most-banner__trigger" for="top-most-banner--trigger">
# <span class="a11y">상단 배너 닫기</span>
# <svg class="icon--close" height="28" viewbox="0 0 28 28" width="28" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <path d="M0 0H28V28H0z"></path>
# <g class="icon--close__group" fill="#9B9BA0" transform="translate(6 6)">
# <rect height="18" rx="1" transform="rotate(-135 8 8)" width="2" x="7" y="-1"></rect>
# <rect height="18" rx="1" transform="rotate(-45 8 8)" width="2" x="7" y="-1"></rect>
# </g>
# </g>
# </svg>
# </label>
# </div>
# </div>
# </aside>
# <header class="header fc-theme--light" data-b2b-menu='{"state":"NORMAL","title":"기업교육","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[{"state":"NORMAL","title":"Future Report for HRD","hideAt":"","imgUrl":null,"showAt":"","assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"","subtitle":"\n","droppable":false,"titleLink":"/b2b_report","categoryId":null,"linkTarget":"","subCategoryId":null},{"state":"NORMAL","title":"기업교육 서비스 소개","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"","subtitle":"\n","droppable":false,"titleLink":"/b2b_main","categoryId":null,"linkTarget":"","subCategoryId":null},{"state":"NORMAL","title":"온라인 교육 구독 서비스","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"","subtitle":"\n","droppable":false,"titleLink":"/b2b_online_forbiz","categoryId":null,"linkTarget":"","subCategoryId":null},{"state":"NORMAL","title":"맞춤형 기업교육 설계","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"","subtitle":"\n","droppable":false,"titleLink":"/b2b_fast_custom","categoryId":null,"linkTarget":"","subCategoryId":null},{"state":"NORMAL","title":"온라인 세미나","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"","subtitle":"\n","droppable":false,"titleLink":"/b2b_onlineseminar","categoryId":null,"linkTarget":"","subCategoryId":null},{"state":"NORMAL","title":"도입 사례","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"","subtitle":"\n","droppable":false,"titleLink":"/b2b_story","categoryId":null,"linkTarget":"","subCategoryId":null},{"state":"NORMAL","title":"HR Insight","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"","subtitle":"\n","droppable":false,"titleLink":"/b2b_insight","categoryId":null,"linkTarget":"","subCategoryId":null}],"menuType":"","subtitle":"\n","titleLink":"","categoryId":null,"linkTarget":"","subCategoryId":null}' data-design-theme="LIGHT" data-gnb-menu='[{"state":"NORMAL","title":"카테고리","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[{"state":"NORMAL","title":"프로그래밍","imgUrl":"https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202107/043549-406/ico-prog-large.svg","assetId":61230,"tagline":"","bannerId":null,"children":[{"state":"NORMAL","title":"🏆 BEST 프로그래밍 강의","hideAt":"","imgUrl":null,"showAt":"","assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"CATEGORY","subtitle":"\n","titleLink":"category_dev_2023branding","categoryId":10,"linkTarget":"","subCategoryId":null},{"state":"NORMAL","title":"프론트엔드 개발","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"CATEGORY","subtitle":"\n","titleLink":"category_online_programmingfront","categoryId":10,"linkTarget":"","subCategoryId":33},{"state":"NORMAL","title":"백엔드 개발","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"CATEGORY","subtitle":"\n","titleLink":"category_online_programmingback","categoryId":10,"linkTarget":"","subCategoryId":32},{"state":"NORMAL","title":"모바일 앱 개발","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"CATEGORY","subtitle":"\n","titleLink":"category_online_programmingapp","categoryId":10,"linkTarget":"","subCategoryId":36},{"state":"NORMAL","title":"DevOps/Infra","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"CATEGORY","subtitle":"\n","titleLink":"category_online_programmingdevops","categoryId":10,"linkTarget":"","subCategoryId":35},{"state":"NORMAL","title":"블록체인 개발","hideAt":"","imgUrl":null,"showAt":"","assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"CATEGORY","subtitle":"\n","titleLink":"category_online_programmingblockchain","categoryId":10,"linkTarget":"","subCategoryId":110},{"state":"NORMAL","title":"게임 개발","imgUrl":null,"assetId":null,"tagline":"","bannerId":null,"children":[],"menuType":"CAT ...
# <h1 class="a11y">25개 실습으로 끝내는 AI 고객센터 서비스 구축</h1>
# <h2 class="a11y">AICC</h2>
# <h2 class="a11y">LLM 서비스</h2>
# </header>
# </body>
# </html>
# <main class="main main--flat" data-category-code="DATASCIENCEDL" data-category-id="39" data-course-id="236246" data-course-promotion="true" data-discount-percent="58" data-format-id="6" data-has-products="2" data-hide-at="Mon Apr 22 2024 14:59:00 GMT+0000 (Coordinated Universal Time)" data-list-price="600,000" data-page-id="52115" data-product-discount-amount="351,000" data-product-id="258434" data-product-sale-due-date="4월 22일 월요일 23시" data-product-title="[100% 페이백 이벤트 : 5월 8일 쿠폰 자동발급]25개 실습으로 끝내는 AI 고객센터 서비스 구축" data-sale-price="249,000" data-split-price="20,750" data-subcategory-code="DATASCIENCE_DEEP" data-subcategory-id="126" id="main" role="main">
# <h2 class="a11y">LLM 서비스</h2>
# <aside id="banner-event-top"></aside>
# <section class="fc-block fc-layout fc-layout-103">
# <div class="container-fluid" style="padding-top: 7rem; padding-bottom: 39rem;">
# <div class="container">
# <p class="container__text-content fc-h5-text" style="color: #000000;; "><span style="display:inline-block; padding:8px 20px 8px 20px; background-color:#fff; border-radius:6px; color:#000; font-size:15px; color: #000; margin-bottom: 16px;">
# <b>Online.</b></span><br/>
# <span style="font-size:28px; color:#fff;;"><b>25개 실습으로 끝내는<br/>
# AI 고객센터 서비스 구축</b></span>
# </p>
# </div>
# <div class="container-color" style="background: #000; opacity: 0"></div>
# <picture>
# <source media="(min-width: 64.1rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/183309-1428/1-2.webp"/>
# <source media="(max-width: 64rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/200707-1428/폰4.webp"/>
# <img alt="" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/183309-1428/1-2.webp"/>
# </picture>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 1rem;
#        padding-bottom: 1rem;
#        background-color: #000">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-405">
# <div class="container-fluid" style="padding-top: 2rem; padding-bottom: 2rem; background-color: #000">
# <ul class="container fc-list" style="color: #fff; --grid-gap: none">
# <li class="fc-list__item" style="background-color: #222222; ">
# <div class="fc-list__wrap">
# <p class="fc-list__main-text fc-h6-text"><b>LLM 기술을 모두 배울 수 있는 All-in-one 서비스, AI 고객센터 </b></p>
# <p class="fc-list__sub-text fc-content-text">감성 분석부터 텍스트 처리까지 LLM 작동 원리와 모델 학습을 한 번에 이해하고 서비스로 적용 가능</p>
# </div>
# </li>
# <li class="fc-list__item" style=" background-color: #222; ">
# <div class="fc-list__wrap">
# <p class="fc-list__main-text fc-h6-text"><b>실무에 바로 적용 가능한 AI 고객센터를 25개 실습으로 완성하기</b></p>
# <p class="fc-list__sub-text fc-content-text">패스트캠퍼스에서 준비한 25개 프로젝트와
# 고객센터 운영 필수 18가지 기술 모두 활용</p>
# </div>
# </li>
# <li class="fc-list__item" style=" background-color: #222; ">
# <div class="fc-list__wrap">
# <p class="fc-list__main-text fc-h6-text"><b>국내 Top-tier 기업 현직자도 인정한 소장하고 싶은 완벽 커리큘럼 </b></p>
# <p class="fc-list__sub-text fc-content-text">네이버, 국내 대표 AICC 기업 등 국내 Top-tier 기업 현직자들이 직접 추천한 커리큘럼으로 구성</p>
# </div>
# </li>
# </ul>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-501">
# <div class="container-fluid" style="background-color: #000">
# <div class="container">
# <div class="accordion">
# <div class="accordion-tab" style="background-color: #202020; border-color: #333">
# <label>
# <input type="checkbox"/>
# <h3 class="accordion-tab__title" style="color: #fff">
#             기본정보
#             <svg class="fold" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <path d="M0 0H32V32H0z" fill="#FFF" fill-opacity="0"></path>
# <path d="M10 13L15.951 19 22 13" stroke="#6e6e73" stroke-width="2" transform="rotate(-180 16 16)"></path>
# </g>
# </svg>
# <svg class="unfold" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <path d="M0 0H32V32H0z" fill="#FFF" fill-opacity="0"></path>
# <path d="M10 13L15.951 19 22 13" stroke="#6e6e73" stroke-width="2"></path>
# </g>
# </svg>
# </h3>
# <p class="accordion-tab__content" style="border-color: #333;color: #fff">
#             ㆍ10개 대주제,  41여개 강의 클립 (약 15시간 분량)<br/>
# ㆍ실전 - 심화
# <br/>
# ㆍ선수 지식 : ML/DL에 대한 배경 지식이 있는 수준
#
#           </p>
# </label>
# </div>
# <div class="accordion-tab" style="background-color: #202020; border-color: #333">
# <label>
# <input type="checkbox"/>
# <h3 class="accordion-tab__title" style="color: #fff">
#             강의특징
#             <svg class="fold" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <path d="M0 0H32V32H0z" fill="#FFF" fill-opacity="0"></path>
# <path d="M10 13L15.951 19 22 13" stroke="#6e6e73" stroke-width="2" transform="rotate(-180 16 16)"></path>
# </g>
# </svg>
# <svg class="unfold" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
# <g fill="none" fill-rule="evenodd">
# <path d="M0 0H32V32H0z" fill="#FFF" fill-opacity="0"></path>
# <path d="M10 13L15.951 19 22 13" stroke="#6e6e73" stroke-width="2"></path>
# </g>
# </svg>
# </h3>
# <p class="accordion-tab__content" style="border-color: #333; color: #fff">
#             ㆍ수강료 1회 결제로 평생 소장
# <br/>
# ㆍ부가 학습 자료 제공
# <br/>
# ㆍ질의응답 제공
#
#           </p>
# </label>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 2rem;
#        padding-bottom: 2rem;
#        background-color: #000">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-912">
# <div class="container-fluid">
# <div class="container"><div class="skeleton__image"></div></div>
# <div class="container theme-white">
# <div class="fc-txt">코스 프로모션 배너 전용입니다.</div>
# <div class="fc-timer-container">
# <span class="fc-timer-days fc-timer-box"><span>0</span>일</span>
# <span class="fc-timer-hours fc-timer-box"><span>0</span>시간</span>
# <span class="fc-timer-minutes fc-timer-box"><span>0</span>분</span>
# <span class="fc-timer-seconds fc-timer-box"><span>0</span>초</span>
# <span class="fc-timer-target-time"> 코스 프로모션 배너 전용입니다. </span>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-901">
# <div class="container-fluid" data-chart-content="" data-chart-title="제목을 입력해주세요." data-show-graph="false" data-use-new-tab="false">
# <div class="container">
# <div class="vbox">
# <div class="hbox">
# <strong class="product-title">(자동)</strong>
# </div>
# <div class="hbox payment-card has-installment">
# <div class="vbox">
# <div class="hbox">
# <span class="list-price title">정가</span>
# <s class="list-price sale">(자동)</s>
# </div>
# <div class="hbox">
# <span class="price-txt title">할인 금액</span>
# <span class="sale-price sale">(자동)</span>
# </div>
# </div>
# <div class="vbox">
# <div class="hbox">
# <div class="hbox salePrice">
# <span class="title">현재 판매가</span>
# <span class="sale">(자동)</span>
# </div>
# <div class="hbox splitPrice">
# <p>(자동)</p>
# <span>* 12개월 무이자 할부 시</span>
# </div>
# </div>
# </div>
# <div class="vbox">
# <div class="hbox">
# <a class="payment-btn" href="#">
# <span class="payment-txt">바로 구매하기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #000; padding-top: 4.5rem; padding-bottom: 0rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h6-text" style="color: #A873FF">
# <b>[전 세계 AI 고객센터 시장 규모 전망] <br/>
# </b></p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #000; padding-top: 1rem; padding-bottom: 1.5rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h5-text" style="color: #fff">
# <b>5년 만에 300% 초고속 성장한 <br/>
# AI 고객센터 서비스</b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-201">
# <div class="container-fluid" style="background-color: #000">
# <div class="container">
# <picture class="container__picture container__picture--center">
# <source media="(min-width: 64.1rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/183048-1428/2.webp"/>
# <source media="(max-width: 64rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/183048-1428/2.webp"/>
# <img alt="세계 AI 고객센터 시장 규모 전망" class="container__image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/183048-1428/2.webp" style="width: 45rem;"/>
# </picture>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 0.5rem;
#        padding-bottom: 0.5rem;
#        background-color: #000">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-103">
# <div class="container-fluid" style="padding-top: 8rem; padding-bottom: 8rem;">
# <div class="container">
# <p class="container__text-content fc-h5-text" style="color: #fff;; "><b>국내외 Top-tier 기업들 역시 빠르게 도입하고 있습니다.</b></p>
# </div>
# <div class="container-color" style="background: #000; opacity: 0"></div>
# <picture>
# <source media="(min-width: 64.1rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/183134-1428/3.webp"/>
# <source media="(max-width: 64rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/104655-1427/frame-1321314623-b-m.webp"/>
# <img alt="" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/183134-1428/3.webp"/>
# </picture>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 2.5rem;
#        padding-bottom: 2.5rem;
#        background-color: #EEEEEE">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-201">
# <div class="container-fluid" style="background-color: #EEEEEE">
# <div class="container">
# <picture class="container__picture container__picture--center">
# <source media="(min-width: 64.1rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/234623-1428/수정4.webp"/>
# <source media="(max-width: 64rem)" srcset=""/>
# <img alt="AICC 문제점" class="container__image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/234623-1428/수정4.webp" style="width: 80rem;"/>
# </picture>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-201">
# <div class="container-fluid" style="background-color: #EEEEEE">
# <div class="container">
# <picture class="container__picture container__picture--center">
# <source media="(min-width: 64.1rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/234416-1428/수정3.webp"/>
# <source media="(max-width: 64rem)" srcset=""/>
# <img alt="AICC 문제점" class="container__image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/234416-1428/수정3.webp" style="width: 35rem;"/>
# </picture>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #EEEEEE; padding-top: 3rem; padding-bottom: 4rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h3-text" style="color: 000000">
# <b>확실한 성과와 고객 만족도로 인정받은 <br/><span style="color:#4A26B4;">AI 고객센터</span></b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #1A1A1A; padding-top: 6rem; padding-bottom: 3rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h5-text" style="color: #fff">
# <b>하지만 고도화되지 않은 AI 고객센터 서비스<br/>구축 시 발생하는 <span style="color:#F53838;"> 문제점</span></b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-201">
# <div class="container-fluid" style="background-color: #1A1A1A">
# <div class="container">
# <picture class="container__picture container__picture--center">
# <source media="(min-width: 64.1rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/182859-1428/5.webp"/>
# <source media="(max-width: 64rem)" srcset=""/>
# <img alt="AICC 문제점" class="container__image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/182859-1428/5.webp" style="width: 80rem;"/>
# </picture>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 0.5rem;
#        padding-bottom: 0.5rem;
#        background-color: #1A1A1A">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-201">
# <div class="container-fluid" style="background-color: #1A1A1A">
# <div class="container">
# <picture class="container__picture container__picture--center">
# <source media="(min-width: 64.1rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/160334-199/dots.png"/>
# <source media="(max-width: 64rem)" srcset=""/>
# <img alt="AICC 문제점" class="container__image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/160334-199/dots.png" style="width: 35rem;"/>
# </picture>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #1A1A1A; padding-top: 2rem; padding-bottom: 4rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h5-text" style="color: #FFFFFF">
# <b>더 이상 해결하지 않고 <span style="color:#F53838;"> 방치</span>하실 건가요?</b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #1A1A1A; padding-top: 1rem; padding-bottom: 6rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h6-text" style="color: #fff">
# <b>이제는 AI 고객센터를 직접 구축해야 할 차례입니다.<br/>
# 이 강의 하나로 AI 고객센터 서비스 구축의 모든 것을 학습하세요!</b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-201">
# <div class="container-fluid" style="background-color: #ffffff">
# <div class="container">
# <picture class="container__picture container__picture--center">
# <source media="(min-width: 64.1rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202403/110328-1427/union.webp"/>
# <source media="(max-width: 64rem)" srcset=""/>
# <img alt="AICC 문제점" class="container__image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202403/110328-1427/union.webp" style="width: 35rem;"/>
# </picture>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #fff; padding-top: 5rem; padding-bottom: 0rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h1-text" style="color: #000000">
# <span style="color: #fff; background: #4A25B3; border-radius: 6px; margin-right: 0px; text-align: center;  font-size: 1.5rem; font-weight: bold; padding: 8px 40px 8px 40px; display: inline-block;margin-bottom: 0px;">Point 1</span>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #fff; padding-top: 1.5rem; padding-bottom: 0rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h5-text" style="color: #000000">
# <b>25개 프로젝트로 완성하는<br/>
# <span style="color:#4A25B3;"> AI 고객센터 실 서비스</span> 만들기 </b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #fff; padding-top: 1rem; padding-bottom: 3rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-content-text" style="color: #000">
# <b>AI 고객센터에서 사용하고 있는 실제 서비스</b>를 <br/>
# 단계별로 학습 가능합니다.
#       </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-201">
# <div class="container-fluid" style="background-color: #fff">
# <div class="container">
# <picture class="container__picture container__picture--center">
# <source media="(min-width: 64.1rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/182557-1428/6.webp"/>
# <source media="(max-width: 64rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/182557-1428/6.webp"/>
# <img alt="AI 고객센터" class="container__image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/182557-1428/6.webp" style="width: 80rem;"/>
# </picture>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 2.25rem;
#        padding-bottom: 2.25rem;
#        background-color: #FFFFFF">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-201">
# <div class="container-fluid" style="background-color: #F5F3FE">
# <div class="container">
# <picture class="container__picture container__picture--center">
# <source media="(min-width: 64.1rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/191807-1428/union.webp"/>
# <source media="(max-width: 64rem)" srcset=""/>
# <img alt="AICC 문제점" class="container__image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/191807-1428/union.webp" style="width: 35rem;"/>
# </picture>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #F5F3FE; padding-top: 4rem; padding-bottom: 3rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h5-text" style="color: #000000">
# <b>단계별 학습을 통해 <br/><span style="color:#4A25B3;"> AI 고객센터 서비스를 완성해 보세요!</span></b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-201">
# <div class="container-fluid" style="background-color: #ffffff">
# <div class="container">
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-206">
# <div class="container-fluid" style="background-color: #F5F3FE">
# <div class="container">
# <div class="container__body">
# <div class="container__column" style="width: 30rem">
# <img alt="" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/182231-1428/7.webp"/>
# </div>
# <div class="container__column" style="color: #000">
# <div class="container__text">
# <div class="container__title text--h6"><span style="color:#4A25B3;"><span style="font-size:14px;">Step 1</span><br/>
# <span style="color:#000;">AI 고객센터 서비스 이해</span></span></div>
# <div class="container__content text--content1">
# ㆍLLM 작동 원리 (Deep  learning, Training, Fine-tuning, Prompt Engineering)  <br/>
# ㆍLLM 모델 학습 (ChatGPT, LLaMa, Gemini, Open Source LLM)<br/>
# ㆍAI 고객센터 이해 (전체 서비스 구성, 데이터 파이프라인 구축, QA 시스템 구축)</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-003">
# <div class="container-fluid" style="background-color: #F5F3FE">
# <div class="container" style="padding-top: 3rem;padding-bottom: 3rem;">
# <hr style="border-top: 0.1rem solid #B9AAE3;"/>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-206">
# <div class="container-fluid" style="background-color: #F5F3FE">
# <div class="container">
# <div class="container__body">
# <div class="container__column" style="width: 30rem">
# <img alt="" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/182251-1428/8.webp"/>
# </div>
# <div class="container__column" style="color: #000000">
# <div class="container__text">
# <div class="container__title text--h6"><span style="color:#4A25B3;"><span style="font-size:14px;">Step 2</span> <span style="color:#000;"> <br/>
# AI 고객센터 서비스 구축</span></span></div>
# <div class="container__content text--content1">
# ㆍAI 고객센터 대표 서비스 구축 (Chatbot, Voicebot, Assist) <br/>
# ㆍAI 고객센터 산업별 서비스 구축 (Ecommerce, Finance)<br/></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-003">
# <div class="container-fluid" style="background-color: #F5F3FE">
# <div class="container" style="padding-top: 3rem;padding-bottom: 3rem;">
# <hr style="border-top: 0.1rem solid #B9AAE3;"/>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-206">
# <div class="container-fluid" style="background-color: #F5F3FE">
# <div class="container">
# <div class="container__body">
# <div class="container__column" style="width: 30rem">
# <img alt="" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/182300-1428/9.webp"/>
# </div>
# <div class="container__column" style="color: #000000">
# <div class="container__text">
# <div class="container__title text--h6"><span style="color:#4A25B3;"><span style="font-size:14px;">Step 3</span> <span style="color:#000;"> <br/>
# AI 고객센터 서비스 운영</span></span></div>
# <div class="container__content text--content1">
# ㆍ최신 AI 고객 서비스 사례 소개 <br/>
# ㆍ서비스 호스팅 방법 노하우<br/>
# ㆍ성공적인 전망 및 제언</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 2.5rem;
#        padding-bottom: 2.5rem;
#        background-color: #F5F3FE">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #1A1A1A; padding-top: 6rem; padding-bottom: 1rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h5-text" style="color: #A873FF">
# <b>이런 분들이라면 주목하세요! </b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #1A1A1A; padding-top: 0rem; padding-bottom: 3rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-content-text" style="color: #fff">
#         남들보다 빠른 속도로 AI 고객센터를 만들고 싶은 누구나 지원 및 수강이 가능합니다.<br/>
# 특히, 아래 유형에 해당하는 분들께 강력하게 추천 드립니다.
#       </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-211">
# <div class="container-fluid" style="padding-top: 0rem;
#              padding-bottom: 6rem;
#              background-color: #1A1A1A">
# <div class="container theme-light-red">
# <div class="container__body">
# <div class="carousel">
# <ul class="carousel__cards carousel__cards--column-3" data-column-count="3">
# <li class="carousel__card">
# <div class="card__image">
# <img alt="" class="image" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/182452-1428/10.webp">
# </img></div>
# </li>
# <li class="carousel__card">
# <div class="card__image">
# <img alt="" class="image" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/182523-1428/11.webp">
# </img></div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #fff; padding-top: 4rem; padding-bottom: 0rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h1-text" style="color: #000000">
# <span style="color: #fff; background: #4A25B3; border-radius: 6px; margin-right: 0px; text-align: center;  font-size: 1.5rem; font-weight: bold; padding: 8px 40px 8px 40px; display: inline-block;margin-bottom: 0px;">Point 2</span>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #fff; padding-top: 1.5rem; padding-bottom: 0rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h5-text" style="color: #000000">
# <b>고객센터 운영 효율화<br/>
# <span style="color:#4A25B3;">필수 18가지 기술 활용</span></b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #fff; padding-top: 1rem; padding-bottom: 0rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-content-text" style="color: #000">
#         AI 엔지니어들이 서비스 구축에 가장 많이 활용하는 <br/>ChatGPT, RAG 등
# 필수 18가지 기술을 학습하세요.
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 2rem;
#        padding-bottom: 2rem;
#        background-color: #ffffff">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-403">
# <div class="container-fluid" style="background-color: #ffffff">
# <div class="container container--center">
# <div class="container__content container__content--row container__content--border-size-1" style="width: 98rem; border-color: #916BFF;  background-color: #ECE7F7">
# <p class="fc-h6-text" style="color: #4A25B3">
# <b>Part 01.  AI 고객센터 대표 서비스 구축
# </b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 1.5rem;
#        padding-bottom: 1.5rem;
#        background-color: #ffffff">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-211">
# <div class="container-fluid" style="padding-top: 0rem;
#              padding-bottom: 0rem;
#              background-color: #fff">
# <div class="container theme-light-red">
# <div class="container__body">
# <div class="carousel">
# <ul class="carousel__cards carousel__cards--column-2" data-column-count="2">
# <li class="carousel__card">
# <div class="card__image">
# <img alt="" class="image" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/205407-1428/kakaotalk-photo-2024-04-05-20-53-42.gif">
# </img></div>
# </li>
# <li class="carousel__card">
# <div class="card__image">
# <img alt="" class="image" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/205726-1428/2.gif">
# </img></div>
# </li>
# <li class="carousel__card">
# <div class="card__image">
# <img alt="" class="image" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/205735-1428/3.gif">
# </img></div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 1.5rem;
#        padding-bottom: 1.5rem;
#        background-color: #ffffff">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-403">
# <div class="container-fluid" style="background-color: #ffffff">
# <div class="container container--center">
# <div class="container__content container__content--row container__content--border-size-1" style="width: 98rem; border-color: #916BFF;  background-color: #ECE7F7">
# <p class="fc-h6-text" style="color: #4A25B3">
# <b>Part 02.  AI 고객센터 산업별 서비스 구축
# </b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 1.5rem;
#        padding-bottom: 1.5rem;
#        background-color: #ffffff">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-211">
# <div class="container-fluid" style="padding-top: 0rem;
#              padding-bottom: 4rem;
#              background-color: #fff">
# <div class="container theme-light-red">
# <div class="container__body">
# <div class="carousel">
# <ul class="carousel__cards carousel__cards--column-3" data-column-count="3">
# <li class="carousel__card">
# <div class="card__image">
# <img alt="" class="image" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/205746-1428/4.gif">
# </img></div>
# </li>
# <li class="carousel__card">
# <div class="card__image">
# <img alt="" class="image" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/205756-1428/5.gif">
# </img></div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 2.5rem;
#        padding-bottom: 2.5rem;
#        background-color: #F5F3FE">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-403">
# <div class="container-fluid" style="background-color: #F5F3FE">
# <div class="container container--center">
# <div class="container__content container__content--row container__content--border-size-1" style="width: 98rem; border-color: #916BFF;  background-color: #916BFF">
# <p class="fc-h6-text" style="color: #FFFFFF">
# <b>Final.  강의 수강 후 최종 프로젝트
# </b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 1.5rem;
#        padding-bottom: 1.5rem;
#        background-color: #F5F3FE">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-201">
# <div class="container-fluid" style="background-color: #F5F3FE">
# <div class="container">
# <picture class="container__picture container__picture--center">
# <source media="(min-width: 64.1rem)" srcset="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/163757-1427/gif-6---llm-기반-ai-고객센터.gif"/>
# <source media="(max-width: 64rem)" srcset=""/>
# <img alt="AI 고객센터 서비스" class="container__image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/163757-1427/gif-6---llm-기반-ai-고객센터.gif" style="width: 98rem;"/>
# </picture>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-405">
# <div class="container-fluid" style="padding-top: 2rem; padding-bottom: 8rem; background-color: #F5F3FE">
# <ul class="container fc-list" style="color: #000000; --grid-gap: none">
# <li class="fc-list__item" style="background-color: #fff;  text-align: center;">
# <div class="fc-list__wrap">
# <p class="fc-list__sub-text fc-content-text">AI 엔진(STT, TTS, NLP 등)을 활용한 대표적인 AI 고객센터 서비스를 직접 만들어 보고<br/>
# AICC 상품을 개발하여 솔루션을 직접 도입할 수 있습니다. </p>
# </div>
# </li>
# </ul>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #1A1A1A; padding-top: 6rem; padding-bottom: 0rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h1-text" style="color: #000000">
# <span style="color: #fff; background: #916BFF; border-radius: 6px; margin-right: 0px; text-align: center;  font-size: 1.5rem; font-weight: bold; padding: 8px 40px 8px 40px; display: inline-block;margin-bottom: 0px;">Point 3</span>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #1A1A1A; padding-top: 1.5rem; padding-bottom: 0rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h5-text" style="color: #fff">
# <b>국내 Top-tier 기업<br/>현직자가 인정한
# <span style="color:#916BFF;">추천 커리큘럼</span></b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #1A1A1A; padding-top: 1rem; padding-bottom: 3rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-content-text" style="color: #fff">
#         국내 대표 기업 현직자도 듣고 싶은 <br/>
# 웰메이드 강의를 경험해 보세요!
#       </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-212">
# <div class="container-fluid" style="
#     padding-top: 0rem;
#     padding-bottom: 6rem;
#     background-color: #1A1A1A;
#   ">
# <div class="container theme-light-red">
# <div class="container__body">
# <div class="carousel">
# <ul class="carousel__cards carousel__cards--column-3" data-autoplay="true" data-column-count="3" data-delay="2500" data-shuffle="false">
# <li class="carousel__card">
# <div class="card__image">
# <img alt="" class="image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/181413-1428/15.webp">
# </img></div>
# </li>
# <li class="carousel__card">
# <div class="card__image">
# <img alt="" class="image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/181452-1428/16.webp">
# </img></div>
# </li>
# <li class="carousel__card">
# <div class="card__image">
# <img alt="" class="image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/181526-1428/17.webp">
# </img></div>
# </li>
# <li class="carousel__card">
# <div class="card__image">
# <img alt="" class="image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/181533-1428/18.webp">
# </img></div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #916BFF; padding-top: 4rem; padding-bottom: 0.5rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h5-text" style="color: #000000">
# <span style="color:#fff;"> <b>여기서 끝이 아닙니다!<br/>
# 압도적인 연사진의 전문 지식도 함께 얻어 가세요</b></span>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #916BFF; padding-top: 0rem; padding-bottom: 4rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h6-text" style="color: #fff">
#         AI 고객센터 도입 Top-tier 기업 실무자와 소통하세요!
#       </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #fff; padding-top: 6rem; padding-bottom: 0rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h1-text" style="color: #000000">
# <span style="color: #fff; background: #4A25B3; border-radius: 6px; margin-right: 0px; text-align: center;  font-size: 1.5rem; font-weight: bold; padding: 8px 40px 8px 40px; display: inline-block;margin-bottom: 0px;">Plus 1</span>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #fff; padding-top: 1.5rem; padding-bottom: 0rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-h5-text" style="color: #000000">
# <b>마이크로소프트와 대기업 L사<br/>
# AI 개발자의 <span style="color:#4A25B3;">실무 노하우</span></b>
# </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-101">
# <div class="container-fluid" style="background: #fff; padding-top: 1rem; padding-bottom: 3rem">
# <div class="container">
# <div class="vbox fc-text-align-center">
# <p class="container__text-content fc-content-text" style="color: #000000">
#         원활한 AI 고객센터 운영을 위해 전문가가 실무에서 적용한
#  <br/>성공 사례를 기반으로 서비스 운영 방법을 학습합니다.
#       </p>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-203">
# <div class="container-fluid" style="background-color: #ffffff;">
# <div class="container">
# <div class="container__cards" style="color: #000000">
# <div class="container__card">
# <img alt="" class="container__card-image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/181325-1428/19.webp"/>
# <h5 class="container__card-title fc-h6-text">01 ｜ 국내외 기업 서비스 사례</h5>
# <p class="container__card-content fc-content-text">원활한 AI 고객센터 운영을 위해 전문가가 실무에서 적용한 성공 사례를 기반으로 서비스 운영 방법을 학습합니다. </p>
# </div>
# <div class="container__card">
# <img alt="" class="container__card-image" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/181344-1428/20.webp"/>
# <h5 class="container__card-title fc-h6-text">02 ｜ 고객센터 운영 노하우 학습</h5>
# <p class="container__card-content fc-content-text">카카오톡 채널 관리, AWS 호스팅, On premise vs Cloud 비용 비교를 통해 제품/서비스에 적합한 고객센터 운영 노하우를 학습합니다.</p>
# </div>
# <div class="container__card">
# ...
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 2rem;
#        padding-bottom: 2rem;
#        background-color: #F2F2F2">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-901">
# <div class="container-fluid" data-chart-content="" data-chart-title="제목을 입력해주세요." data-show-graph="false" data-use-new-tab="false">
# <div class="container">
# <div class="vbox">
# <div class="hbox">
# <strong class="product-title">(자동)</strong>
# </div>
# <div class="hbox payment-card has-installment">
# <div class="vbox">
# <div class="hbox">
# <span class="list-price title">정가</span>
# <s class="list-price sale">(자동)</s>
# </div>
# <div class="hbox">
# <span class="price-txt title">할인 금액</span>
# <span class="sale-price sale">(자동)</span>
# </div>
# </div>
# <div class="vbox">
# <div class="hbox">
# <div class="hbox salePrice">
# <span class="title">현재 판매가</span>
# <span class="sale">(자동)</span>
# </div>
# <div class="hbox splitPrice">
# <p>(자동)</p>
# <span>* 12개월 무이자 할부 시</span>
# </div>
# </div>
# </div>
# <div class="vbox">
# <div class="hbox">
# <a class="payment-btn" href="#">
# <span class="payment-txt">바로 구매하기</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 1rem;
#        padding-bottom: 1rem;
#        background-color: #fff">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-401">
# <div class="container-fluid">
# <div class="container">
# <div class="vbox card-list fc-text-align-center">
# <div class="card">
# <div class="card-content">
# <img alt="" loading="lazy" src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202004/194338-11/alarm-checked-3x.png"/>
# <h5 class="fc-h6-text">해당 강의는 사전 예약 구매 상품입니다.</h5>
# <p class="fc-content-text"><font color="#">
#
# 영상 공개는 다음과 같이 3회에 걸쳐 공개됩니다.<br/>
# <span style="font-size:12px; color: #B47026; line-height: 30px;">
# (1회 구매 이후 모든 영상을 평생 소장 가능합니다.)</span>
# <br/><br/></font>
# <a href="http://fastcampus.co.kr"><img src="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202309/134136-199/vector-2746.png" style="width: 100px; height:auto; margin-left:auto; margin-right: auto; margin-top: 40; display:block;"/></a>
# <br/><br/>
# <span style="display:inline-block; padding:6px 12px; background-color:#f5f5f5; border-radius:3px; color:white; font-size:12px; color: #000000; margin-bottom: 10px;">
# <b>1차 공개</b></span>    24년 04월 26일 (금)
# <br/>
# <span style="display:inline-block; padding:6px 12px; background-color:#f5f5f5; border-radius:3px; color:white; font-size:12px; color: #000000; margin-bottom: 10px;">
# <b>2차 공개</b></span>    24년 05월 31일 (금)
# <br/>
# <span style="display:inline-block; padding:6px 12px; background-color:#f5f5f5; border-radius:3px; color:white; font-size:12px; color: #000000; margin-bottom: 10px;">
# <b>전체 공개</b></span>    24년 06월 14일 (금)
#
# <br/>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-001">
# <div class="container-fluid" style="padding-top: 1rem;
#        padding-bottom: 1rem;
#        background-color: #fff">
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-513">
# <div class="container-fluid theme--light" data-button-color="#466eff" data-color-theme="theme--light" data-load-more-btn-text="더 보기" data-padding-bottom="60" data-padding-top="40" data-reverse-order="false" data-title="이 강의도 추천해요." data-use-load-more-btn="false" data-use-new-tab="false" style="padding-top: 4rem; padding-bottom: 6rem;">
# <div class="container">
# <div class="container__body">
# <h5 class="container__title">이 강의도 추천해요.</h5>
# <ul class="container__cards container__cards--column-4" data-column-count="4">
# <li class="container__card" data-badge-background-color="#ffffffff" data-badge-text-color="#ffffff" data-course-id="235911" data-id="1" data-image-badge="">
# <a class="card__container" href="" target="">
# <div class="card__body">
# <div class="skeleton__image"></div>
# <div class="skeleton__labels"></div>
# <div class="skeleton__title"></div>
# <div class="skeleton__content"></div>
# </div>
# </a>
# </li>
# <li class="container__card" data-badge-background-color="#ff7450" data-badge-text-color="#ffffff" data-course-id="218125" data-id="2" data-image-badge="">
# <a class="card__container" href="" target="">
# <div class="card__body">
# <div class="skeleton__image"></div>
# <div class="skeleton__labels"></div>
# <div class="skeleton__title"></div>
# <div class="skeleton__content"></div>
# </div>
# </a>
# </li>
# <li class="container__card" data-badge-background-color="#ff7450" data-badge-text-color="#ffffff" data-course-id="217128" data-id="3" data-image-badge="">
# <a class="card__container" href="" target="">
# <div class="card__body">
# <div class="skeleton__image"></div>
# <div class="skeleton__labels"></div>
# <div class="skeleton__title"></div>
# <div class="skeleton__content"></div>
# </div>
# </a>
# </li>
# <li class="container__card" data-badge-background-color="#ff7450" data-badge-text-color="#ffffff" data-course-id="214496" data-id="4" data-image-badge="">
# <a class="card__container" href="" target="">
# <div class="card__body">
# <div class="skeleton__image"></div>
# <div class="skeleton__labels"></div>
# <div class="skeleton__title"></div>
# <div class="skeleton__content"></div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="container__footer">
# <div class="container__btn-group">
# <button class="container__load-more-btn" style="border-color: #466eff; color: #466eff">
#           더 보기
#           <svg fill="none" height="7" viewbox="0 0 12 7" width="12" xmlns="http://www.w3.org/2000/svg">
# <path d="M11 1L6 6L1 1" stroke="#466eff"></path>
# </svg>
# </button>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="fc-block fc-layout fc-layout-502">
# <div class="container-fluid" style="background-color: #282828">
# <div class="container">
# <div class="vbox">
# <div class="hbox">
# <div class="collapse-container">
# <label class="collapse fc-content-text">
# <input checked="" type="checkbox"/>
# <span class="title">
# <span style="color: #9b9ba0;">주의사항</span>
# </span>
# <span class="more fc-content-text"><span style="color:#ff7450">
# * 본 상품은 동영상 형태의 강의를 수강하는 상품입니다.
# <br/>
# * 상황에 따라 사전 공지 없이 할인이 조기 마감되거나 연장될 수 있습니다.
# <br/>
# * 해당 강의는 사전 예약 상품으로, 강의 영상이 공개 일정에 따라 순차적으로 제작되어 오픈됩니다.
# <br/>
# * 강의 공개 일정은 내부 사정에 따라 변경될 수 있습니다.
# </span>
# <br/><br/>
# <span style="color:#ff7450">
# [학습에 사용되는 기술스택 버전] <br/>
# <span style="color:#9b9ba0">
# Part 1 : Python (anaaconda) <br/>
# Part 2 : Hugging Face <br/>
# Part 3 : Google colab
# <br/><br/>
# <span style="color:#9b9ba0">
# 총 학습기간:
# <br/>
# – 정상 수강기간(유료 수강기간) 최초 2개월  (<span style="color:#ed234b">60일</span>), 무료 수강 기간은 <span style="color:#ed234b">61일</span> 일차 이후로 무제한이며, 유료 수강기간과 무료 수강기간 모두 동일하게 시청 가능합니다.
# <br/>
# – 본 패키지는 약 <span style="color:#ed234b">15</span>시간 분량으로, 일 1시간 내외의 학습 시간을 통해 정상 수강 기간(=유료 수강 기간) 내에 모두 수강이 가능합니다.
# <br/>
# – 수강시작일: 수강 시작일은 결제일로부터 기간이 산정되며, 결제를 완료하시면 마이페이지를 통해 바로 수강이 가능합니다. (사전 예약 강의는 1차 강의 오픈일)<br/>
# – 패스트캠퍼스의 사정으로 수강시작이 늦어진 경우에는 해당 일정 만큼 수강 시작일이 연기됩니다.
# <br/>
# – 일부 강의는 아직 모든 영상이 공개되지 않았습니다. 각 상세페이지 하단에 공개 일정이 안내되어 있습니다.
# <br/>
# </span></span>
# </span></span></label>
# </div>
# <div class="collapse-container">
# <label class="collapse fc-content-text">
# <input checked="" type="checkbox"/>
# <span class="title">
# <span style="color: #9b9ba0;">환불규정</span>
# </span>
# <span class="more fc-content-text"><span style="color:#9b9ba0">
# – 환불금액은 정가가 아닌 실제 결제금액을 기준으로 계산됩니다. <br/>
# – 쿠폰을 사용하여 강의를 결제하신 후 취소/환불 시 쿠폰은 복구되지 않습니다. <br/>
# <br/>
#
# – 수강시작 후 7일 이내, 5강 미만 수강 시에는 100% 환불 가능합니다. <br/>
# – 수강시작 후 7일 초과, 5강 이상 수강 시 정상 수강기간(유료 수강기간) 대비 잔여일에 대해 다음과 같이 환불 가능합니다.<br/><br/>
# 환불요청일 시 기준<br/>
# : 수강시작 후 1/3 경과 전, 실 결제금액의 2/3에 해당하는 금액 환불<br/>
# : 수강시작 후 1/2 경과 전, 실 결제금액의 1/2에 해당하는 금액 환불<br/>
# : 수강시작 후 1/2 경과 후, 환불 금액 없음<br/>
# <br/>
# * 보다 자세한 환불 규정은 홈페이지 취소/환불 정책에서 확인 가능합니다.</span>
# </span></label>
# </div>
# <div class="collapse-container">
# <label class="collapse fc-content-text">
# <input checked="" type="checkbox"/>
# <span class="title">
# <span style="color: #9b9ba0;">패스트캠퍼스 아이디 공유 금지 정책 안내</span>
# </span>
# <span class="more fc-content-text"><span style="color:#9b9ba0">
# [패스트캠퍼스 아이디 공유 금지 정책]
# <br/>
# 패스트캠퍼스의 모든 온라인 강의에서는 1개의 아이디로 여러명이 공유하는 형태를 금지하고 있습니다.
# <br/>
# 동시접속에 대한 기록은 내부 시스템을 통해 자동으로 누적되며, 이후 서비스 이용이 제한될 수 있습니다.
# <br/><br/>
#
# [기기제한 정책]
# <br/>
# 패스트캠퍼스 온라인 강의 시청을 위해서는 ID별 최대 3개의 기기를 등록할 수 있으며, 기기 등록은 온라인 강의장 접속 시 자동 등록됩니다.
# <br/>
# 최대 갯수를 초과하였을 경우 등록된 기기 해제가 필요합니다.
# <br/><br/>
#
# [저작권 정책]
# <br/>
# 패스트캠퍼스의 모든 강의는 무단 배포 및 가공하는 행위, 캡쳐 및 녹화하여 공유하는 행위, 무단으로 판매하는 행위 등 일체의 저작권 침해 행위를 금지합니다.
# <br/>부정 사용이 적발될 경우 저작권법 위반에 의한 법적인 제재를 받으실 수 있습니다.
# </span></span>
# </label>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="vn-sheet vn-sheet--midnight">
# <div class="vn-sheet__frame">
# <h2 class="a11y"><span class="vn-sheet__h__deco">수강료.</span></h2>
# <div class="vn-sheet__panel">
# <p class="vn-sheet__panel__p">
# <strong>국내 8개 카드사 12개월 무이자 할부 지원! (간편 결제 제외)</strong>
# </p>
# <ul class="vn-sheet__tags">
# <li>삼성카드</li>
# <li>신한카드</li>
# <li>롯데카드</li>
# <li>현대카드</li>
# <li>하나카드</li>
# <li>BC카드</li>
# <li>KB국민은행</li>
# <li>NH농협카드</li>
# </ul>
# <p class="vn-sheet__panel__notice">
#                 ※ BC카드의 경우, <strong>비씨(페이북)</strong>을 선택하여 결제시에만 12개월 무이자 할부가 가능합니다.<br>
#                 (BC계열 – 우리/제일/기업/대구/경남/부산/광주/수협/전북/제주/신협)
#               </br></p>
# </div>
# </div>
# </section>
# <div class="vn-purchase-container">
# <div class="vn-purchase-grid">
# <aside class="vn-purchase">
# <div data-id="236246" id="purchase-sheet">
# </div></aside>
# </div>
# </div>
# </main>
# <script>
#   localStorage.removeItem('courseInfo');
#   localStorage.setItem('courseInfo', JSON.stringify({length: window.history.length, courseId:'236246'}));
# </script>
# <script>
#   const courseData = {
#           id: '236246',
#           categoryId: '39',
#           categoryCode: 'DATASCIENCEDL',
#           subCategoryId: '126',
#           subCategoryCode: 'DATASCIENCE_DEEP',
#           formatId: '6',
#           formatCode: 'AOP',
#           title: '',
#           publicTitle: '25개 실습으로 끝내는 AI 고객센터 서비스 구축',
#           originCourseId: '',
#           imageAssetUrl: 'https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202404/221519-1428/light-active-thumb.png',
#         };
#   if (courseData.id) {
#       window.addEventListener('completeInitiatingTracker', function () {
#         const products = [
#           {
#             id: '258434',
#             listPrice: '600,000',
#             salePrice: '249,000',
#             courseId: '236246',
#             title: '[4월 100% 페이백 대상강의]25개 실습으로 끝내는 AI 고객센터 서비스 구축',
#             publicTitle: '[100% 페이백 이벤트 : 5월 8일 쿠폰 자동발급]25개 실습으로 끝내는 AI 고객센터 서비스 구축',
#             quantity: '',
#           },
#           {
#             id: '256746',
#             listPrice: '719,000',
#             salePrice: '279,000',
#             courseId: '236246',
#             title: '프로모션 : [갤럭시 버즈 FE 패키지] 25개 실습으로 끝내는 AI 고객센터 서비스 구축 : 4월 1차 현물 프로모션 (버즈FE)',
#             publicTitle: '[갤럭시 버즈 FE 패키지] 25개 실습으로 끝내는 AI 고객센터 서비스 구축',
#             quantity: '',
#           },
#         ];
#
#         const product = {
#           id: '258434',
#           title: '[4월 100% 페이백 대상강의]25개 실습으로 끝내는 AI 고객센터 서비스 구축',
#           publicTitle: '',
#           listPrice: '600,000',
#           salePrice: '249,000',
#         };
#
#         const page = {
#             slug: 'data_online_aicc',
#             id: '52115',
#             title: '리뉴얼_25개 실습으로 끝내는 AI 고객센터 서비스 구축',
#             type: 'COURSE',
#             formatId: '',
#             formatCode: '',
#             categoryId: '',
#             categoryCode: '',
#         };
#
#         typeof $fc !== 'undefined' &&
#           $fc.track &&
#           $fc.track(
#             'COURSE_VIEW',
#             Object.assign(courseData, { products: products }, { page: page }, { product: product })
#           );
#       });
#     }
# </script>
# <footer class="footer" id="footer">
# <div class="footer__info-links">
# <ul class="footer__link-list footer__content">
# <li class="footer__link-list-item"><a class="footer__info-link" href="/info/about">회사소개</a></li>
# <li class="footer__link-list-divider"></li>
# <li class="footer__link-list-item"><a class="footer__info-link" href="/instructor_apply">강사지원</a></li>
# <li class="footer__link-list-divider"></li>
# <li class="footer__link-list-item"><a class="footer__info-link" href="https://fastcampus-careers.oopy.io">채용안내</a></li>
# <li class="footer__link-list-divider"></li>
# <li class="footer__link-list-item"><a class="footer__info-link" href="/partners">인재추천</a></li>
# </ul>
# </div>
# <div class="footer__company-info">
# <div class="footer__content">
# <input class="footer__toggle-checkbox a11y" id="company-info-toggler" type="checkbox"/>
# <div class="footer__company-info-top">
# <label class="footer__company-name" for="company-info-toggler">
# <strong>FAST CAMPUS</strong>
# <span class="footer__company-kr-name">
#             (주) 데이원컴퍼니
#             <div class="footer__company-accordion-arrow" style="background-image: url('/assets/img/footer_triangle.svg');"></div>
# </span>
# </label>
# <div class="footer__emblems">
# <img alt="올해의 브랜드 대상 2021" src="/assets/img/footer_emblem_1.png"/>
# <img alt="올해를 빛낸 브랜드 대상 2021" src="/assets/img/footer_emblem_2.png"/>
# </div>
# </div>
# <div class="footer__mobile-toggled-element">
# <ul class="footer__company-info-list">
# <li class="footer__company-info-list-item">대표이사: 이강민</li>
# <li class="footer__company-info-list-item">개인정보책임관리자: 이강민</li>
# <li class="footer__company-info-list-item">사업자번호 : 810-86-00658</li>
# </ul>
# <ul class="footer__company-info-list">
# <li class="footer__company-info-list-item">사무실 : 서울특별시 강남구 테헤란로 231, 센터필드 WEST 6층, 7층</li>
# <li class="footer__company-info-list-item">교육장 : 서울특별시 강남구 강남대로 364 미왕빌딩 10, 11층</li>
# </ul>
# </div>
# <div class="footer__divider"></div>
# <ul class="footer__link-list multiple-line">
# <li class="footer__link-list-item"><a class="footer__info-link" href="/info/policies/service">이용약관</a></li>
# <li class="footer__link-list-divider"></li>
# <li class="footer__link-list-item"><a class="footer__link-list-decoration footer__info-link" href="/info/policies/privacy">개인정보처리방침</a></li>
# <li class="footer__link-list-divider"></li>
# <li class="footer__link-list-item">
# <a class="footer__info-link" href="https://day1fastcampussupport.zendesk.com/hc/ko" rel="noreferrer" target="_blank">FAQ</a>
# </li>
# <li class="footer__link-list-divider"></li>
# <li class="footer__link-list-item"><a class="footer__info-link" href="/info/policies/refund">취소/환불 정책</a></li>
# <li class="footer__link-list-divider"></li>
# <li class="footer__link-list-item"><a class="footer__info-link" href="/info/library">자료실</a></li>
# <li class="footer__link-list-divider"></li>
# <li class="footer__link-list-item"><a class="footer__info-link" href="/info/notices">공지사항</a></li>
# <li class="footer__link-list-divider"></li>
# <li class="footer__link-list-item"><a class="footer__info-link" href="/online_scholarships">장학프로그램</a></li>
# </ul>
# <div class="footer__operation-info">
# <ul class="footer__company-info-list">
# <li class="footer__company-info-list-item">
# <a class="footer__company-info-list-support" href="https://day1fastcampussupport.zendesk.com/hc/ko" rel="noreferrer" target="_blank">고객센터 바로가기</a>
# </li>
# <li class="footer__company-info-list-item">
#             전화번호 02-501-9396
#           </li>
# <li class="footer__company-info-list-item">
#             주중 10시~18시 (점심시간 12~13시 / 주말 및 공휴일 제외)
#           </li>
# </ul>
# <ul class="footer__company-info-list">
# <li class="footer__company-info-list-item">
#             통신판매업 신고번호 : 제 2017-서울강남-01977호
#           </li>
# <li class="footer__company-info-list-item">
#             학원설립 운영등록번호: 제12484호(강남)
#           </li>
# <li class="footer__company-info-list-item">
#             원격평생교육원 :
#             <a class="footer__a footer__company-info__emphasis" href="https://storage.googleapis.com/static.fastcampus.co.kr/prod/uploads/202110/151443-146/[평생교육시설신고증]-데이원컴퍼니-원격평생교육원.pdf" target="_blank">
#               제 572호
#             </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# <div data-run-env="prod" id="fc-popup"></div>
# <div id="modal-in-app"></div>
# <script src="https://storage.googleapis.com/gcs-fastcampus-production-www/assets/js/20240403-1712120699777.tracker.js?2cc0ce3926ad1b32531c53faf7d6adc2"></script>

# %%
data = soup.get_text()
print(data)
# Out:
# 25개 실습으로 끝내는 AI 고객센터 서비스 구축 | 패스트캠퍼스
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2024/4/19-4/25 : [4월 100% 페이백] 최상단 띠배너
#
#
# 상단 배너 닫기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 25개 실습으로 끝내는 AI 고객센터 서비스 구축
# AICC
# LLM 서비스
#
#
#
#
# LLM 서비스
#
#
#
#
#
# Online.
# 25개 실습으로 끝내는
# AI 고객센터 서비스 구축
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LLM 기술을 모두 배울 수 있는 All-in-one 서비스, AI 고객센터
# 감성 분석부터 텍스트 처리까지 LLM 작동 원리와 모델 학습을 한 번에 이해하고 서비스로 적용 가능
#
#
#
#
# 실무에 바로 적용 가능한 AI 고객센터를 25개 실습으로 완성하기
# 패스트캠퍼스에서 준비한 25개 프로젝트와
# 고객센터 운영 필수 18가지 기술 모두 활용
#
#
#
#
# 국내 Top-tier 기업 현직자도 인정한 소장하고 싶은 완벽 커리큘럼
# 네이버, 국내 대표 AICC 기업 등 국내 Top-tier 기업 현직자들이 직접 추천한 커리큘럼으로 구성
#
#
#
#
#
#
#
#
#
#
#
#
#
#             기본정보
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             ㆍ10개 대주제,  41여개 강의 클립 (약 15시간 분량)
# ㆍ실전 - 심화
#
# ㆍ선수 지식 : ML/DL에 대한 배경 지식이 있는 수준
#
#
#
#
#
#
#
#
#             강의특징
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             ㆍ수강료 1회 결제로 평생 소장
#
# ㆍ부가 학습 자료 제공
#
# ㆍ질의응답 제공
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 코스 프로모션 배너 전용입니다.
#
# 0일
# 0시간
# 0분
# 0초
#  코스 프로모션 배너 전용입니다.
#
#
#
#
#
#
#
#
#
# (자동)
#
#
#
#
# 정가
# (자동)
#
#
# 할인 금액
# (자동)
#
#
#
#
#
# 현재 판매가
# (자동)
#
#
# (자동)
# * 12개월 무이자 할부 시
#
#
#
#
#
#
# 바로 구매하기
#
#
#
#
#
#
#
#
#
#
#
#
#
# [전 세계 AI 고객센터 시장 규모 전망]
#
#
#
#
#
#
#
#
#
#
# 5년 만에 300% 초고속 성장한
# AI 고객센터 서비스
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국내외 Top-tier 기업들 역시 빠르게 도입하고 있습니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 확실한 성과와 고객 만족도로 인정받은 AI 고객센터
#
#
#
#
#
#
#
#
#
#
# 하지만 고도화되지 않은 AI 고객센터 서비스구축 시 발생하는  문제점
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 더 이상 해결하지 않고  방치하실 건가요?
#
#
#
#
#
#
#
#
#
#
# 이제는 AI 고객센터를 직접 구축해야 할 차례입니다.
# 이 강의 하나로 AI 고객센터 서비스 구축의 모든 것을 학습하세요!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Point 1
#
#
#
#
#
#
#
#
#
#
# 25개 프로젝트로 완성하는
#  AI 고객센터 실 서비스 만들기
#
#
#
#
#
#
#
#
#
#
# AI 고객센터에서 사용하고 있는 실제 서비스를
# 단계별로 학습 가능합니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 단계별 학습을 통해  AI 고객센터 서비스를 완성해 보세요!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Step 1
# AI 고객센터 서비스 이해
#
# ㆍLLM 작동 원리 (Deep  learning, Training, Fine-tuning, Prompt Engineering)
# ㆍLLM 모델 학습 (ChatGPT, LLaMa, Gemini, Open Source LLM)
# ㆍAI 고객센터 이해 (전체 서비스 구성, 데이터 파이프라인 구축, QA 시스템 구축)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Step 2
# AI 고객센터 서비스 구축
#
# ㆍAI 고객센터 대표 서비스 구축 (Chatbot, Voicebot, Assist)
# ㆍAI 고객센터 산업별 서비스 구축 (Ecommerce, Finance)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Step 3
# AI 고객센터 서비스 운영
#
# ㆍ최신 AI 고객 서비스 사례 소개
# ㆍ서비스 호스팅 방법 노하우
# ㆍ성공적인 전망 및 제언
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이런 분들이라면 주목하세요!
#
#
#
#
#
#
#
#
#
#
#         남들보다 빠른 속도로 AI 고객센터를 만들고 싶은 누구나 지원 및 수강이 가능합니다.
# 특히, 아래 유형에 해당하는 분들께 강력하게 추천 드립니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Point 2
#
#
#
#
#
#
#
#
#
#
# 고객센터 운영 효율화
# 필수 18가지 기술 활용
#
#
#
#
#
#
#
#
#
#
#         AI 엔지니어들이 서비스 구축에 가장 많이 활용하는 ChatGPT, RAG 등
# 필수 18가지 기술을 학습하세요.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Part 01.  AI 고객센터 대표 서비스 구축
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Part 02.  AI 고객센터 산업별 서비스 구축
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Final.  강의 수강 후 최종 프로젝트
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AI 엔진(STT, TTS, NLP 등)을 활용한 대표적인 AI 고객센터 서비스를 직접 만들어 보고
# AICC 상품을 개발하여 솔루션을 직접 도입할 수 있습니다.
#
#
#
#
#
#
#
#
#
#
# Point 3
#
#
#
#
#
#
#
#
#
#
# 국내 Top-tier 기업현직자가 인정한
# 추천 커리큘럼
#
#
#
#
#
#
#
#
#
#
#         국내 대표 기업 현직자도 듣고 싶은
# 웰메이드 강의를 경험해 보세요!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  여기서 끝이 아닙니다!
# 압도적인 연사진의 전문 지식도 함께 얻어 가세요
#
#
#
#
#
#
#
#
#
#
#         AI 고객센터 도입 Top-tier 기업 실무자와 소통하세요!
#
#
#
#
#
#
#
#
#
#
# Plus 1
#
#
#
#
#
#
#
#
#
#
# 마이크로소프트와 대기업 L사
# AI 개발자의 실무 노하우
#
#
#
#
#
#
#
#
#
#
#         원활한 AI 고객센터 운영을 위해 전문가가 실무에서 적용한
#  성공 사례를 기반으로 서비스 운영 방법을 학습합니다.
#
#
#
#
#
#
#
#
#
#
#
# 01 ｜ 국내외 기업 서비스 사례
# 원활한 AI 고객센터 운영을 위해 전문가가 실무에서 적용한 성공 사례를 기반으로 서비스 운영 방법을 학습합니다.
#
#
#
# 02 ｜ 고객센터 운영 노하우 학습
# 카카오톡 채널 관리, AWS 호스팅, On premise vs Cloud 비용 비교를 통해 제품/서비스에 적합한 고객센터 운영 노하우를 학습합니다.
#
#
#
# 03 ｜ 성공적인 운영을 위한 제언 및 전망
# 성공적인 운영을 위한 제언과 미래 AI 고객센터 전망을 살피며 강의를 마무리 합니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 김강우 강사님
#
#  l 소속
# 전) Microsoft Research Asia Researcher
# Naver AI Research Researcher
# Seoul National University Hospital Researcher
#
# l 프로젝트
# • Tree of Clarifications: Answering Ambiguous Questions with Retrieval-Augmented Large Language Models, EMNLP 2023
# • Pre-trained Vision-Language Model for Radiology Report Summarization, BioNLP Workshop @ ACL 2023
# • Winner of RadSum23 Challenge - Task 1B, MIMIC-CXR Hidden (1st place)
#
#
#  “최근 기업들이 AI를 활용한 고객 서비스 모델을 가장 유망한 비즈니스 모델로 주목하고 있습니다. ”
#
# AI 고객센터 서비스는 고객 서비스 개선, 비용 절감, 업무 자동화, 데이터 분석의 효율성 증대와 같은
# 현실적인 이익을 가능하게 하고 있습니다. 본 강의를 통해 여러분은 이러한 기술의 핵심을 이해하고,
# 직접 손에 넣은 지식을 바탕으로 여러분의 조직이나 사업에서 혁신을 이끌어낼 수 있기를 바랍니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Rina 강사님
#
# l 소속
# 현) 국내 대기업 L사 AI Research Engineer
#
# l 프로젝트
# • Generative AI PoC 및 사업 수행 - L사, K은행, S은행 등
# • 제조사 글로벌 챗봇 사업 검증
# • 금융사 RAG 기반 챗봇 사업 검증
# • 금융사 ChatGPT API 기반 서비스 개발 및 데이터 정비 사업
#
#
#  “AI 고객센터 서비스 구축을 통해 AI 활용 능력을 업그레이드 하세요.”
#
# 최신 AI 기술을 이해하고 실제 프로젝트에 적용할 수 있는 실질적인 능력을 길러 드립니다.
# 현재 업무 방식보다 고도화된, 효율적이고 혁신적인 AI 고객센터 서비스를 구축하세요.
#
#
#
#
#
#
#
#
#
#
#
# Plus 2
#
#
#
#
#
#
#
#
#
#
# 디스코드 질의응답 채널을 통해
# 전문가와 1:1 소통하기
#
#
#
#
#
#
#
#
#
#
#         현직 AI 엔지니어가 직접 답변해 드립니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         * 교육 내용 범주 내에서만 질의응답이 가능합니다.* 2024년 4월 26일부터 2025년 4월 26일까지 운영됩니다.
#
#
#
#
#
#
#
#
#
#
# Q&A
#
#
#
#
#
#
#
#
#
#
# Question 1.
#
#
#
#
#
#
#
#
#
#
#
#
# 필요한 선수지식
#
#
#
#
#
#
# • 기본적인 NLP 지식 및 언어 모델에 대한 이해가 필요합니다.
# • Python 언어에 대한 이해가 필요합니다.
# • Hugging Face 사용법 이해가 필요합니다.
#  • 데이터 셋 다루고 분석하기 위해 데이터 과학 및 분석 개념과  도구에 대한 이해가 필요합니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Question 2.
#
#
#
#
#
#
#
#
#
#
#
#
# 개발 환경
#
#
#
#
#
#
# • Python (anaconda)
# • Hugging Face
# • Colab 및 Colab Pro
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 커리큘럼
#
#
#
#
#
#
#
#
#
#
#
#
# 지금 한 번만 결제하고 강의를 평생 소장하세요!
#
#
#
#
#
#
#
#
#
#
#
#
#
# Part 1. 시작하기 전, LLM 이해하기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             01. LLM 작동 원리
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# · Resources (Data, Library)
# · Pre-training
# · Fine-tuning
# · Prompt Engineering
# · Evaluation
#
#
#
#
#
#
#
#             02. LLM 모델 학습
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# · LLM 모델 개요
# · OpenAI 모델 (GPT)
# · Meta 모델 (LLaMA)
# · Google 모델 (Gemini)
# · Open source LLM
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             03. AI 고객센터 이해
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# · 전체 서비스 구성
# · 데이터 파이프라인 구축
# · QA 시스템 구축
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Part 2. AI 고객센터 대표 서비스 구축
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             01. Chatbot
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# · 강의 개괄적 소개 및 OpenAI 모델 소개, API 활용 준비 등
# · LLM(ChatGPT)를 활용한 사용자 요청 의도 요약
# · LLM(ChatGPT)를 활용한 불가능한 요청 탐지
# · Moderation API로 민감한 대화 차단하기
# · ChatGPT API를 활용하여 매뉴얼 기반의 답변 생성하기
# ChatGPT API를 활용하여 고객사 홈페이지 기반 답변 생성하기
# · ChatGPT API를 활용하여 고객사 DB (Table 형태) 기반 답변 생성하기
# · gpt4-vision API를 활용하여 Image 인식 기반 답변 생성하기
# · Word, Powerpoint 문서 기반 답변 결과 생성하기
# · RAG 기반 웹 검색 결과 기반 답변 생성하기
# · RAG 기반 고객사 자체 문서에 대한 커스텀 검색 엔진 제작
# · RAG 기반 커스텀 검색 엔진 결과 기반 답변 생성하기
# · LLM Agent 기반 자동 예약 서비스 구성하기
# · 각 대화 상황을 위한 지시문 학습 (Instruction Tuning) 데이터셋 생성
# · Fine-tuning으로 고객사별 맞춤 Chatbot 학습 (1) - 데이터 준비
# · Fine-tuning으로 고객사별 맞춤 Chatbot 학습 (2) - 학습하고 대화하기
# · Fine-tuning으로 고객사별 맞춤 Chatbot 학습 (3) - 최근 학습 방법 소개
#
#
#
#
#
#
#
#             02. Voicebot
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# · Whisper, STT API를 활용한 음성 인식 및 오류 교정
# · Whisper, TTS API를 활용하여 다양한 답변 음성 생성
# · Voicebot과 Chatbot 연동을 통해 음성 기반 상담 서비스 구현
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             03.Assistant
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# · 실시간 상담 요약 - 사용자 발화 요약 및 키워드 로깅
# · 실시간 상담결과 피드백 - 상담 과정 전반에 대한 사용자 평가 기록
# · 상담 후처리 지원 - 상담 결과 개선점 파악 및 관련 내용 보고 시스템
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Part 3. AI 고객센터 산업별 서비스 구축
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             01. Ecommerce
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ·고객 주문/배송 기록 등 개인 정보 기반 고객 맞춤형 상담
# ·상담 기록 기반 연속성 높은 대화 서비스 구축
# · 고객 성향 분석을 활용한 추천 시스템 기반 상품 추천
# · 예측 모델을 활용한 잠재 이탈 고객 탐지
#
#
#
#
#
#
#
#
#             02. Finance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# · 예금, 대출, 외환, 펀드, 투자 상품 추천
# · 불완전판매 모니터링 자동화 - 해피콜
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Part 4. AI 고객센터 서비스 운영
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             01. 최근 고객 서비스 사례 소개
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# · 서비스 소개
# · Amazon LEX, NAVER Clovacall 등
#
#
#
#
#
#
#
#
#             02. 서비스 호스팅 방법 소개
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ·카카오톡 채널 추가
# · AWS 호스팅 방법 소개
# · On-premise vs Cloud 비용
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             03.결론
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# · 성공적인 운영을 위한 제언 및 전망 등
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  커리큘럼 상세보기
#
#
#
#
#
#
#
#
#
#
#
#
#
# (자동)
#
#
#
#
# 정가
# (자동)
#
#
# 할인 금액
# (자동)
#
#
#
#
#
# 현재 판매가
# (자동)
#
#
# (자동)
# * 12개월 무이자 할부 시
#
#
#
#
#
#
# 바로 구매하기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 해당 강의는 사전 예약 구매 상품입니다.
#
#
# 영상 공개는 다음과 같이 3회에 걸쳐 공개됩니다.
#
# (1회 구매 이후 모든 영상을 평생 소장 가능합니다.)
#
#
#
#
# 1차 공개    24년 04월 26일 (금)
#
#
# 2차 공개    24년 05월 31일 (금)
#
#
# 전체 공개    24년 06월 14일 (금)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이 강의도 추천해요.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           더 보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 주의사항
#
#
# * 본 상품은 동영상 형태의 강의를 수강하는 상품입니다.
#
# * 상황에 따라 사전 공지 없이 할인이 조기 마감되거나 연장될 수 있습니다.
#
# * 해당 강의는 사전 예약 상품으로, 강의 영상이 공개 일정에 따라 순차적으로 제작되어 오픈됩니다.
#
# * 강의 공개 일정은 내부 사정에 따라 변경될 수 있습니다.
#
#
#
# [학습에 사용되는 기술스택 버전]
#
# Part 1 : Python (anaaconda)
# Part 2 : Hugging Face
# Part 3 : Google colab
#
#
# 총 학습기간:
#
# – 정상 수강기간(유료 수강기간) 최초 2개월  (60일), 무료 수강 기간은 61일 일차 이후로 무제한이며, 유료 수강기간과 무료 수강기간 모두 동일하게 시청 가능합니다.
#
# – 본 패키지는 약 15시간 분량으로, 일 1시간 내외의 학습 시간을 통해 정상 수강 기간(=유료 수강 기간) 내에 모두 수강이 가능합니다.
#
# – 수강시작일: 수강 시작일은 결제일로부터 기간이 산정되며, 결제를 완료하시면 마이페이지를 통해 바로 수강이 가능합니다. (사전 예약 강의는 1차 강의 오픈일)
# – 패스트캠퍼스의 사정으로 수강시작이 늦어진 경우에는 해당 일정 만큼 수강 시작일이 연기됩니다.
#
# – 일부 강의는 아직 모든 영상이 공개되지 않았습니다. 각 상세페이지 하단에 공개 일정이 안내되어 있습니다.
#
#
#
#
#
#
#
#
# 환불규정
#
#
# – 환불금액은 정가가 아닌 실제 결제금액을 기준으로 계산됩니다.
# – 쿠폰을 사용하여 강의를 결제하신 후 취소/환불 시 쿠폰은 복구되지 않습니다.
#
#
# – 수강시작 후 7일 이내, 5강 미만 수강 시에는 100% 환불 가능합니다.
# – 수강시작 후 7일 초과, 5강 이상 수강 시 정상 수강기간(유료 수강기간) 대비 잔여일에 대해 다음과 같이 환불 가능합니다.
# 환불요청일 시 기준
# : 수강시작 후 1/3 경과 전, 실 결제금액의 2/3에 해당하는 금액 환불
# : 수강시작 후 1/2 경과 전, 실 결제금액의 1/2에 해당하는 금액 환불
# : 수강시작 후 1/2 경과 후, 환불 금액 없음
#
# * 보다 자세한 환불 규정은 홈페이지 취소/환불 정책에서 확인 가능합니다.
#
#
#
#
#
#
# 패스트캠퍼스 아이디 공유 금지 정책 안내
#
#
# [패스트캠퍼스 아이디 공유 금지 정책]
#
# 패스트캠퍼스의 모든 온라인 강의에서는 1개의 아이디로 여러명이 공유하는 형태를 금지하고 있습니다.
#
# 동시접속에 대한 기록은 내부 시스템을 통해 자동으로 누적되며, 이후 서비스 이용이 제한될 수 있습니다.
#
#
# [기기제한 정책]
#
# 패스트캠퍼스 온라인 강의 시청을 위해서는 ID별 최대 3개의 기기를 등록할 수 있으며, 기기 등록은 온라인 강의장 접속 시 자동 등록됩니다.
#
# 최대 갯수를 초과하였을 경우 등록된 기기 해제가 필요합니다.
#
#
# [저작권 정책]
#
# 패스트캠퍼스의 모든 강의는 무단 배포 및 가공하는 행위, 캡쳐 및 녹화하여 공유하는 행위, 무단으로 판매하는 행위 등 일체의 저작권 침해 행위를 금지합니다.
# 부정 사용이 적발될 경우 저작권법 위반에 의한 법적인 제재를 받으실 수 있습니다.
#
#
#
#
#
#
#
#
#
#
# 수강료.
#
#
# 국내 8개 카드사 12개월 무이자 할부 지원! (간편 결제 제외)
#
#
# 삼성카드
# 신한카드
# 롯데카드
# 현대카드
# 하나카드
# BC카드
# KB국민은행
# NH농협카드
#
#
#                 ※ BC카드의 경우, 비씨(페이북)을 선택하여 결제시에만 12개월 무이자 할부가 가능합니다.
#                 (BC계열 – 우리/제일/기업/대구/경남/부산/광주/수협/전북/제주/신협)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 회사소개
#
# 강사지원
#
# 채용안내
#
# 인재추천
#
#
#
#
#
#
#
# FAST CAMPUS
#
#             (주) 데이원컴퍼니
#
#
#
#
#
#
#
#
#
#
# 대표이사: 이강민
# 개인정보책임관리자: 이강민
# 사업자번호 : 810-86-00658
#
#
# 사무실 : 서울특별시 강남구 테헤란로 231, 센터필드 WEST 6층, 7층
# 교육장 : 서울특별시 강남구 강남대로 364 미왕빌딩 10, 11층
#
#
#
#
# 이용약관
#
# 개인정보처리방침
#
#
# FAQ
#
#
# 취소/환불 정책
#
# 자료실
#
# 공지사항
#
# 장학프로그램
#
#
#
#
# 고객센터 바로가기
#
#
#             전화번호 02-501-9396
#
#
#             주중 10시~18시 (점심시간 12~13시 / 주말 및 공휴일 제외)
#
#
#
#
#             통신판매업 신고번호 : 제 2017-서울강남-01977호
#
#
#             학원설립 운영등록번호: 제12484호(강남)
#
#
#             원격평생교육원 :
#
#               제 572호

# %% [markdown]
# ##### 2. GPT API를 이용하여 중요한 정보 구조화 하기

# %%
from openai import OpenAI

OPENAI_API_KEY='sk-'
model_name="gpt-3.5-turbo"

client = OpenAI(
    api_key=OPENAI_API_KEY,
)

def summarize_html(prompt):
  chat_completion = client.chat.completions.create(
      messages=[
          {
              "role": "user",
              "content": prompt,
          }
      ],
      model=model_name,
  )
  return chat_completion.choices[0].message.content

# %%
def promt_generation(raw_txt):
    promt = f"""
    TXT는 html문서에서 추출된 텍스트입니다.
    TXT를 보고 정보를 구조화 하여서 json 파일을 만들어주세요.
    포함되어야 하는 정보는 코스 제목, 강사진, 강의 내용, 추천 대상입니다.

    TXT: {raw_txt}

    JSON:
    """
    return promt

prompt = promt_generation(data)


structured_data = summarize_html(prompt)

# %%
print(structured_data)
# Out:
# {
#     "course_title": "25개 실습으로 끝내는 AI 고객센터 서비스 구축",
#     "instructors": [
#         {
#             "name": "김강우 강사님",
#             "affiliation": "전) Microsoft Research Asia Researcher, Naver AI Research Researcher, Seoul National University Hospital Researcher",
#             "projects": [
#                 "Tree of Clarifications: Answering Ambiguous Questions with Retrieval-Augmented Large Language Models, EMNLP 2023",
#                 "Pre-trained Vision-Language Model for Radiology Report Summarization, BioNLP Workshop @ ACL 2023",
#                 "Winner of RadSum23 Challenge - Task 1B, MIMIC-CXR Hidden (1st place)"
#             ],
#             "quote": "최근 기업들이 AI를 활용한 고객 서비스 모델을 가장 유망한 비즈니스 모델로 주목하고 있습니다."
#         },
#         {
#             "name": "Rina 강사님",
#             "affiliation": "현) 국내 대기업 L사 AI Research Engineer",
#             "projects": [
#                 "Generative AI PoC 및 사업 수행 - L사, K은행, S은행 등",
#                 "제조사 글로벌 챗봇 사업 검증",
#                 "금융사 RAG 기반 챗봇 사업 검증",
#                 "금융사 ChatGPT API 기반 서비스 개발 및 데이터 정비 사업"
#             ],
#             "quote": "AI 고객센터 서비스 구축을 통해 AI 활용 능력을 업그레이드 하세요."
#         }
#     ],
#     "course_content": {
#         "topics": "10대 주제, 41여개 강의 클립 (약 15시간 분량)",
#         "level": "실전 - 심화",
#         "prerequisites": "ML/DL에 대한 배경 지식이 있는 수준"
#     },
#     "target_audience": "남들보다 빠른 속도로 AI 고객센터를 만들고 싶은 누구나 지원 및 수강이 가능합니다. 특히, 아래 유형에 해당하는 분들께 강력하게 추천 드립니다.",
#     "recommend_curriculum": {
#         "highlights": [
#             "25개 프로젝트로 완성하는 AI 고객센터 실 서비스 만들기",
#             "고객센터 운영 효율화 필수 18가지 기술 활용",
#             "국내 Top-tier 기업 현직자가 인정한 추천 커리큘럼"
#         ],
#         "detailed_curriculum": {
#             "Part 1. 시작하기 전, LLM 이해하기": {
#                 "01. LLM 작동 원리": ["Resources (Data, Library)", "Pre-training", "Fine-tuning", "Prompt Engineering", "Evaluation"],
#                 "02. LLM 모델 학습": ["LLM 모델 개요", "OpenAI 모델 (GPT)", "Meta 모델 (LLaMa)", "Google 모델 (Gemini)", "Open source LLM"],
#                 "03. AI 고객센터 이해": ["전체 서비스 구성", "데이터 파이프라인 구축", "QA 시스템 구축"]
#             },
#             "Part 2. AI 고객센터 대표 서비스 구축": {
#                 "01. Chatbot": ["강의 개괄적 소개 및 OpenAI 모델 소개", "LLM(ChatGPT)를 활용한 사용자 요청 의도 요약", "..."],
#                 "02. Voicebot": ["Whisper, STT API를 활용한 음성 인식 및 오류 교정", "Whisper, TTS API를 활용하여 다양한 답변 음성 생성", "..."],
#                 "03. Assistant": ["실시간 상담 요약", "실시간 상담결과 피드백", "..."]
#             },
#             "Part 3. AI 고객센터 산업별 서비스 구축": {
#                 "01. Ecommerce": ["고객 주문/배송 기록 등 개인 정보 기반 고객 맞춤형 상담", "상담 기록 기반 연속성 높은 대화 서비스 구축", "..."],
#                 "02. Finance": ["예금, 대출, 외환, 펀드, 투자 상품 추천", "불완전판매 모니터링 자동화 - 해피콜", "..."]
#             },
#             "Part 4. AI 고객센터 서비스 운영": {
#                 "01. 최근 고객 서비스 사례 소개": ["서비스 소개", "Amazon LEX, NAVER Clovacall 등"],
#                 "02. 서비스 호스팅 방법 소개": ["카카오톡 채널 추가", "AWS 호스팅 방법 소개", "On-premise vs Cloud 비용", "..."],
#                 "03. 결론": ["성공적인 운영을 위한 제언 및 전망", "..."]
#             }
#         }
#     }
# }

# %% [markdown]
# ##### 3. 구조화된 데이터 정보 분석

# %%
import json


structured_json_data = json.loads(structured_data)
print(structured_json_data.keys())
# Out:
# dict_keys(['course_title', 'instructors', 'course_content', 'target_audience', 'recommend_curriculum'])

# %%
print(structured_json_data['course_title'])
# Out:
# 25개 실습으로 끝내는 AI 고객센터 서비스 구축

# %%
print(structured_json_data['instructors'])
# Out:
# [{'name': '김강우 강사님', 'affiliation': '전) Microsoft Research Asia Researcher, Naver AI Research Researcher, Seoul National University Hospital Researcher', 'projects': ['Tree of Clarifications: Answering Ambiguous Questions with Retrieval-Augmented Large Language Models, EMNLP 2023', 'Pre-trained Vision-Language Model for Radiology Report Summarization, BioNLP Workshop @ ACL 2023', 'Winner of RadSum23 Challenge - Task 1B, MIMIC-CXR Hidden (1st place)'], 'quote': '최근 기업들이 AI를 활용한 고객 서비스 모델을 가장 유망한 비즈니스 모델로 주목하고 있습니다.'}, {'name': 'Rina 강사님', 'affiliation': '현) 국내 대기업 L사 AI Research Engineer', 'projects': ['Generative AI PoC 및 사업 수행 - L사, K은행, S은행 등', '제조사 글로벌 챗봇 사업 검증', '금융사 RAG 기반 챗봇 사업 검증', '금융사 ChatGPT API 기반 서비스 개발 및 데이터 정비 사업'], 'quote': 'AI 고객센터 서비스 구축을 통해 AI 활용 능력을 업그레이드 하세요.'}]

# %%
print(structured_json_data['course_content'])
# Out:
# {'topics': '10대 주제, 41여개 강의 클립 (약 15시간 분량)', 'level': '실전 - 심화', 'prerequisites': 'ML/DL에 대한 배경 지식이 있는 수준'}

# %%
print(structured_json_data['target_audience'])
# Out:
# 남들보다 빠른 속도로 AI 고객센터를 만들고 싶은 누구나 지원 및 수강이 가능합니다. 특히, 아래 유형에 해당하는 분들께 강력하게 추천 드립니다.

# %%
print(json.dumps(structured_json_data['instructors'], ensure_ascii=False, indent=2))
# Out:
# [
#   {
#     "name": "김강우 강사님",
#     "affiliation": "전) Microsoft Research Asia Researcher, Naver AI Research Researcher, Seoul National University Hospital Researcher",
#     "projects": [
#       "Tree of Clarifications: Answering Ambiguous Questions with Retrieval-Augmented Large Language Models, EMNLP 2023",
#       "Pre-trained Vision-Language Model for Radiology Report Summarization, BioNLP Workshop @ ACL 2023",
#       "Winner of RadSum23 Challenge - Task 1B, MIMIC-CXR Hidden (1st place)"
#     ],
#     "quote": "최근 기업들이 AI를 활용한 고객 서비스 모델을 가장 유망한 비즈니스 모델로 주목하고 있습니다."
#   },
#   {
#     "name": "Rina 강사님",
#     "affiliation": "현) 국내 대기업 L사 AI Research Engineer",
#     "projects": [
#       "Generative AI PoC 및 사업 수행 - L사, K은행, S은행 등",
#       "제조사 글로벌 챗봇 사업 검증",
#       "금융사 RAG 기반 챗봇 사업 검증",
#       "금융사 ChatGPT API 기반 서비스 개발 및 데이터 정비 사업"
#     ],
#     "quote": "AI 고객센터 서비스 구축을 통해 AI 활용 능력을 업그레이드 하세요."
#   }
# ]

# %% [markdown]
# ##### 4. 웹 사이트 정보기반 답변 생성

# %%
from string import Template

query = "안녕하세요. 이 강의에서 배울 수 있는 것들을 알려주세요"

system_prompt = Template("""
너는 $course_title 관련 답변을 해주는 인공지능 챗봇이야.
주어진 강의 관련 정보를 활용하여서 사용자에게 친절한 답변을 제공해줘.

강의 관련 정보
$informations

""")

prompt = Template("""
다음 사용자의 요청에 대한 답변을 해줘

요청: $query
""")

print(system_prompt.substitute(course_title="25개 실습으로 끝내는 AI 고객센터 서비스 구축", informations=structured_data))
print(prompt.substitute(query=query))
# Out:
# 너는 25개 실습으로 끝내는 AI 고객센터 서비스 구축 관련 답변을 해주는 인공지능 챗봇이야.
# 주어진 강의 관련 정보를 활용하여서 사용자에게 친절한 답변을 제공해줘.
#
# 강의 관련 정보
# {
#     "course_title": "25개 실습으로 끝내는 AI 고객센터 서비스 구축",
#     "instructors": [
#         {
#             "name": "김강우 강사님",
#             "affiliation": "전) Microsoft Research Asia Researcher, Naver AI Research Researcher, Seoul National University Hospital Researcher",
#             "projects": [
#                 "Tree of Clarifications: Answering Ambiguous Questions with Retrieval-Augmented Large Language Models, EMNLP 2023",
#                 "Pre-trained Vision-Language Model for Radiology Report Summarization, BioNLP Workshop @ ACL 2023",
#                 "Winner of RadSum23 Challenge - Task 1B, MIMIC-CXR Hidden (1st place)"
#             ],
#             "quote": "최근 기업들이 AI를 활용한 고객 서비스 모델을 가장 유망한 비즈니스 모델로 주목하고 있습니다."
#         },
#         {
#             "name": "Rina 강사님",
#             "affiliation": "현) 국내 대기업 L사 AI Research Engineer",
#             "projects": [
#                 "Generative AI PoC 및 사업 수행 - L사, K은행, S은행 등",
#                 "제조사 글로벌 챗봇 사업 검증",
#                 "금융사 RAG 기반 챗봇 사업 검증",
#                 "금융사 ChatGPT API 기반 서비스 개발 및 데이터 정비 사업"
#             ],
#             "quote": "AI 고객센터 서비스 구축을 통해 AI 활용 능력을 업그레이드 하세요."
#         }
#     ],
#     "course_content": {
#         "topics": "10대 주제, 41여개 강의 클립 (약 15시간 분량)",
#         "level": "실전 - 심화",
#         "prerequisites": "ML/DL에 대한 배경 지식이 있는 수준"
#     },
#     "target_audience": "남들보다 빠른 속도로 AI 고객센터를 만들고 싶은 누구나 지원 및 수강이 가능합니다. 특히, 아래 유형에 해당하는 분들께 강력하게 추천 드립니다.",
#     "recommend_curriculum": {
#         "highlights": [
#             "25개 프로젝트로 완성하는 AI 고객센터 실 서비스 만들기",
#             "고객센터 운영 효율화 필수 18가지 기술 활용",
#             "국내 Top-tier 기업 현직자가 인정한 추천 커리큘럼"
#         ],
#         "detailed_curriculum": {
#             "Part 1. 시작하기 전, LLM 이해하기": {
#                 "01. LLM 작동 원리": ["Resources (Data, Library)", "Pre-training", "Fine-tuning", "Prompt Engineering", "Evaluation"],
#                 "02. LLM 모델 학습": ["LLM 모델 개요", "OpenAI 모델 (GPT)", "Meta 모델 (LLaMa)", "Google 모델 (Gemini)", "Open source LLM"],
#                 "03. AI 고객센터 이해": ["전체 서비스 구성", "데이터 파이프라인 구축", "QA 시스템 구축"]
#             },
#             "Part 2. AI 고객센터 대표 서비스 구축": {
#                 "01. Chatbot": ["강의 개괄적 소개 및 OpenAI 모델 소개", "LLM(ChatGPT)를 활용한 사용자 요청 의도 요약", "..."],
#                 "02. Voicebot": ["Whisper, STT API를 활용한 음성 인식 및 오류 교정", "Whisper, TTS API를 활용하여 다양한 답변 음성 생성", "..."],
#                 "03. Assistant": ["실시간 상담 요약", "실시간 상담결과 피드백", "..."]
#             },
#             "Part 3. AI 고객센터 산업별 서비스 구축": {
#                 "01. Ecommerce": ["고객 주문/배송 기록 등 개인 정보 기반 고객 맞춤형 상담", "상담 기록 기반 연속성 높은 대화 서비스 구축", "..."],
#                 "02. Finance": ["예금, 대출, 외환, 펀드, 투자 상품 추천", "불완전판매 모니터링 자동화 - 해피콜", "..."]
#             },
#             "Part 4. AI 고객센터 서비스 운영": {
#                 "01. 최근 고객 서비스 사례 소개": ["서비스 소개", "Amazon LEX, NAVER Clovacall 등"],
#                 "02. 서비스 호스팅 방법 소개": ["카카오톡 채널 추가", "AWS 호스팅 방법 소개", "On-premise vs Cloud 비용", "..."],
#                 "03. 결론": ["성공적인 운영을 위한 제언 및 전망", "..."]
#             }
#         }
#     }
# }
#
#
#
# 다음 사용자의 요청에 대한 답변을 해줘
#
# 요청: 안녕하세요. 이 강의에서 배울 수 있는 것들을 알려주세요

# %%
def create_answer(query):
  chat_completion = client.chat.completions.create(
      messages=[
          {
              "role": "system",
              "content": system_prompt.substitute(course_title="25개 실습으로 끝내는 AI 고객센터 서비스 구축", informations=structured_data),
          },
          {
              "role": "user",
              "content": prompt.substitute(query=query),
          }
      ],
      model=model_name,
  )

  return chat_completion.choices[0].message.content


query_list = [
    '강사진에 대한 설명을 부탁해',
    '이 강의에서 배울 수 있는 것들을 알려주세요'
]

for q in query_list:
  print(f"Q: {q}")
  print(f"A: {create_answer(q)}")
  print("\n===============================\n")
# Out:
# Q: 강사진에 대한 설명을 부탁해
# A: 저희 강의 "25개 실습으로 끝내는 AI 고객센터 서비스 구축"의 강사진은 김강우 강사님과 Rina 강사님 두 분으로 구성되어 있습니다.
#
# 1. 김강우 강사님:
# - 소속: 전) Microsoft Research Asia Researcher, Naver AI Research Researcher, Seoul National University Hospital Researcher
# - 주요 프로젝트:
#     - Tree of Clarifications: Answering Ambiguous Questions with Retrieval-Augmented Large Language Models, EMNLP 2023
#     - Pre-trained Vision-Language Model for Radiology Report Summarization, BioNLP Workshop @ ACL 2023
#     - Winner of RadSum23 Challenge - Task 1B, MIMIC-CXR Hidden (1st place)
# - 인용구: "최근 기업들이 AI를 활용한 고객 서비스 모델을 가장 유망한 비즈니스 모델로 주목하고 있습니다."
#
# 2. Rina 강사님:
# - 소속: 현) 국내 대기업 L사 AI Research Engineer
# - 주요 프로젝트:
#     - Generative AI PoC 및 사업 수행 - L사, K은행, S은행 등
#     - 제조사 글로벌 챗봇 사업 검증
#     - 금융사 RAG 기반 챗봇 사업 검증
#     - 금융사 ChatGPT API 기반 서비스 개발 및 데이터 정비 사업
# - 인용구: "AI 고객센터 서비스 구축을 통해 AI 활용 능력을 업그레이드 하세요."
#
# 위와 같이 두 강사님 모두 각자의 경험과 전문성을 바탕으로 풍부한 내용을 전달해주실 것이며, 참가자분들께 많은 도움이 될 것입니다.
#
# ===============================
#
# Q: 이 강의에서 배울 수 있는 것들을 알려주세요
# A: 이 강의인 "25개 실습으로 끝내는 AI 고객센터 서비스 구축"에서는 다음과 같은 내용을 배울 수 있습니다:
#
# 1. Large Language Models (LLM)의 작동 원리와 학습 방법
# 2. AI 고객센터의 전체 서비스 구성과 데이터 파이프라인 구축 방법
# 3. Chatbot, Voicebot, Assistant 등과 같은 AI 고객센터 대표 서비스의 구축 방법
# 4. Ecommerce 및 Finance 산업별 AI 고객센터 서비스의 구축 방법
# 5. 최근 고객 서비스 사례 및 서비스 호스팅 방법 등에 대한 내용
#
# 이 강의를 통해 AI 고객센터 서비스를 구축하는 과정과 실무에 필요한 기술을 학습할 수 있습니다.
#
# ===============================
