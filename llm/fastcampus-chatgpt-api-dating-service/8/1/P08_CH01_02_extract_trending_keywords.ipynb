# %% [markdown]
# # Extract Trending Keywords

# %% [markdown]
# 여러 프로필에서 핫 키워드 추출하기

# %%
from typing import List, Dict
from collections import Counter
import random

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.pydantic_v1 import BaseModel, Field
# Out:
# /Users/hyeonjinho/.pyenv/versions/3.11.6/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3577: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Keyword Extraction Chain 만들기

# %%
model_3_5 = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.8)
model = ChatOpenAI(model="gpt-4-turbo-preview", temperature=0.8)

# %%
class Keywords(BaseModel):
    keyword_list: List[str] = Field(description="List of keywords")

# %%
parser = JsonOutputParser(pydantic_object=Keywords)
format_instructions = parser.get_format_instructions()
format_instructions
# Out:
# 'The output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"properties": {"keyword_list": {"title": "Keyword List", "description": "List of keywords", "type": "array", "items": {"type": "string"}}}, "required": ["keyword_list"]}\n```'

# %%
human_prompt_template = HumanMessagePromptTemplate.from_template(
                            "{doc}\n{format_instructions}")

prompt = ChatPromptTemplate.from_messages(
    [
        human_prompt_template,
    ])
prompt = prompt.partial(format_instructions=format_instructions)

# %%
extract_keyword_chain = prompt | model | parser

# %%
profile = model.invoke("20대 평범한 직장인 자기소개 하나 만들어줘").content
print(profile)
# Out:
# 안녕하세요! 저는 20대 후반의 평범한 직장인입니다. 현재 IT업계에서 마케팅 담당자로 근무하고 있어요. 대학에서 경영학을 전공하고, 졸업 후 이 분야에서 제 커리어를 시작했습니다.
#
# 일하는 것 외에도 여러 취미가 있는데, 특히 음악 감상과 요리하기를 좋아합니다. 주말이면 새로운 레시피를 시도하는 것이 제 소소한 즐거움 중 하나예요. 또한, 운동을 꾸준히 하려고 노력 중이며, 요즘엔 특히 요가에 관심이 많습니다.
#
# 사람들과 소통하는 것을 좋아하고, 다양한 경험을 통해 새로운 것을 배우는 것을 두려워하지 않습니다. 앞으로도 다양한 분야에 도전하며, 제 역량을 넓혀나가고자 합니다.
#
# 이렇게 저는 평범하지만, 제 삶을 즐기며 살아가는 20대 직장인입니다. 앞으로도 많은 성장과 발전을 이루어 나가고 싶습니다. 감사합니다!

# %%
extract_keyword_chain.invoke({'doc': profile})
# Out:
# {'keyword_list': ['20대 후반',
#   '직장인',
#   'IT업계',
#   '마케팅',
#   '경영학 전공',
#   '음악 감상',
#   '요리',
#   '주말',
#   '새로운 레시피',
#   '운동',
#   '요가',
#   '소통',
#   '다양한 경험',
#   '도전',
#   '역량 넓히기',
#   '성장',
#   '발전']}

# %% [markdown]
# ## Trending Keywords 추출하기

# %% [markdown]
# 1. pseudo profile description 만들기
# 2. description으로 profile sampling 하기
# 3. Trending Keyword 추출

# %%
# 직업, 연령대, 그리고 추가 특징 리스트 정의
jobs = ["금융 분석가", "소프트웨어 엔지니어", "창업가", "그래픽 디자이너", "초등학교 교사", "마케팅 전문가", "건축가", "의사", "간호사", "운동선수"]
age_groups = ["20대 초반", "20대 후반", "30대 초반", "30대 중반", "40대 초반", "40대 중반"]
features = ["자기소개 하나 만들어줘", "에 대한 간략한 소개 부탁해", "의 일상과 업무에 대해 알려줘"]

# 설명 생성 함수
def create_description() -> str:
    job = random.choice(jobs)
    age_group = random.choice(age_groups)
    feature = random.choice(features)
    description = f"{age_group}의 {job} {feature}"
    return description

# 여러 가상의 설명 생성
descriptions = [create_description() for _ in range(20)]

# 생성된 설명 확인
for description in descriptions:
    print(description)
# Out:
# 20대 초반의 건축가 에 대한 간략한 소개 부탁해
# 30대 중반의 초등학교 교사 의 일상과 업무에 대해 알려줘
# 30대 중반의 운동선수 자기소개 하나 만들어줘
# 40대 초반의 의사 자기소개 하나 만들어줘
# 20대 초반의 소프트웨어 엔지니어 에 대한 간략한 소개 부탁해
# 30대 초반의 운동선수 의 일상과 업무에 대해 알려줘
# 30대 중반의 창업가 에 대한 간략한 소개 부탁해
# 30대 중반의 소프트웨어 엔지니어 의 일상과 업무에 대해 알려줘
# 40대 초반의 소프트웨어 엔지니어 자기소개 하나 만들어줘
# 40대 중반의 의사 에 대한 간략한 소개 부탁해
# 30대 초반의 마케팅 전문가 자기소개 하나 만들어줘
# 40대 중반의 마케팅 전문가 에 대한 간략한 소개 부탁해
# 40대 중반의 금융 분석가 의 일상과 업무에 대해 알려줘
# 20대 초반의 금융 분석가 자기소개 하나 만들어줘
# 20대 후반의 운동선수 자기소개 하나 만들어줘
# 20대 초반의 의사 에 대한 간략한 소개 부탁해
# 30대 중반의 소프트웨어 엔지니어 에 대한 간략한 소개 부탁해
# 40대 중반의 운동선수 에 대한 간략한 소개 부탁해
# 30대 중반의 초등학교 교사 자기소개 하나 만들어줘
# 30대 초반의 건축가 의 일상과 업무에 대해 알려줘

# %%
# 프로필 생성을 위한 함수 정의
def create_profile(description: str) -> str:
    response = model_3_5.invoke(description).content
    return response

# 각 설명에 대해 프로필 생성
profiles = [create_profile(description) for description in descriptions]

# 생성된 프로필 확인
for i, profile in enumerate(profiles, start=1):
    print(f"Profile {i}:\n{profile}\n")
# Out:
# Profile 1:
# 20대 초반의 건축가는 전문적인 건축 교육을 받고 현장 경험이 부족한 신진 건축가로, 건축 디자인에 대한 열정과 창의성을 가지고 있습니다. 이들은 새로운 아이디어와 기술을 통해 현대적이고 혁신적인 건축물을 설계하며, 다양한 프로젝트를 경험하며 자신의 스타일과 방향성을 찾아가고 있습니다. 또한, 끊임없는 자기계발과 학습을 통해 전문성을 향상시키고, 건축계에서 인정받을 수 있는 전문가로 성장하고자 합니다.
#
# Profile 2:
# 30대 중반의 초등학교 교사의 일상과 업무는 매우 바쁜 일정을 갖고 있습니다. 보통 아침 일찍 출근하여 학교 준비를 하고, 학생들을 맞이하며 수업을 진행합니다.
#
# 수업이 끝나면 학생들의 안전을 지키기 위해 교실 정리 및 방청활동, 보호자와의 소통 등 다양한 업무를 처리하게 됩니다. 또한 학생들의 학업 및 생활에 대한 관리와 지도를 위해 학습지도 및 학생 상담 업무도 수행합니다.
#
# 또한 교과서의 준비와 교육과정에 따른 교육자료 제작, 학급운영 계획 수립 및 평가 등 교사로서의 전문적인 업무도 맡게 됩니다. 또한 학부모와의 소통을 통해 학생들의 학업 및 학교생활에 대한 정보를 공유하고 협력하여 학생들의 발전을 도모하는 역할도 중요한 부분입니다.
#
# 또한 학생들의 안전과 행복을 지키기 위해 학교 생활 규칙 및 안전 프로토콜을 준수하고, 학생들의 안전 및 보호를 위한 대처 및 상황 관리 역시 교사의 책임이자 업무 중 하나입니다.
#
# 이렇게 바쁜 업무와 책임을 맡고 있지만, 학생들과의 소통과 교육에 대한 열정으로 인해 행복한 순간들을 경험하며, 학생들의 성장과 발전을 도와주는 데 큰 보람을 느낄 수 있습니다.
#
# Profile 3:
# 안녕하세요! 저는 30대 중반의 운동선수 XXX입니다.
#
# 저는 어릴 때부터 운동을 사랑하고, 그로 인해 전국 대회에서 수상한 경력을 가지고 있습니다. 현재는 주로 농구와 테니스를 즐기고 있습니다. 농구를 통해 스피드와 슈팅 능력을 향상시키고, 테니스를 통해 근력과 집중력을 키우고 있습니다.
#
# 운동을 통해 건강하고 활기찬 삶을 살기 위해 노력하고 있습니다. 또한, 운동을 통해 자신감을 키우고 목표를 이루는 데 도움을 주는 것을 느끼고 있습니다.
#
# 나날이 발전하고 성장하는 운동선수로서, 더 나은 성과를 이루기 위해 노력하고 있습니다. 함께 열심히 노력하고 성장하는 동료들과 함께하며 더 나은 선수가 되기 위해 노력할 것입니다. 함께 운동을 즐기고 성장하는 것을 목표로 삼고 있습니다. 감사합니다.
#
# Profile 4:
# 안녕하세요, 40대 초반의 의사 XXX입니다. 저는 신체와 마음의 건강을 동시에 챙기는 통합 의학적 접근을 중시하며, 환자들에게 최상의 치료와 관리를 제공하기 위해 노력하고 있습니다. 특히 만성질환과 스트레스와 같은 정신건강 문제에 대해 전문적인 지식과 경험이 있습니다. 환자들과의 소통을 중요하게 생각하며, 항상 환자의 의견을 존중하고 함께 상담해 나가는 것을 가장 중요한 가치로 삼고 있습니다. 저의 지식과 열정으로 환자들의 건강과 행복을 도모하는데 최선을 다하겠습니다. 함께 건강하고 행복한 삶을 살아가는데 도움이 되길 바랍니다. 감사합니다.
#
# Profile 5:
# 안녕하세요! 20대 초반의 소프트웨어 엔지니어입니다. 프로그래밍에 관심을 가지고 대학교에서 컴퓨터 공학을 전공하였고, 현재는 소프트웨어 개발 분야에서 일하고 있습니다. 주로 웹 개발을 주로 다루며, 프론트엔드와 백엔드 양쪽에서 다양한 프로젝트를 경험하고 있습니다. 새로운 기술과 도구에 대한 열정을 가지고 있으며, 문제 해결과 협업을 통해 더 나은 소프트웨어를 만들기 위해 노력하고 있습니다. 부족한 부분은 끊임없이 공부하며 성장하고자 하는 열정적인 소프트웨어 엔지니어입니다. 함께 일하면서 서로 발전해 나갈 수 있는 기회가 되기를 기대합니다. 감사합니다.
#
# Profile 6:
# 30대 초반의 운동선수는 일반적으로 아침 일찍 일어나서 조깅이나 요가 등의 스트레칭을 하고, 식사를 챙겨 먹은 뒤에 훈련을 시작합니다. 훈련은 주로 체력과 근력을 향상시키기 위한 운동을 중심으로 진행됩니다. 훈련 후에는 영양가 있는 식사를 섭취하고, 몸을 푸는 스트레칭을 하며 휴식을 취합니다.
#
# 운동선수는 훈련 외에도 영양 제품을 복용하거나 마사지를 받아 몸 상태를 유지하며, 다양한 대회나 경기에 참가할 준비를 합니다. 특히, 대회나 경기가 있는 날에는 전날부터 식사와 수면 등을 신경써서 최상의 상태로 경기에 임합니다.
#
# 운동선수의 업무는 주로 스포츠 관련 업체나 팀과의 계약 및 협상, 스포츠 용품 브랜드와의 협찬 계약, 미디어 활동 등이 포함됩니다. 또한, 자신의 팀이나 클럽과의 훈련 일정 조정, 대회 일정 관리, 개인 트레이닝 프로그램 수립 등의 업무도 맡게 될 수 있습니다. 이 외에도 팬들과의 소통, SNS 활동, 스포츠 이벤트나 프로모션 참여 등 다양한 활동을 펼칩니다.
#
# Profile 7:
# 30대 중반의 창업가는 현재 시대의 트렌드와 시장 동향을 잘 파악하고, 창의적이고 도전적인 사고를 가지고 있습니다. 주로 혁신적인 아이디어나 기술을 통해 새로운 비즈니스 모델을 만들어내며, 리더십과 실행력을 갖추고 있습니다. 경험과 지식을 바탕으로 자신의 비전을 실현하기 위해 노력하며, 실패에도 굴하지 않고 변화와 성장을 위해 끊임없이 노력합니다. 통찰력과 통제력을 갖춘 30대 중반의 창업가는 뛰어난 리더십과 비전을 통해 성공적인 창업을 이루어내고 있습니다.
#
# Profile 8:
# 30대 중반의 소프트웨어 엔지니어는 일반적으로 아침 일찍 출근하여 업무를 시작합니다. 일단 오피스에 도착하면 이메일 확인과 업무 일정 확인을 하고, 오늘의 할 일을 정리합니다. 그리고 프로젝트 팀과의 미팅을 진행하거나 개인적으로 할일을 처리하기 시작합니다.
#
# 주로 프로그래밍 언어를 사용하여 소프트웨어를 개발하고 테스트하는 일을 하게 됩니다. 엔지니어들은 코드를 작성하고 디버깅하며, 다른 동료들과 협업하여 소프트웨어를 완성시킵니다. 또한, 새로운 기술을 학습하고 업무에 적용하는 것도 중요한 업무입니다.
#
# 업무 중에는 프로젝트 관리를 위해 이슈 트래킹 시스템을 사용하거나 소스 코드를 버전 관리하는 작업도 함께 이루어집니다. 또한, 클라이언트나 상사와 소통하여 요구사항을 이해하고 프로젝트를 진행하는 것도 중요한 일입니다.
#
# 30대 중반의 소프트웨어 엔지니어는 주로 정해진 근무시간 동안 업무에 집중하고, 필요에 따라 유연한 근무시간을 가질 수도 있습니다. 또한, 새로운 기술이나 도구를 습득하고 자기계발에도 신경을 쓰는 것이 일상적입니다.
#
# Profile 9:
# 안녕하세요, 40대 초반의 소프트웨어 엔지니어로 활동하고 있는 ○○○(이름)입니다.
#
# 저는 다양한 프로그래밍 언어와 기술을 활용하여 소프트웨어 제품을 개발하고, 사용자들이 원활한 서비스 이용 경험을 할 수 있도록 노력하고 있습니다. 주로 웹 개발과 모바일 애플리케이션 개발을 전문으로 하며, 최신 기술 동향을 파악하고 적용하는 것에 관심을 가지고 있습니다.
#
# 끊임없는 도전과 학습을 통해 더 나은 소프트웨어를 만들기 위해 노력하고 있습니다. 업무에 대한 책임감과 성실함을 바탕으로 팀원들과의 협업을 통해 효율적인 결과물을 만들어내는 것을 중요시하고 있습니다.
#
# 더 나은 소프트웨어 개발을 위해 노력하고 있는 저의 모습에 많은 관심과 지지를 부탁드립니다. 함께 더 나은 미래를 만들어 가는데 기여하고 싶습니다. 감사합니다.
#
# Profile 10:
# 40대 중반의 의사는 경력이 어느 정도 쌓인 중년 의사로, 전문적인 지식과 경험을 가지고 있습니다. 환자들에게 안정감을 주고 친절한 태도로 치료를 시행하며, 최신 의학 지식을 바탕으로 정확한 진단과 치료를 제공합니다. 또한, 팀원들과의 원활한 협업을 통해 환자의 건강을 최우선으로 생각하고 있는 전문가입니다.
#
# Profile 11:
# 안녕하세요! 저는 30대 초반의 마케팅 전문가로서 다양한 기업들과 함께 일한 경험이 있습니다. 디지털 마케팅과 브랜드 전략을 중점으로 하여 고객들의 니즈를 파악하고 그에 맞는 효과적인 마케팅 전략을 구사하는 것을 즐깁니다. 소비자 트렌드를 예측하고 분석하여 기존의 마케팅 전략을 더욱 혁신적으로 발전시키는 것에 관심이 많으며, 항상 새로운 것을 배우고 발전하는 것을 추구합니다. 함께 일하면서 성공을 만들어내는 것을 목표로 삼고 있으며, 열정과 창의성을 바탕으로 최고의 결과물을 만들어내는 것에 자부심을 느낍니다. 함께 일하면 더 큰 성과를 이룰 수 있는 파트너가 될 것을 약속드립니다. 감사합니다.
#
# Profile 12:
# 안녕하세요, 40대 중반의 마케팅 전문가입니다. 저는 다양한 기업에서 다채로운 제품과 서비스를 홍보하고 마케팅 전략을 기획하고 실행해왔습니다. 소비자 행동 및 시장 동향을 분석하여 최적의 전략을 수립하고, 디지털 마케팅 및 소셜 미디어를 활용하여 브랜드 인지도를 향상시키는 것을 즐기고 있습니다. 열정적이고 창의적인 마인드를 가지고 있으며 항상 변화하는 시장에서의 도전을 즐기고 있습니다. 함께 일하게 된다면 최선을 다해 기업의 마케팅 성과를 높이는데 도움이 될 것입니다. 감사합니다.
#
# Profile 13:
# 40대 중반의 금융 분석가는 일반적으로 오전부터 점심까지는 주식 시장 및 경제 동향 등을 분석하고 이에 대한 보고서를 작성하는 업무에 주로 매진하게 됩니다. 이를 위해 주식 가격, 기업 실적, 산업 동향, 정책 변화 등을 분석하고 투자 전략을 수립합니다.
#
# 오후에는 회의나 협의를 통해 투자 전략에 대해 논의하고 팀원들과 협력하여 더 나은 전략을 수립하는데 시간을 할애할 수 있습니다. 또한, 신규 투자 기회를 발굴하고 기존 투자 포트폴리오를 관리하는 업무도 중요한 부분입니다.
#
# 금융 분석가는 종종 주식 시장의 변동성과 불확실성에 대처해야 하므로 긴장한 상태에서 일을 하는 경우가 많습니다. 또한, 주식 시장이 급격히 변동할 때는 긴 근무시간을 요구할 수도 있습니다.
#
# 이 외에도 금융 분석가는 최신 경제 이슈와 금융 동향을 계속해서 업데이트하고 자기 계발에도 노력해야 합니다. 끊임없는 학습과 분석 능력 향상이 필요하기 때문에 시간과 노력을 투자해야 합니다.
#
# Profile 14:
# 안녕하세요, 저는 20대 초반의 금융 분석가로서 데이터 분석과 금융 모델링에 능숙한 전문가입니다. 경제학을 전공하여 꾸준히 금융 시장과 관련된 지식을 쌓아왔고, 신뢰성 높은 분석 보고서를 작성하는 데 능숙합니다. 또한, 주식, 채권, 외환 등 다양한 자산 클래스에 대한 전문적인 지식을 보유하고 있습니다. 항상 새로운 도전을 즐기며, 팀원들과의 협업을 통해 최상의 결과물을 만들어내는 데에 자부심을 가지고 있습니다. 함께 일하게 된다면 최상의 성과를 이루어낼 수 있는 열정적이고 전문적인 분석가가 될 것을 약속드립니다. 감사합니다.
#
# Profile 15:
# 안녕하세요, 저는 20대 후반의 운동선수 XXX입니다. 저는 어린 시절부터 운동에 관심을 가지고 항상 최선을 다해왔습니다. 주로 러닝, 웨이트 트레이닝, 요가 등 다양한 운동을 즐기며 몸과 마음을 건강하게 유지하고 있습니다.
#
# 운동을 통해 몸의 근력과 유연성을 향상시키는 것뿐만 아니라, 스포츠 경기에서도 뛰어난 실력을 발휘할 수 있습니다. 특히 뛰어난 체력과 집중력을 바탕으로 경기 중에도 최상의 성과를 얻을 수 있습니다.
#
# 저는 항상 도전을 즐기며, 스스로에게 더 높은 목표를 세우고 끊임없이 노력하는 선수입니다. 또한 팀원들과의 협동심을 중요시하며, 함께 노력하고 성장하는 것을 가장 중요시합니다.
#
# 저는 끊임없는 도전과 성장을 위해 노력하며, 앞으로도 더 나은 모습을 보여드리기 위해 노력할 것입니다. 함께 나아가는 동료들과 함께 더 큰 성취를 이루기 위해 노력하겠습니다. 감사합니다.
#
# Profile 16:
# 이 의사는 20대 초반에 신진 의사로서 많은 열정과 의지를 갖고 있습니다. 학창 시절부터 의학에 대한 꿈을 키우고, 학업을 열심히 해서 의대에 진학했습니다. 현재는 인턴이나 레지던트로서 현장에서의 경험을 쌓고 있으며, 환자들을 치료하고 돌보는 일에 헌신하고 있습니다. 끊임없이 자기계발을 위해 노력하고, 항상 최신의 의학 지식을 습득하려고 노력하고 있습니다. 향후에 더 많은 경험을 쌓고 전문의로 성장해 나갈 계획입니다.
#
# Profile 17:
# 안녕하세요, 30대 중반의 소프트웨어 엔지니어입니다. 전문적으로 소프트웨어 개발 및 시스템 구축에 경력이 있으며, 주로 웹 애플리케이션 및 모바일 앱을 개발하는 것을 즐깁니다. 다양한 프로그래밍 언어와 프레임워크에 능숙하며, 문제 해결능력과 창의성을 바탕으로 사용자들에게 편리하고 효율적인 소프트웨어를 제공하기 위해 항상 노력하고 있습니다. 혁신적인 기술과 트렌드를 주시하며, 항상 새로운 것을 배우고 습득하는 것을 좋아합니다. 함께 일하는 동료들과 협업하는 것을 중요하게 생각하며, 팀원들과의 소통과 협력을 통해 프로젝트를 성공적으로 완수하는 데 기여하고 있습니다. 저의 열정과 전문성을 바탕으로 더 나은 소프트웨어를 만들어내는 것을 목표로 하고 있습니다. 감사합니다.
#
# Profile 18:
# 이 선수는 40대 중반에 속하며, 체력과 근력이 뛰어나고 뛰어난 운동 능력을 가지고 있습니다. 경기력 또한 뛰어나며, 자신의 몸을 잘 다루며 다양한 운동을 수행합니다. 팀 내에서도 리더십을 발휘하며 동료들에게 큰 영감을 주고 있습니다. 40대 중반의 나이에도 불구하고 여전히 열정을 가지고 운동을 즐기고 있습니다.
#
# Profile 19:
# 안녕하세요! 제 이름은 김지혜라고 합니다. 30대 중반의 초등학교 교사로 근무하고 있는데요, 학생들을 가르치는 것을 너무나 즐기는 교사입니다. 학생들과의 소통을 중요하게 생각하며, 항상 학생들의 개개인에 맞는 맞춤 교육을 제공하기 위해 노력하고 있습니다. 학생들이 자신감을 가지고 능동적으로 배울 수 있도록 도와주는 것이 저의 책무라고 생각합니다. 또한, 창의적이고 재미있는 수업을 펼치기 위해 노력하며, 학생들이 학습하는 과정에서 흥미를 느끼도록 노력하고 있습니다. 함께 성장하고 발전하는 학급을 만들기 위해 노력하는 교사로서, 미래를 이끌어갈 학생들을 함께 길러나가는 일에 보람을 느끼고 있습니다. 함께 행복한 교육 공간을 만들어 나가고 싶습니다. 감사합니다.
#
# Profile 20:
# 30대 초반의 건축가는 일반적으로 신진 건축가로서 경력을 쌓고 있는 단계일 것입니다. 이들은 주로 다음과 같은 업무를 수행하고 있을 것입니다.
#
# 1. 프로젝트 기획 및 설계: 건축가는 클라이언트와의 미팅을 통해 프로젝트 요구사항을 이해하고, 이를 바탕으로 건축 설계를 진행합니다. 이 단계에서는 건축 기획서, 도면 및 모형 제작 등이 이루어집니다.
#
# 2. 현장 관리: 건축가는 현장에서 공사 진행 상황을 모니터링하고, 시공 중 발생하는 문제를 해결하며 공사 품질을 유지하는 역할을 합니다.
#
# 3. 예산 및 일정 관리: 건축가는 프로젝트의 예산과 일정을 산정하고, 이를 지켜나가는 역할을 합니다. 이를 통해 프로젝트가 원활하게 진행되도록 지원합니다.
#
# 4. 협업 및 의사소통: 건축가는 클라이언트, 시공사, 기타 전문가들과 원활한 의사소통을 유지하여 프로젝트의 성공을 이루는 데 기여합니다.
#
# 5. 지속적인 전문성 강화: 건축가는 시장 동향과 기술 발전을 지속적으로 업데이트하며, 전문성을 향상시키는 데 노력합니다.
#
# 이러한 업무를 통해 건축가는 전문성을 쌓고, 미래에 더 큰 프로젝트를 성공적으로 이끌어 나갈 수 있는 기반을 다지고 있을 것입니다.

# %%
# 이미 정의된 모델과 파서를 사용하여 여러 프로필로부터 키워드를 추출하는 함수
def extract_keywords_from_profiles(profiles: List[str]) -> List[str]:
    keywords = []
    for profile in profiles:
        result = extract_keyword_chain.invoke({'doc': profile})['keyword_list']
        keywords.extend(result)
    return keywords

# %%
# 여러 프로필에서 키워드 추출
extracted_keywords = extract_keywords_from_profiles(profiles)
extracted_keywords
# Out:
# ['early-career architect',
#  'professional architectural education',
#  'lack of field experience',
#  'passionate about architectural design',
#  'creativity',
#  'innovative architecture',
#  'contemporary design',
#  'exploring personal style',
#  'diverse project experience',
#  'continuous self-improvement',
#  'enhancing expertise',
#  'aspiring to be recognized in the architecture field',
#  '출근',
#  '학교 준비',
#  '수업 진행',
#  '학생 안전',
#  '교실 정리',
#  '보호자 소통',
#  '학습지도',
#  '학생 상담',
#  '교과서 준비',
#  '교육자료 제작',
#  '학급운영 계획',
#  '학부모 소통',
#  '학생 발전',
#  '학교 생활 규칙',
#  '안전 프로토콜',
#  '상황 관리',
#  '교육 열정',
#  '학생 성장',
#  '운동선수',
#  '30대',
#  '전국 대회',
#  '수상',
#  '농구',
#  '테니스',
#  '스피드',
#  '슈팅',
#  '근력',
#  '집중력',
#  '건강',
#  '활기찬 삶',
#  '자신감',
#  '목표',
#  '성장',
#  '성과',
#  '동료',
#  '노력',
#  '통합 의학',
#  '만성질환',
#  '스트레스',
#  '정신건강',
#  '소통',
#  '환자 의견 쭂',
#  '건강과 행복',
#  '상담',
#  '소프트웨어 엔지니어',
#  '프로그래밍',
#  '컴퓨터 공학',
#  '소프트웨어 개발',
#  '웹 개발',
#  '프론트엔드',
#  '백엔드',
#  '새로운 기술',
#  '문제 해결',
#  '협업',
#  '공부',
#  '성장',
#  '운동선수',
#  '아침 일찍',
#  '조깅',
#  '요가',
#  '스트레칭',
#  '식사',
#  '훈련',
#  '체력',
#  '근력',
#  '영양가 있는 식사',
#  '영양 제품 복용',
#  '마사지',
#  '대회 준비',
#  '경기 준비',
#  '계약',
#  '협상',
#  '스포츠 용품 브랜드',
#  '미디어 활동',
#  '훈련 일정 조정',
#  '대회 일정 관리',
#  '개인 트레이닝 프로그램',
#  '팬 소통',
#  'SNS 활동',
#  '스포츠 이벤트',
#  '프로모션 참여',
#  '30대 중반',
#  '창업가',
#  '트렌드',
#  '시장 동향',
#  '창의적',
#  '도전적',
#  '혁신적 아이디어',
#  '기술',
#  '비즈니스 모델',
#  '리더십',
#  '실행력',
#  '경험',
#  '지식',
#  '비전',
#  '변화',
#  '성장',
#  '통찰력',
#  '통제력',
#  '성공적 창업',
#  '소프트웨어 엔지니어',
#  '아침 일찍 출근',
#  '이메일 확인',
#  '업무 일정 확인',
#  '프로젝트 팀 미팅',
#  '프로그래밍 언어',
#  '소프트웨어 개발',
#  '코드 작성',
#  '디버깅',
#  '협업',
#  '새로운 기술 학습',
#  '이슈 트래킹 시스템',
#  '소스 코드 버전 관리',
#  '클라이언트 소통',
#  '요구사항 이해',
#  '유연한 근무시간',
#  '자기계발',
#  '소프트웨어 엔지니어',
#  '프로그래밍 언어',
#  '웹 개발',
#  '모바일 애플리케이션 개발',
#  '최신 기술 동향',
#  '사용자 서비스 이용 경험',
#  '도전',
#  '학습',
#  '책임감',
#  '성실함',
#  '팀원 협업',
#  '효율적인 결과물',
#  '40대 중반 의사',
#  '전문적 지식',
#  '경험',
#  '안정감',
#  '친절한 태도',
#  '최신 의학 지식',
#  '정확한 진단',
#  '치료',
#  '팀원 협업',
#  '환자 건강 최우선',
#  '마케팅 전문가',
#  '디지털 마케팅',
#  '브랜드 전략',
#  '고객 니즈',
#  '효과적인 마케팅 전략',
#  '소비자 트렌드',
#  '마케팅 전략 혁신',
#  '새로운 것 학습',
#  '성과 창출',
#  '열정',
#  '창의성',
#  '최고의 결과물',
#  '마케팅 전문가',
#  '제품 홍보',
#  '서비스 홍보',
#  '마케팅 전략 기획',
#  '마케팅 전략 실행',
#  '소비자 행동 분석',
#  '시장 동향 분석',
#  '최적의 전략 수립',
#  '디지털 마케팅',
#  '소셜 미디어',
#  '브랜드 인지도 향상',
#  '열정적',
#  '창의적',
#  '시장 변화 대응',
#  '마케팅 성과 향상',
#  '주식 시장',
#  '경제 동향',
#  '분석',
#  '보고서',
#  '주식 가격',
#  '기업 실적',
#  '산업 동향',
#  '정책 변화',
#  '투자 전략',
#  '회의',
#  '협의',
#  '팀원 협력',
#  '신규 투자 기회',
#  '포트폴리오 관리',
#  '시장 변동성',
#  '불확실성',
#  '긴 근무시간',
#  '최신 경제 이슈',
#  '금융 동향',
#  '자기 계발',
#  '학습',
#  '분석 능력',
#  '20대 초반',
#  '금융 분석가',
#  '데이터 분석',
#  '금융 모델링',
#  '경제학 전공',
#  '금융 시장',
#  '신뢰성 높은 분석 보고서',
#  '주식',
#  '채권',
#  '외환',
#  '자산 클래스',
#  '새로운 도전',
#  '팀워크',
#  '최상의 결과물',
#  '열정적',
#  '전문적',
#  '운동선수',
#  '러닝',
#  '웨이트 트레이닝',
#  '요가',
#  '근력',
#  '유연성',
#  '체력',
#  '집중력',
#  '도전',
#  '목표',
#  '노력',
#  '협동심',
#  '성장',
#  '성취',
#  'passionate',
#  'early 20s',
#  'aspiring doctor',
#  'dedicated',
#  'medical school',
#  'intern',
#  'resident',
#  'patient care',
#  'self-improvement',
#  'latest medical knowledge',
#  'specialist growth',
#  '소프트웨어 엔지니어',
#  '소프트웨어 개발',
#  '시스템 구축',
#  '웹 애플리케이션 개발',
#  '모바일 앱 개발',
#  '프로그래밍 언어',
#  '프레임워크',
#  '문제 해결능력',
#  '창의성',
#  '사용자 중심 설계',
#  '혁신적인 기술',
#  '기술 트렌드',
#  '지속적 학습',
#  '팀워크',
#  '프로젝트 관리',
#  '소통',
#  '협력',
#  '40대 중반',
#  '체력',
#  '근력',
#  '운동 능력',
#  '경기력',
#  '리더십',
#  '열정',
#  '운동 즐김',
#  '초등학교 교사',
#  '학생들과의 소통',
#  '맞춤 교육',
#  '자신감',
#  '능동적 학습',
#  '창의적 수업',
#  '학습 흥미',
#  '성장과 발전',
#  '미래 인재 육성',
#  '행복한 교육 공간',
#  '프로젝트 기획 및 설계',
#  '현장 관리',
#  '예산 및 일정 관리',
#  '협업 및 의사소통',
#  '지속적인 전문성                                 arFirst Draft                                 강                                ']

# %%
# 키워드의 빈도를 계산하고 가장 인기 있는 핫 키워드를 추출하는 함수
def get_top_keywords(keywords: List[str], top_n: int = 5) -> List[Dict[str, int]]:
    keyword_frequency = Counter(keywords)
    most_common_keywords = keyword_frequency.most_common(top_n)
    return most_common_keywords

# %%
# 인기 키워드 추출
top_keywords = get_top_keywords(extracted_keywords, top_n=5)
top_keywords

print(top_keywords)
# Out:
# [('근력', 4), ('성장', 4), ('소프트웨어 엔지니어', 4), ('운동선수', 3), ('소프트웨어 개발', 3)]
