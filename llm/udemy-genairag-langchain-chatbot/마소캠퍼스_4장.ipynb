# %% [markdown]
# ### **LLM API 활용해보기**

# %%
#필수 라이브러리 설치
# !pip install langchain openai anthropic langchain-openai langchain-anthropic
# Out:
# Collecting langchain
#   Downloading langchain-1.3.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting openai
#   Downloading openai-2.37.0-py3-none-any.whl.metadata (31 kB)
# Collecting anthropic
#   Downloading anthropic-0.102.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.2.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-1.4.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting langchain-core<2.0.0,>=1.4.0 (from langchain)
#   Downloading langchain_core-1.4.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph<1.3.0,>=1.2.0 (from langchain)
#   Downloading langgraph-1.2.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 367.6 kB/s eta 0:00:001m353.9 kB/s eta 0:00:01
# Collecting anyio<5,>=3.5.0 (from openai)
#   Downloading anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.14.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in ./.venv/lib/python3.11/site-packages (from openai) (4.15.0)
# Collecting docstring-parser<1,>=0.15 (from anthropic)
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.13.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai)
#   Downloading idna-3.15-py3-none-any.whl.metadata (7.7 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.4.0->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.14 (from langchain-core<2.0.0,>=1.4.0->langchain)
#   Downloading langchain_protocol-0.0.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.4.0->langchain)
#   Downloading langsmith-0.8.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in ./.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (26.2)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.4.0->langchain)
#   Using cached pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.4.0->langchain)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.4.0->langchain)
#   Downloading uuid_utils-0.15.0-cp311-cp311-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (6.5 kB)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.0->langchain)
#   Downloading langgraph_checkpoint-4.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.0->langchain)
#   Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.3.0,>=1.2.0->langchain)
#   Downloading langgraph_sdk-0.3.14-py3-none-any.whl.metadata (1.7 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.3.0,>=1.2.0->langchain)
#   Downloading xxhash-3.7.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.46.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting regex (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2026.5.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 1.5 MB/s eta 0:00:000m eta -:--:--
# Collecting requests (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain)
#   Downloading jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.0->langchain)
#   Downloading ormsgpack-1.12.2-cp311-cp311-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (3.2 kB)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.0->langchain)
#   Downloading orjson-3.11.9-cp311-cp311-macosx_15_0_arm64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.3 MB/s eta 0:00:000:00:01
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain)
#   Using cached zstandard-0.25.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting charset_normalizer<4,>=2 (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Using cached charset_normalizer-3.4.7-cp311-cp311-macosx_10_9_universal2.whl.metadata (40 kB)
# Collecting urllib3<3,>=1.26 (from requests->tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Downloading langchain-1.3.1-py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.3/114.3 kB 691.9 kB/s eta 0:00:00 kB/s eta 0:00:01
# Downloading openai-2.37.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 367.8 kB/s eta 0:00:000:00:010:00:01:01
# Downloading anthropic-0.102.0-py3-none-any.whl (763 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.1/763.1 kB 240.1 kB/s eta 0:00:000:00:010:00:01:01
# Downloading langchain_openai-1.2.1-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 513.5 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Downloading langchain_anthropic-1.4.3-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 424.3 kB/s eta 0:00:00 kB/s eta 0:00:01
# Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.4/114.4 kB 428.2 kB/s eta 0:00:00 kB/s eta 0:00:01
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.14.0-cp311-cp311-macosx_11_0_arm64.whl (321 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.1/321.1 kB 274.3 kB/s eta 0:00:001m255.7 kB/s eta 0:00:01
# Downloading langchain_core-1.4.0-py3-none-any.whl (548 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.1/548.1 kB 424.3 kB/s eta 0:00:001m425.0 kB/s eta 0:00:01
# Downloading langgraph-1.2.0-py3-none-any.whl (234 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.3/234.3 kB 646.2 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 kB 1.1 MB/s eta 0:00:001.0 MB/s eta 0:00:01m
# Downloading pydantic_core-2.46.4-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 1.3 MB/s eta 0:00:001.3 MB/s eta 0:00:01
# Downloading tiktoken-0.13.0-cp311-cp311-macosx_11_0_arm64.whl (984 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 984.6/984.6 kB 1.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading idna-3.15-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 kB 2.2 MB/s eta 0:00:00
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_protocol-0.0.15-py3-none-any.whl (7.0 kB)
# Downloading langgraph_checkpoint-4.1.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 1.9 MB/s eta 0:00:000m eta -:--:--
# Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 1.5 MB/s eta 0:00:003.9 MB/s eta 0:00:01
# Downloading langgraph_sdk-0.3.14-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 1.9 MB/s eta 0:00:002.3 MB/s eta 0:00:01
# Downloading langsmith-0.8.5-py3-none-any.whl (399 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.6/399.6 kB 1.2 MB/s eta 0:00:001.2 MB/s eta 0:00:01
# Using cached pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl (175 kB)
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.4 MB/s eta 0:00:00
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 1.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading uuid_utils-0.15.0-cp311-cp311-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.1/564.1 kB 999.0 kB/s eta 0:00:00 eta 0:00:010:00:01
# Downloading xxhash-3.7.0-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Downloading regex-2026.5.9-cp311-cp311-macosx_11_0_arm64.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.2/289.2 kB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached charset_normalizer-3.4.7-cp311-cp311-macosx_10_9_universal2.whl (309 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Downloading orjson-3.11.9-cp311-cp311-macosx_15_0_arm64.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 1.3 MB/s eta 0:00:0031m1.5 MB/s eta 0:00:010m
# Downloading ormsgpack-1.12.2-cp311-cp311-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (378 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.3/378.3 kB 1.3 MB/s eta 0:00:001.4 MB/s eta 0:00:01
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 1.0 MB/s eta 0:00:00 MB/s eta 0:00:0101
# Using cached zstandard-0.25.0-cp311-cp311-macosx_11_0_arm64.whl (640 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, urllib3, typing-inspection, tqdm, tenacity, sniffio, regex, pyyaml, pydantic-core, ormsgpack, orjson, langchain-protocol, jsonpointer, jiter, idna, h11, docstring-parser, distro, charset_normalizer, certifi, annotated-types, requests, pydantic, jsonpatch, httpcore, anyio, tiktoken, requests-toolbelt, httpx, openai, langsmith, langgraph-sdk, anthropic, langchain-core, langgraph-checkpoint, langchain-openai, langchain-anthropic, langgraph-prebuilt, langgraph, langchain
# Successfully installed annotated-types-0.7.0 anthropic-0.102.0 anyio-4.13.0 certifi-2026.4.22 charset_normalizer-3.4.7 distro-1.9.0 docstring-parser-0.18.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.15 jiter-0.14.0 jsonpatch-1.33 jsonpointer-3.1.1 langchain-1.3.1 langchain-anthropic-1.4.3 langchain-core-1.4.0 langchain-openai-1.2.1 langchain-protocol-0.0.15 langgraph-1.2.0 langgraph-checkpoint-4.1.0 langgraph-prebuilt-1.1.0 langgraph-sdk-0.3.14 langsmith-0.8.5 openai-2.37.0 orjson-3.11.9 ormsgpack-1.12.2 pydantic-2.13.4 pydantic-core-2.46.4 pyyaml-6.0.3 regex-2026.5.9 requests-2.34.2 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 tiktoken-0.13.0 tqdm-4.67.3 typing-inspection-0.4.2 urllib3-2.7.0 uuid-utils-0.15.0 xxhash-3.7.0 zstandard-0.25.0
#
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# **[앤트로픽의 Claude 2.1 모델 API 호출 코드]**

# %%
import anthropic

anthropic.Anthropic().messages.create(
    model="claude-sonnet-4-20250514",
    max_tokens=1024,
    messages=[
        {"role": "user", "content": "Hello, world"}
    ]
)
# Out:
# /var/folders/sd/72757lvs4fx3jpxplj70p5nh0000gn/T/ipykernel_21561/3194730336.py:6: DeprecationWarning: The model 'claude-sonnet-4-20250514' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   anthropic.Anthropic().messages.create(
# Message(id='msg_01FByBkeuma78XzKnX5btacm', container=None, content=[TextBlock(citations=None, text='Hello! Nice to meet you. How are you doing today? Is there anything I can help you with?', type='text')], model='claude-sonnet-4-20250514', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=10, output_tokens=25, server_tool_use=None, service_tier='standard'))

# %% [markdown]
# **[오픈AI의 GPT-3.5 Turbo 모델 API 호출 코드]**

# %%
from openai import OpenAI

client = OpenAI()
client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": "Who won the world series in 2020?"
        }
    ]
)
# Out:
# ChatCompletion(id='chatcmpl-DgNtJW2UTdTipm5Et5mFNXLtgBqi2', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='The Los Angeles Dodgers won the World Series in 2020. They defeated the Tampa Bay Rays in six games to claim their first championship since 1988.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1778993985, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_ed68e9d81f', usage=CompletionUsage(completion_tokens=32, prompt_tokens=17, total_tokens=49, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %% [markdown]
# **[랭체인을 활용한 앤트로픽 Claude 2.1 모델 API 호출 코드]**

# %%
from langchain_anthropic import ChatAnthropic
chat = ChatAnthropic(
    model="claude-sonnet-4-20250514",
)
chat.invoke("안녕~ 너를 소개해줄래?")
# Out:
# AIMessage(content='안녕하세요! 😊\n\n저는 Anthropic에서 개발한 Claude라고 합니다. \n\n**간단한 소개:**\n- AI 어시스턴트로, 다양한 주제에 대해 대화하고 도움을 드릴 수 있어요\n- 텍스트 작성, 분석, 번역, 창작, 문제 해결 등 여러 작업을 도와드려요\n- 궁금한 것이 있으면 언제든 물어보세요!\n\n**특징:**\n- 정직하고 도움이 되는 답변을 하려고 노력해요\n- 모르는 것은 모른다고 솔직히 말씀드려요\n- 한국어로 자연스럽게 대화할 수 있어요\n\n오늘 어떤 도움이 필요하신가요? 무엇이든 편하게 말씀해 주세요! 🤗', additional_kwargs={}, response_metadata={'id': 'msg_01DjcEabeERhB2mi1jASnRvs', 'container': None, 'model': 'claude-sonnet-4-20250514', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'not_available', 'input_tokens': 23, 'output_tokens': 283, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-20250514', 'model_provider': 'anthropic'}, id='lc_run--019e344e-43c6-7f53-8c10-0b24b7199522-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 283, 'total_tokens': 306, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}})

# %% [markdown]
# **[랭체인을 활용한 오픈AI GPT-3.5 Turbo 모델 API 호출 코드]**

# %%
from langchain_openai import ChatOpenAI
chat = ChatOpenAI(
    model_name = 'gpt-4o',
)
chat.invoke("안녕~ 너를 소개해줄래?")
# Out:
# AIMessage(content='안녕하세요! 저는 인공지능 언어 모델입니다. 다양한 주제에 대해 대화를 나누거나 질문에 답변을 드리는 것이 가능합니다. 여러분께 도움을 드리고자 최선을 다하고 있습니다. 궁금한 점이 있으면 언제든지 물어보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 17, 'total_tokens': 77, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_75d6fecaa6', 'id': 'chatcmpl-DgNtwNJU0NCm5t0hTVYAu84lXCoCT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e344e-8ac4-78f3-9074-3f829a1b29b0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 60, 'total_tokens': 77, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ### **프롬프트 템플릿에 대해 알아보기**

# %% [markdown]
# **[ChatPromptTemplate]**

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages(
    [
	#SystemMessage: 유용한 챗봇이라는 역할과 이름을 부여
        ("system", "You are a helpful AI bot. Your name is {name}."),
    #HumanMessage와 AIMessage: 서로 안부를 묻고 답하는 대화 히스토리 주입
        ("human", "Hello, how are you doing?"),
        ("ai", "I'm doing well, thanks!"),
    #HumanMessage로 사용자가 입력한 프롬프트를 전달
        ("human", "{user_input}"),
    ]
)

messages = chat_template.format_messages(name="Bob", user_input="What is your name?")
print(messages)
# Out:
# [SystemMessage(content='You are a helpful AI bot. Your name is Bob.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello, how are you doing?', additional_kwargs={}, response_metadata={}), AIMessage(content="I'm doing well, thanks!", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is your name?', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import HumanMessagePromptTemplate
from langchain_core.messages import SystemMessage
from langchain_openai import ChatOpenAI

chat_template = ChatPromptTemplate.from_messages(
    [
        SystemMessage(
            content=(
       "You are a helpful assistant that re-writes the user's text to sound more upbeat."
            )
        ),
        HumanMessagePromptTemplate.from_template("{text}"),
    ]
)
messages = chat_template.format_messages(text="I don't like eating tasty things")
print(messages)
# Out:
# [SystemMessage(content="You are a helpful assistant that re-writes the user's text to sound more upbeat.", additional_kwargs={}, response_metadata={}), HumanMessage(content="I don't like eating tasty things", additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ### **LLM API의 다양한 기능 활용해보기**

# %% [markdown]
# **[LLM API의 Temperature 이애하기]**

# %%
#Temperature=0
chatgpt_temp0_1 = ChatOpenAI(model_name="gpt-3.5-turbo-0125", temperature = 0)
chatgpt_temp0_2 = ChatOpenAI(model_name="gpt-3.5-turbo-0125", temperature = 0)

#Temperature=1
chatgpt_temp1_1 = ChatOpenAI(model_name="gpt-3.5-turbo-0125", temperature = 1)
chatgpt_temp1_2 = ChatOpenAI(model_name="gpt-3.5-turbo-0125", temperature = 1)

model_list = [chatgpt_temp0_1, chatgpt_temp0_2, chatgpt_temp1_1, chatgpt_temp1_2]

for i in model_list:
    answer = i.invoke("왜 파이썬이 가장 인기있는 프로그래밍 언어인지 한 문장으로 설명해줘", max_tokens = 128)
    print("-"*100)
    print(">>>",answer.content)
# Out:
# ----------------------------------------------------------------------------------------------------
# >>> 파이썬은 간결하고 읽기 쉬운 문법으로 다양한 분야에서 활용이 가능하며, 풍부한 라이브러리와 커뮤니티 지원으로 개발자들에게 편의성을 제공하기 때문에 가장 인기있는 프로그래밍 언어입니다.
# ----------------------------------------------------------------------------------------------------
# >>> 파이썬은 간결하고 읽기 쉬운 문법으로 다양한 분야에서 활용이 가능하며, 풍부한 라이브러리와 커뮤니티 지원으로 개발자들에게 편의성을 제공하기 때문에 가장 인기있는 프로그래밍 언어입니다.
# ----------------------------------------------------------------------------------------------------
# >>> 파이썬은 간단하고 쉽게 배울 수 있는 문법과 다양한 라이브러리를 제공하여 빠르게 프로토타이핑하고 다양한 분야에 적용하기 쉽기 때문에 가장 인기 있는 프로그래밍 언어이다.
# ----------------------------------------------------------------------------------------------------
# >>> 파이썬은 배우기 쉽고 다양한 분야에서 활용할 수 있는 유연성과 강력한 커뮤니티 지원으로 인해 인기 있는 프로그래밍 언어입니다.

# %% [markdown]
# **[ChatGPT처럼 답변 스트리밍하기]**

# %%
from langchain_openai import ChatOpenAI
chat = ChatOpenAI(model_name="gpt-3.5-turbo-0125", temperature = 0)
for chunk in chat.stream("달에 관한 시를 써줘"):
    print(chunk.content, end="", flush=True)
# Out:
# 달이 높이 떠오르는 밤
# 은은한 빛으로 세상을 비추며
# 하늘을 수놓는 별들과 함께
# 아름다운 풍경을 만들어준다
#
# 달빛 아래 걷는 길은
# 로맨틱한 느낌을 안겨주며
# 사랑하는 이와 함께 한다면
# 더욱 특별한 밤이 될 것이다
#
# 달은 우리에게 희망을 주는
# 빛나는 존재이며
# 언제나 우리를 지켜주는
# 신비로운 존재이다
#
# 달의 아름다움을 느끼며
# 우리의 마음을 달래주는
# 달에 대한 사랑을 노래하며
# 평화롭고 행복한 밤을 보내자.

# %% [markdown]
# **[답변 캐싱하기]**

# %%
from langchain_core.globals import set_llm_cache #캐시메모리 라이브러리 호출
from langchain_openai import ChatOpenAI

chat = ChatOpenAI(model_name="gpt-3.5-turbo-0125", temperature = 0)

# %% [markdown]
# **첫 질문-응답 시간 측정**

# %%
pip install langchain-community
# Out:
# Collecting langchain-community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in ./.venv/lib/python3.11/site-packages (from langchain-community) (1.4.0)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.7-py3-none-any.whl.metadata (5.1 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Downloading sqlalchemy-2.0.49-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in ./.venv/lib/python3.11/site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./.venv/lib/python3.11/site-packages (from langchain-community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.13.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.venv/lib/python3.11/site-packages (from langchain-community) (9.1.4)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.14.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in ./.venv/lib/python3.11/site-packages (from langchain-community) (0.8.5)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting numpy>=1.26.2 (from langchain-community)
#   Downloading numpy-2.4.5-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.5.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached yarl-1.23.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./.venv/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in ./.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.0.15)
# Requirement already satisfied: packaging>=23.2.0 in ./.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (26.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./.venv/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in ./.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in ./.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./.venv/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.4.22)
# Requirement already satisfied: anyio in ./.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.13.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in ./.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.46.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Downloading aiohttp-3.13.5-cp311-cp311-macosx_11_0_arm64.whl (501 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 501.7/501.7 kB 160.8 kB/s eta 0:00:000:00:01m eta 0:00:01
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.7-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 760.5 kB/s eta 0:00:000:00:010:00:01:01
# Downloading numpy-2.4.5-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 1.7 MB/s eta 0:00:000:00:010:00:01:01
# Downloading pydantic_settings-2.14.1-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.1 MB/s eta 0:00:00
# Downloading sqlalchemy-2.0.49-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Using cached frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl (50 kB)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Using cached multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl (44 kB)
# Downloading propcache-0.5.2-cp311-cp311-macosx_11_0_arm64.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 983.5 kB/s eta 0:00:00B/s eta 0:00:01
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.23.0-cp311-cp311-macosx_11_0_arm64.whl (85 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: SQLAlchemy, python-dotenv, propcache, numpy, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, attrs, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-text-splitters, langchain-classic, langchain-community
# Successfully installed SQLAlchemy-2.0.49 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 attrs-26.1.0 dataclasses-json-0.6.7 frozenlist-1.8.0 httpx-sse-0.4.3 langchain-classic-1.0.7 langchain-community-0.4.1 langchain-text-splitters-1.1.2 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 numpy-2.4.5 propcache-0.5.2 pydantic-settings-2.14.1 python-dotenv-1.2.2 typing-inspect-0.9.0 yarl-1.23.0
#
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%time
#셀 실행 시간 측정
from langchain_community.cache import InMemoryCache
set_llm_cache(InMemoryCache()) #캐시메모리 설정

chat.invoke("일반상대성 이론을 한마디로 설명해줘")
# Out:
# CPU times: user 184 ms, sys: 34.7 ms, total: 219 ms
# Wall time: 4.33 s
# AIMessage(content='일반상대성 이론은 질량이나 에너지가 물리적 현상에 미치는 영향을 설명하는 이론으로, 시간과 공간이 상대적이며 중력은 곡률된 공간에 의해 발생한다는 개념을 기반으로 한다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 92, 'prompt_tokens': 27, 'total_tokens': 119, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DgON5WephtFmPMveckXhhAJ1XnErO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e346a-1cc1-74f2-8dc6-f6f4bed5dce1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 92, 'total_tokens': 119, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# **두번째 질문-응답 시간 측정**

# %%
# %%time
#같은 질문 전달
chat.invoke("일반상대성 이론을 한마디로 설명해줘")
# Out:
# CPU times: user 462 μs, sys: 22 μs, total: 484 μs
# Wall time: 490 μs
# AIMessage(content='일반상대성 이론은 질량이나 에너지가 물리적 현상에 미치는 영향을 설명하는 이론으로, 시간과 공간이 상대적이며 중력은 곡률된 공간에 의해 발생한다는 개념을 기반으로 한다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 92, 'prompt_tokens': 27, 'total_tokens': 119, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DgON5WephtFmPMveckXhhAJ1XnErO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e346a-1cc1-74f2-8dc6-f6f4bed5dce1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 27, 'output_tokens': 92, 'total_tokens': 119, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}, 'total_cost': 0})
