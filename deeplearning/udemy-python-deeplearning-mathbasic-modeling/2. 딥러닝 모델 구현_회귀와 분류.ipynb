# %% [markdown]
# # 딥러닝 모델 구현 - 회귀와 분류

# %% [markdown]
# ## 1. 딥러닝 모델 구현 - 선형 회귀

# %%
# 경고 무시
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ### 1) 환경 준비

# %%
import numpy as np
import matplotlib.pyplot as plt

# 텐서플로의 케라스 API에서 필요한 함수 불러오기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### 2) 데이터 준비

# %%
x = np.array([2, 4, 6, 8])     # 공부시간
y = np.array([81, 93, 91, 97]) # 성적

# %% [markdown]
# ### 3) 모델 정의, 컴파일 설정, 모델 학습

# %%
model = Sequential()

# 모델 정의 - 입력, 출력 
model.add(Dense(1, input_dim=1, activation='linear'))

# 컴파일 설정 -  옵티마이저 : 경사 하강법(sgd), 오차 함수 : 평균 제곱 오차(mse) 
model.compile(optimizer='sgd', loss='mse')

# 모델 학습
model.fit(x, y, epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 275ms/step - loss: 8367.4131
# Epoch 2/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 2060.7261
# Epoch 3/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 1129.0913
# Epoch 4/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 986.9521
# Epoch 5/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 960.8046
# Epoch 6/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 951.7274
# Epoch 7/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 945.1912
# Epoch 8/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 939.0623
# Epoch 9/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 933.0263
# Epoch 10/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 927.0372
# Epoch 11/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 921.0882
# Epoch 12/2000
# ...

# %% [markdown]
# ### 4) 그래프로 확인

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x),'r')    
plt.show()
# Out:
# 1/1 [==============================] - 0s 77ms/step

# %% [markdown]
# ### 5) 모델 테스트

# %%
# 7시간 공부, 예상 점수는?
hour = 7
prediction = model.predict([hour])

print("%.f시간을 공부할 경우의 예상 점수는 %.02f점입니다" % (hour, prediction))
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 7시간을 공부할 경우의 예상 점수는 95.12점입니다

# %% [markdown]
# ## 2. 딥러닝 모델 구현 -  다중 선형회귀 모델

# %% [markdown]
# ### 1) 환경 준비

# %%
import numpy as np
import matplotlib.pyplot as plt

#텐서플로의 케라스 API에서 필요한 함수 불러오기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### 2) 데이터 준비

# %%
x = np.array([[2, 0], [4, 4], [6, 2], [8, 3]]) # 입력 변수가 2개(학습 시간, 과외 시간)
y = np.array([81, 93, 91, 97]) # 출력 변수 1개(성적)

# %% [markdown]
# ### 3) 모델 정의, 컴파일 설정, 모델 학습

# %%
model = Sequential()

# 모델 정의 - 입력 변수가 2개(학습 시간, 과외 시간)이므로 input_dim에 2를 입력합니다. 
model.add(Dense(1, input_dim=2, activation='linear'))

# 모델 컴파일
model.compile(optimizer='sgd' , loss='mse')

# 모델 학습
model.fit(x, y, epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 226ms/step - loss: 7221.0806
# Epoch 2/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 1373.0120
# Epoch 3/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 956.1667
# Epoch 4/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 921.3369
# Epoch 5/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 913.4126
# Epoch 6/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 907.4188
# Epoch 7/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 901.5983
# Epoch 8/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 895.8275
# Epoch 9/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 890.0969
# Epoch 10/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 884.4058
# Epoch 11/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 878.7534
# Epoch 12/2000
# ...

# %% [markdown]
# ### 4) 모델 예측

# %%
# 7시간 학습시간, 과외시간 4시간, 예측 점수는?

hour = 7
private_class = 4
prediction = model.predict([[hour, private_class]])

print("%.f시간을 공부하고 %.f시간의 과외를 받을 경우, 예상 점수는 %.02f점입니다" % (hour, private_class, prediction))
# Out:
# 1/1 [==============================] - 0s 63ms/step
# 7시간을 공부하고 4시간의 과외를 받을 경우, 예상 점수는 97.53점입니다

# %% [markdown]
# ## 3. 딥러닝 모델 구현 - 로지스틱 회귀 모델(이항 분류)

# %% [markdown]
# ### 1) 환경 준비

# %%
import numpy as np
import matplotlib.pyplot as plt

# 텐서플로의 케라스 API에서 필요한 함수 불러오기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### 2) 데이터 준비

# %%
x = np.array([2, 4, 6, 8, 10, 12, 14]) # 공부 시간
y = np.array([0, 0, 0, 1, 1, 1, 1])    # 합격 여부: 0 - 불합격, 1 - 합격

# %% [markdown]
# ### 3) 모델 정의, 컴파일 설정, 모델 학습

# %%
model = Sequential()

# 모델 정의 - 입력, 출력 
model.add(Dense(1, input_dim=1, activation='sigmoid'))

# 컴파일 설정 -  옵티마이저 : 경사 하강법(sgd), 오차 함수 : 교차엔트로피
model.compile(optimizer='sgd' ,loss='binary_crossentropy')

# 모델 학습
model.fit(x, y, epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 292ms/step - loss: 2.2329
# Epoch 2/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2026
# Epoch 3/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1723
# Epoch 4/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1421
# Epoch 5/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1119
# Epoch 6/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0817
# Epoch 7/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0516
# Epoch 8/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0215
# Epoch 9/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9915
# Epoch 10/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9615
# Epoch 11/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.9316
# Epoch 12/2000
# ...

# %% [markdown]
# ### 4) 그래프로 확인

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x),'r')
plt.show()
# Out:
# 1/1 [==============================] - 0s 44ms/step

# %% [markdown]
# ### 5) 모델 테스트

# %%
# 7시간 공부,  합격 예상 확률?
hour = 7
prediction = model.predict([hour])

print("%.f시간을 공부할 경우, 합격 예상 확률은 %.01f%%입니다" % (hour, prediction * 100))
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 7시간을 공부할 경우, 합격 예상 확률은 63.3%입니다
