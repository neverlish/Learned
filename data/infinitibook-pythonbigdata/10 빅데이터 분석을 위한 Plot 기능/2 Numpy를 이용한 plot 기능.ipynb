# %%
# %matplotlib inline

import numpy as np

points = np.array([[1,1], [1,2], [1,3], [2,1], [2,2], [2,3], [3,1], [3,2], [3,3]])

p = np.array([2.5, 2])

import matplotlib.pyplot as plt
plt.plot(points[:, 0], points[:, 1], 'ro')
plt.plot(p[0], p[1], 'bo');

# %%
x = np.linspace(0, 5, 10)
y = x ** 2
plt.plot(x, y);

# %%
x = np.linspace(0, 10, 20)
y = x ** 2
plt.plot(x, y, 'bo-', linewidth=3, markersize=5);

# %%
plt.plot(x, y, 'gs-', linewidth=1, markersize=3);

# %%
y1 = x ** 2.0
y2 = x ** 1.5

plt.plot(x, y1, 'bo-', linewidth=2, markersize=12, label='First')
plt.plot(x, y2, 'gs-', linewidth=2, markersize=12, label='Second')

plt.xlabel('X')
plt.ylabel('Y')
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc='upper left')
plt.savefig('./output/mplot.pdf')

# %%
x = np.logspace(-1, 1, 20)
y1 = x ** 2.0
y2 = x ** 1.5

plt.plot(x, y1, 'bo-', linewidth=2, markersize=5, label='First')
plt.plot(x, y2, 'gs-', linewidth=2, markersize=5, label='Second')

plt.xlabel('X')
plt.ylabel('Y')
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc='upper left')
plt.savefig('./output/mplot2.pdf')

# %%
x = np.random.standard_normal(size=1000)
plt.hist(x)
# Out:
# (array([ 11.,  23.,  67., 138., 202., 226., 195.,  83.,  47.,   8.]),
#  array([-3.04642997, -2.46256868, -1.87870738, -1.29484609, -0.71098479,
#         -0.1271235 ,  0.4567378 ,  1.04059909,  1.62446039,  2.20832168,
#          2.79218298]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x, density=True)
# Out:
# (array([0.01884009, 0.03939292, 0.11475328, 0.23635751, 0.34597258,
#         0.38707824, 0.33398343, 0.14215705, 0.08049857, 0.01370188]),
#  array([-3.04642997, -2.46256868, -1.87870738, -1.29484609, -0.71098479,
#         -0.1271235 ,  0.4567378 ,  1.04059909,  1.62446039,  2.20832168,
#          2.79218298]),
#  <a list of 10 Patch objects>)

# %%
x = np.random.randn(1000)
plt.hist(x)
# Out:
# (array([  2.,   5.,  37., 144., 251., 257., 195.,  80.,  25.,   4.]),
#  array([-3.6521017 , -2.95541784, -2.25873399, -1.56205013, -0.86536628,
#         -0.16868242,  0.52800143,  1.22468529,  1.92136914,  2.618053  ,
#          3.31473685]),
#  <a list of 10 Patch objects>)

# %%
x = np.random.randn(30)
y = np.random.randn(30)
colors = np.random.rand(30)
shape = np.pi * (np.random.randn(30) * 20) ** 2
plt.scatter(x, y, s=shape, c=colors, marker='*', alpha=0.7)
plt.show()
