# %%
import requests

# %%
url = 'http://goodmonitoring.com/monitor_board/'

# %%
html = requests.get(url).text

# %%
board_url = 'http://goodmonitoring.com/xe/moi'

# %%
html = requests.get(board_url).text

# %%
html
# Out:
# '<!DOCTYPE html>\n<html lang="ko">\n<head>\n<!-- META -->\n<meta charset="utf-8">\n<meta name="Generator" content="XpressEngine">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<!-- TITLE -->\n<title>모니터링모집게시판</title>\n<!-- CSS -->\n<link rel="stylesheet" href="/xe/common/css/xe.min.css?20170221221000" />\n<link rel="stylesheet" href="/xe/common/js/plugins/ui/jquery-ui.min.css?20170221221000" />\n<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.2.0/css/font-awesome.min.css" />\n<link rel="stylesheet" href="/xe/modules/board/skins/sketchbook5/css/board.css?20140915091455" />\n<!--[if lt IE 9]><link rel="stylesheet" href="/xe/modules/board/skins/sketchbook5/css/ie8.css?20140915091455" />\n<![endif]--><link rel="stylesheet" href="/xe/modules/editor/styles/default/style.css?20170221221000" />\n<link rel="stylesheet" href="/xe/addons/font_nanum_gothic/font-nanum_gothic.css?20141106101209" />\n<link rel="stylesheet" href="/xe/addons/webfont/css/nanumfont.css?20140303165905" />\n<!-- JS -->\n<!--[if lt IE 9]><script src="/xe/common/js/jquery-1.x.min.js?20170221221000"></script>\n<![endif]--><!--[if gte IE 9]><!--><script src="/xe/common/js/jquery.min.js?20170221221000"></script>\n<!--<![endif]--><script src="/xe/common/js/x.min.js?20170221221000"></script>\n<script src="/xe/common/js/xe.min.js?20170221221000"></script>\n<script src="/xe/modules/board/tpl/js/board.min.js?20170221221000"></script>\n<!-- RSS -->\n<link rel="alternate" type="application/rss+xml" title="RSS" href="/xe/moi/rss" /><link rel="alternate" type="application/atom+xml" title="Atom" href="/xe/moi/atom" /><!-- ICON -->\n\n\n<style> .xe_content { font-family:"나눔고딕";font-size:12px; }</style>\n<link rel="canonical" href="http://goodmonitoring.com/xe/moi" />\n<meta property="og:locale" content="ko_KR" />\n<meta property="og:type" content="website" />\n<meta property="og:url" content="http://goodmonitoring.com/xe/moi" />\n<meta property="og:title" content="모니터링모집게시판" />\n\n<style type="text/css">\nbody,input,textarea,select,button,table{font-family:,\'나눔고딕\',NanumGothic,ng,Tahoma,Geneva,sans-serif}\n@font-face{font-family:ng;font-style:normal;font-weight:normal;src:url(http://themes.googleusercontent.com/static/fonts/earlyaccess/nanumgothic/v3/NanumGothic-Regular.eot)\\9}\n@font-face{font-family:ng;font-style:normal;font-weight:bold;src:url(http://themes.googleusercontent.com/static/fonts/earlyaccess/nanumgothic/v3/NanumGothic-Bold.eot)\\9}\n\n\n\n\n\n</style>\n\t\n\n<style data-id="bdCss">\n.bd,.bd input,.bd textarea,.bd select,.bd button,.bd table{font-family:Tahoma,\'돋움\',Dotum,\'돋움\',Dotum,Helvetica,\'Apple SD Gothic Neo\',sans-serif}\n.bd .ngeb{font-family:\'돋움\',Dotum,Helvetica,\'Apple SD Gothic Neo\',sans-serif}\n.bd a:focus,.bd input:focus,.bd button:focus,.bd textarea:focus,.bd select:focus{outline-color:#87cefa;}\n.bd .replyNum{color:#87cefa !important}\n.bd .trackbackNum{color:#5f9ea0 !important}\n.bd.fdb_count .replyNum{background:#87cefa;}\n.bd.fdb_count .trackbackNum{background:#5f9ea0;}\n.bd em,.bd .color{color:#87cefa;}\n.bd .shadow{text-shadow:1px 1px 1px #5f9ea0;}\n.bd .bolder{color:#87cefa;text-shadow:2px 2px 4px #5f9ea0;}\n.bd .bg_color{background-color:#87cefa;}\n.bd .bg_f_color{background-color:#87cefa;background:-webkit-linear-gradient(#FFF -50%,#87cefa 50%);background:linear-gradient(to bottom,#FFF -50%,#87cefa 50%);}\n.bd .border_color{border-color:#87cefa;}\n.bd .bx_shadow{box-shadow:0 0 2px #5f9ea0;}\n.viewer_with.on:before{background-color:#87cefa;box-shadow:0 0 2px #87cefa;}\n.bd_zine .info b,.bd_zine .info a{color:#5f9ea0;}\n.bd_zine.card h3{color:#87cefa;}\n.bd_tb_lst .cate span,.bd_tb_lst .author span,.bd_tb_lst .last_post small{max-width:px}\n</style><script>\n//<![CDATA[\nvar current_url = "http://goodmonitoring.com/xe/?mid=moi";\nvar request_uri = "http://goodmonitoring.com/xe/";\nvar current_mid = "moi";\nvar waiting_message = "서버에 요청 중입니다. 잠시만 기다려주세요.";\nvar ssl_actions = new Array();\nvar default_ ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
rows = []
for tr_tag in soup.select('.bd_lst_wrp > table tbody tr'):
    cols = []
    for td_tag in tr_tag.select('td'):
        cols.append(td_tag.text.strip())
    print(cols)
    rows.append(cols)
# Out:
# ['공지', '일반모니터', '[더스킨팩토리] 쿤달 뷰티 체험단 2기 모집 (~07.28)', 'hera', '2017.07.07', '6']
# ['공지', '대학생모니터', '[부산시] 제20회 부산국제관광전 서포터즈 모집 (~ 07.25)', 'hera', '2017.07.07', '5']
# ['공지', '일반모니터', '[더블앤제로] 더블리 7기 모집 (~ 07.27)', 'hera', '2017.07.07', '7']
# ['8925', '일반모니터', '[코스메카코리아] 메카프렌즈 5기 모집 (~07.14)', 'hera', '2017.07.07', '10']
# ['8924', '대학생모니터', '[한국문화예술위원회] 예술나무 알리미 2기 모집 (~ 07.09)', 'hera', '2017.07.07', '9']
# ['8923', '대학생모니터', '[건원엔지니어링] 서포터즈 3기 모집 (~ 07.16)', 'hera', '2017.07.07', '2']
# ['8922', '일반모니터', '[보나쥬르] 네이쳐프렌즈 서포터즈 모집 (~07.11)', 'hera', '2017.07.06', '20']
# ['8921', '일반모니터', '[미샤] 미샤니아 4기 모집 (~07.23)', 'hera', '2017.07.06', '26']
# ['8920', '일반모니터', '[한국문화관광연구원] 아키스 2기 모집 (~ 07.19)', 'hera', '2017.07.06', '34']
# ['8919', '일반모니터', '[KBL] 어시스터 2기 모집 (~ 07.20)', 'hera', '2017.07.06', '22']
# ['8918', '대학생모니터', '[외교부] 서포터즈 11기 모집 (~ 07.23)', 'hera', '2017.07.05', '24']
# ['8917', '일반모니터', '[레페토] 에뚜왈 11기 모집 (~ 07.23)', 'hera', '2017.07.05', '24']
# ['8916', '대학생모니터', '[신기한리스닝나라] 쏙쏙리스너 6기 모집 (~07.19)', 'hera', '2017.07.05', '8']
# ['8915', '일반모니터', '[쿠우쿠우] Fresh Supporters 모집 (~ 07.19)', 'hera', '2017.07.05', '45']
# ['8914', '일반모니터', '[한국관광공사] 청와대 사랑채 & K-STYLE HUB 온라인 홍보단 모집 (~ 07.11)', 'hera', '2017.07.05', '40']
# ['8913', '일반모니터', '[슈발베] 서포터즈 1기 모집 (~ 07.12)', 'hera', '2017.07.05', '24']
# ['8912', '대학생모니터', '[한국직업방송] 드림스피커즈 2기 모집 (~ 07.31)', 'hera', '2017.07.04', '11']
# ['8911', '대학생모니터', '[삼성전자] 대학생 기자단 6기 모집 (~08.13)', 'hera', '2017.07.04', '9']
# ['8910', '주부모니터', '[애니스쿨] 애니맘 15기 모집 (~ 07.04)', 'hera', '2017.07.04', '20']
# ['8909', '주부모니터', '[씨엔티코리아] 스텐락 주부 서포터즈 6기 모집 (~ 07.28)', 'hera', '2017.07.04', '37']

# %%
import csv

with open('goodsmonitoring.csv', 'wt', encoding='utf8') as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# %%
# %cat goodsmonitoring.csv
# Out:
# 공지,일반모니터,[더스킨팩토리] 쿤달 뷰티 체험단 2기 모집 (~07.28),hera,2017.07.07,6
# 공지,대학생모니터,[부산시] 제20회 부산국제관광전 서포터즈 모집 (~ 07.25),hera,2017.07.07,5
# 공지,일반모니터,[더블앤제로] 더블리 7기 모집 (~ 07.27),hera,2017.07.07,7
# 8925,일반모니터,[코스메카코리아] 메카프렌즈 5기 모집 (~07.14),hera,2017.07.07,10
# 8924,대학생모니터,[한국문화예술위원회] 예술나무 알리미 2기 모집 (~ 07.09),hera,2017.07.07,9
# 8923,대학생모니터,[건원엔지니어링] 서포터즈 3기 모집 (~ 07.16),hera,2017.07.07,2
# 8922,일반모니터,[보나쥬르] 네이쳐프렌즈 서포터즈 모집 (~07.11),hera,2017.07.06,20
# 8921,일반모니터,[미샤] 미샤니아 4기 모집 (~07.23),hera,2017.07.06,26
# 8920,일반모니터,[한국문화관광연구원] 아키스 2기 모집 (~ 07.19),hera,2017.07.06,34
# 8919,일반모니터,[KBL] 어시스터 2기 모집 (~ 07.20),hera,2017.07.06,22
# 8918,대학생모니터,[외교부] 서포터즈 11기 모집 (~ 07.23),hera,2017.07.05,24
# 8917,일반모니터,[레페토] 에뚜왈 11기 모집 (~ 07.23),hera,2017.07.05,24
# 8916,대학생모니터,[신기한리스닝나라] 쏙쏙리스너 6기 모집 (~07.19),hera,2017.07.05,8
# 8915,일반모니터,[쿠우쿠우] Fresh Supporters 모집 (~ 07.19),hera,2017.07.05,45
# 8914,일반모니터,[한국관광공사] 청와대 사랑채 & K-STYLE HUB 온라인 홍보단 모집 (~ 07.11),hera,2017.07.05,40
# 8913,일반모니터,[슈발베] 서포터즈 1기 모집 (~ 07.12),hera,2017.07.05,24
# 8912,대학생모니터,[한국직업방송] 드림스피커즈 2기 모집 (~ 07.31),hera,2017.07.04,11
# 8911,대학생모니터,[삼성전자] 대학생 기자단 6기 모집 (~08.13),hera,2017.07.04,9
# 8910,주부모니터,[애니스쿨] 애니맘 15기 모집 (~ 07.04),hera,2017.07.04,20
# 8909,주부모니터,[씨엔티코리아] 스텐락 주부 서포터즈 6기 모집 (~ 07.28),hera,2017.07.04,37
